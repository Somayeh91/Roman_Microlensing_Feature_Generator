# %%
from Common_functions import  localize_event,prepare, bell_curve,PSPL, bell_curve_data

# %matplotlib inline

# %%
import glob,os,sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from numpy import *
import re
from tqdm import tqdm
import scipy.stats as st
from os.path import expanduser
import cmath
from scipy import optimize
import time
import gzip
from scipy.interpolate import interp1d
import pandas as pd
from scipy.interpolate import interp1d
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import (mark_inset,inset_axes,InsetPosition) 
import traceback
from lmfit import minimize, Parameters, Parameter, report_fit


# %matplotlib inline
home = os.path.expanduser("~")

# %%
def cal_chisqr(model, fx, ferr):
    
    
    return np.sum(((fx-model)**2)/((ferr)**2))

# %%
def PSPL_data (params, t, m_data):
    
    t0 = params['t0'].value
    tE = params['tE'].value
    u0 = params['u0'].value
    base = params['base'].value
    fs = params['fs'].value
#     fb = params['fb'].value

    u = np.sqrt(u0**2+((t-t0)/tE)**2)
    A = ((u**2)+2)/(u*np.sqrt(u**2+4))
    F = (fs * (A-1)) +1
    fx = base*np.ones(len(t)) + (-2.5 * np.log10(F))
    return fx - m_data

def PSPL (t0, tE, u0, base,fs, t):
    
    u = np.sqrt(u0**2+((t-t0)/tE)**2)
    A = ((u**2)+2)/(u*np.sqrt(u**2+4))
    F = (fs * (A-1)) +1
    fx = base*np.ones(len(t)) + (-2.5 * np.log10(F))
    return fx

# %%
def Calculate_PSPL_minus_Cauchy (t, m, e):
    
    c = 2
    
    lightcurve = np.zeros((len(t),4))
    lightcurve[:,0] = t
    lightcurve[:,1] = m
    lightcurve[:,2] = e
    peak = t[np.argmin(m)]

    df, baseline, event, it0, dt = prepare(t,m,e)

    A_max = df['A'][np.argmin(m[m>np.percentile(m, [0.0,100])[0]])] #np.max(df['A']) #1.0/(float(f_s_true)/(max(df['f'])-1+float(f_s_true)))
    u0_true = np.sqrt( ( (1+np.sqrt(1+16*(A_max**2)))/(2* A_max) ) - 2 )
    t0_true =  df['t'][np.argmin(m[m>np.percentile(m, [0.0,100])[0]])] #it0 #t[A.argmax()] #float(t0_theo)
    amp_ini = np.median(lightcurve[baseline,1]) - lightcurve[it0,1]
    tE_true = [0.01, 0.1, 1.0, 10.0, 100]

    ##################################
    temp_bell = [[], []]
    for tE in tE_true:

        params = Parameters()
        params.add('t0', value= t0_true, min=min(df['t']), max=max(df['t']))
        params.add('tE', value= tE, min=0.0001, max=1000)
        params.add('b', value= 1, min=0, max=20)
        params.add('amp', value= amp_ini, min=0, max=20)


        res1 = minimize(bell_curve_data, params, args=(df['t'].values, -lightcurve[:,1]+np.median(lightcurve[baseline,1])))
        temp_bell[0].append(res1.params)
        temp_bell[1].append(res1.chisqr)
        
    result1 = temp_bell[0][np.argmin(temp_bell[1])]

    bellcurve_m = np.median(lightcurve[baseline,1])-bell_curve(t, result1['t0'], result1['tE'] , 
                                                                  result1['b'], result1['amp'])

    #print bellcurve_m
    m_top = df['magnitude'][(df.t < result1['t0'] + c * result1['tE']) & (df.t > result1['t0'] - c * result1['tE'])]
    model_top = bellcurve_m[(df.t < result1['t0'] + c * result1['tE']) & (df.t > result1['t0'] - c * result1['tE'])]
    m_err_top = df['m_err'][(df.t < result1['t0'] + c * result1['tE']) & (df.t > result1['t0'] - c * result1['tE'])]
    
    chisqr_bell = np.sum((df['magnitude'].values-bellcurve_m)**2)
    chisqr_bell_err = cal_chisqr(bellcurve_m, df['magnitude'].values, df['m_err'].values)
    chisqr_bell_top = cal_chisqr(model_top, m_top.values, m_err_top.values)
    chisqr_bell_top_reduced = chisqr_bell_top/(len(model_top))
    
    #################################
    temp_PSPL = [[], []]
    for tE in tE_true:

        params2 = Parameters()
        params2.add('t0', value= t0_true, min=min(df['t']), max=max(df['t']))
        params2.add('tE', value= tE, min=0.001, max=1000)
        params2.add('u0', value= u0_true, min=0, max=5)
        params2.add('base', value= np.median(lightcurve[baseline,1]), min=max((lightcurve[baseline,1])), max=min((lightcurve[baseline,1])))
        params2.add('fs', value= 1, min=0, max=1)
#             params2.add('fb', value= 0.5, min=0, max=1)


        res2 = minimize(PSPL_data, params2, args=(df['t'].values, df['magnitude'].values))

        temp_PSPL[0].append(res2.params)
        temp_PSPL[1].append(res2.chisqr)

    result2 = temp_PSPL[0][np.argmin(temp_PSPL[1])]

    PSPL_m = PSPL(result2['t0'], result2['tE'], result2['u0'],
                  result2['base'], result2['fs'] , df['t'])
    #PSPL_m = base*np.ones(len(PSPL_A)) + (-2.5 * np.log10(PSPL_A))

    m_top = df['magnitude'][(df.t < result1['t0'] + c * result1['tE']) & (df.t > result1['t0'] - c * result1['tE'])]
    model_top = PSPL_m[(df.t < result1['t0'] + c * result1['tE']) & (df.t > result1['t0'] - c * result1['tE'])]
    m_err_top = df['m_err'][(df.t < result1['t0'] + c * result1['tE']) & (df.t > result1['t0'] - c * result1['tE'])]

    chisqr_PSPL = np.sum((df['magnitude'].values-PSPL_m)**2)

    chisqr_PSPL_err = cal_chisqr(PSPL_m, df['magnitude'].values, df['m_err'].values)
    chisqr_PSPL_top = cal_chisqr(model_top, m_top.values, m_err_top.values)
    chisqr_PSPL_top_reduced = chisqr_PSPL_top/len(model_top)
    #################################
    
    return df, baseline, event, result1, result2, chisqr_bell, chisqr_bell_err, chisqr_PSPL,\
            chisqr_PSPL_err, chisqr_bell_top, chisqr_PSPL_top, chisqr_bell_top_reduced, chisqr_PSPL_top_reduced

# %%
name = 'mag.dcnormffp_0_82_1962.det.lc.W149'
f = home+'/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/'+str(name)
t,m,e = np.loadtxt(f,unpack=True)

print len(t)

F = 100**((np.max(m)-m)/5)

df = pd.DataFrame({'t': t, 'Flux_Ratio': F, 'magnitude': m, 'm_err': e})

lightcurve = np.zeros((len(t),4))
lightcurve[:,0] = t
lightcurve[:,1] = m
lightcurve[:,2] = e
peak = t[np.argmin(m)]

df, baseline, event, it0, dt = prepare(t,m,e)
# Out:
# 38568

# %%
# A_max = df['A'][np.argmin(m[m>np.percentile(m, [0.0,100])[0]])] #np.max(df['A']) #1.0/(float(f_s_true)/(max(df['f'])-1+float(f_s_true)))
# u0_true = np.sqrt( ( (1+np.sqrt(1+16*(A_max**2)))/(2* A_max) ) - 2 )
# t0_true =  df['t'][np.argmin(m[m>np.percentile(m, [0.0,100])[0]])] #it0 #t[A.argmax()] #float(t0_theo)
# amp_ini = np.median(lightcurve[baseline,1]) - lightcurve[it0,1]
# tE_true = dt

# params = Parameters()
# params.add('t0', value= t0_true, min=min(df['t']), max=max(df['t']))
# params.add('tE', value= 0.01, min=0.0001, max=1000)
# params.add('b', value= 1, min=0, max=10)
# params.add('amp', value= amp_ini, min=0, max=20)


# result = minimize(bell_curve_data, params, args=(df['t'].values, -lightcurve[:,1]+np.median(lightcurve[baseline,1])))

# bellcurve_m = np.median(lightcurve[baseline,1])-bell_curve(t, result.params['t0'].value, 
#                                                                     result.params['tE'].value , result.params['b'].value,
#                                                                     result.params['amp'].value)

# %%
# df['model'] = np.median(lightcurve[baseline,1])-bell_curve(t, result.params['t0'].value, 
#                                                                     result.params['tE'].value , result.params['b'].value,
#                                                                     result.params['amp'].value)

# %%
# print np.median(lightcurve[baseline,1]), result.params['tE'].value , result.params['b'].value,result.params['amp'].value

# %%
# x = np.linspace(-2,2,1000)
# y = np.median(lightcurve[baseline,1])-bell_curve(x, 0.0, result.params['tE'].value , result.params['b'].value,
#                                                                     result.params['amp'].value)

# %%
# def smooth(y, box_pts):
#     box = np.ones(box_pts)/box_pts
#     y_smooth = np.convolve(y, box, mode='same')
#     return y_smooth

# %%
# dtt = 0.1
# plt.figure()
# plt.title('Fitting Cauchy Distribution PSPL to a Lightcurve', size=25)
# plt.xlabel('$t - t_0 (days)$',size=29)
# plt.ylabel('$Magnitude$',size=29)
# plt.tick_params(axis='y',labelsize=18)
# plt.tick_params(axis='x',labelsize=20)
# # plt.plot(t, m, 'b.', markersize=15)
# #print param['t_eff=5']
# plt.plot(t, smooth(df['model'],1), 'r-')
# #plt.plot(t[event]-peak, bfx[event], 'k-')
# plt.axvline(result.params['t0'].value)

# plt.ylim(18, 18.4)
# plt.xlim(result.params['t0'].value-dtt, result.params['t0'].value+dtt)
# plt.gca().invert_yaxis()
# fig = plt.gcf()
# fig.set_size_inches(12.0,10.0)
# #fig.savefig('Trapezoid_FFP.png')

# %%
# params2 = Parameters()
# params2.add('t0', value= t0_true, min=min(df['t']), max=max(df['t']))
# params2.add('tE', value= 0.01, min=0.001, max=1000)
# params2.add('u0', value= u0_true, min=0, max=5)
# params2.add('base', value= np.median(lightcurve[baseline,1]), min=max((lightcurve[baseline,1])), max=min((lightcurve[baseline,1])))
# params2.add('fs', value= 0.5, min=0, max=1)
# # params2.add('fb', value= 0.5, min=0, max=1)



# result2 = minimize(PSPL_data, params2, args=(df['t'].values, df['magnitude'].values))

# PSPL_m = PSPL(result2.params['t0'],result2.params['tE'],result2.params['u0'],
#               result2.params['base'],result2.params['fs'], df['t'])
# #PSPL_m = base*np.ones(len(PSPL_A)) + (-2.5 * np.log10(PSPL_A))

# %%
# result2

# %%
plt.figure()
plt.title('Fitting Cauchy Distribution PSPL to a Lightcurve', size=25)
plt.xlabel('$t - t_0 (days)$',size=29)
plt.ylabel('$Magnitude$',size=29)
plt.tick_params(axis='y',labelsize=18)
plt.tick_params(axis='x',labelsize=20)
plt.plot(t, m, 'b.', markersize=15)
#print param['t_eff=5']
plt.plot(t, PSPL_m, 'r-')
plt.plot(t, bellcurve_m, 'k-')
plt.axvline(result2.params['t0'].value)


plt.xlim(result2.params['t0'].value-dtt, result2.params['t0'].value+dtt)
plt.gca().invert_yaxis()
fig = plt.gcf()
fig.set_size_inches(12.0,10.0)
#fig.savefig('Trapezoid_FFP.png')

# %%
df, baseline, event, result1, result2, chisqr_bell, chisqr_bell_err, chisqr_PSPL, chisqr_PSPL_err, chisqr_bell_top, chisqr_PSPL_top = Calculate_PSPL_minus_Cauchy(t, m, e)

# %%
result1
# Out:
# Parameters([('t0',
#              <Parameter 't0', value=2460038.2877746946 +/- 0.00189, bounds=[2458346.505461:2460059.241444]>),
#             ('tE',
#              <Parameter 'tE', value=0.06965866004550145 +/- 0.00386, bounds=[0.0001:1000]>),
#             ('b',
#              <Parameter 'b', value=0.9380535267749057 +/- 0.0494, bounds=[0:10]>),
#             ('amp',
#              <Parameter 'amp', value=0.16136551413925004 +/- 0.00533, bounds=[0:20]>)])

# %%
print chisqr_PSPL_top-chisqr_bell_top
# Out:
# 4.149915558233655

# %%
dtt = 0.2

PSPL_m = PSPL(result2['t0'],result2['tE'],result2['u0'],
              result2['base'],result2['fs'], df['t'])
bellcurve_m = np.median(df['magnitude'][baseline])-bell_curve(df['t'], result1['t0'].value, 
                                                              result1['tE'].value , result1['b'].value,
                                                              result1['amp'].value)
print chisqr_PSPL - chisqr_bell

plt.figure()
plt.title('Fitting Cauchy Distribution PSPL to a Lightcurve', size=25)
plt.xlabel('$t - t_0 (days)$',size=29)
plt.ylabel('$Magnitude$',size=29)
plt.tick_params(axis='y',labelsize=18)
plt.tick_params(axis='x',labelsize=20)
plt.plot(df['t'], df['magnitude'], 'b.', markersize=15)
#print param['t_eff=5']
plt.plot(df['t'], PSPL_m, 'r-')
plt.plot(df['t'], bellcurve_m, 'k-')
plt.axvline(result2['t0'].value)


plt.xlim(result2['t0'].value-dtt, result2['t0'].value+dtt)
plt.gca().invert_yaxis()
fig = plt.gcf()
fig.set_size_inches(12.0,10.0)
#fig.savefig('Trapezoid_FFP.png')
# Out:
# 0.0006430619940296367

# %%
# Path to the larger dataset
home = os.path.expanduser("~")

temp = home+'/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/'#lc/'
direc = os.listdir(temp)

# %%
#Fitting Cauchy to Data Challenge light curves


direc.sort()
result = {'name':[], 't0_bell':[], 'tE_bell':[], 'b_bell':[],'amp_bell':[],
          'chisqr_bell':[],'chisqr_bell_err':[], 'chisqr_bell_top':[], 't0_PSPL':[], 'tE_PSPL':[],
          'u0_PSPL':[],'fs_PSPL':[], 'base_PSPL':[], 'chisqr_PSPL':[],'chisqr_PSPL_err':[],'chisqr_PSPL_top': [],
          'xdata': [], 'ydata': [], 'yerr': [], 'event': []}
c = 0 

for f in tqdm(direc):
    #print f
    
    if  f.endswith('.W149') and f.startswith('mag.'):
        
        
#         print c
        c = c +1
        
        try:
            t,m,e = np.loadtxt(temp+str(f),unpack=True, usecols=(0,1, 2))


            

            df, baseline, event, result1, result2, chisqr_bell, chisqr_bell_err, chisqr_PSPL, chisqr_PSPL_err, chisqr_bell_top, chisqr_PSPL_top  = Calculate_PSPL_minus_Cauchy(t, m, e)
           
        
            result['name'].append(f)
            result['t0_bell'].append(result1['t0'].value)
            result['tE_bell'].append(result1['tE'].value)
            result['b_bell'].append(result1['b'].value)
            result['amp_bell'].append(result1['amp'].value)
            result['chisqr_bell'].append(chisqr_bell)
            result['chisqr_bell_err'].append(chisqr_bell_err)
            result['chisqr_bell_top'].append(chisqr_bell_top)
            result['t0_PSPL'].append(result2['t0'].value)
            result['tE_PSPL'].append(result2['tE'].value)
            result['u0_PSPL'].append(result2['u0'].value)
            result['fs_PSPL'].append(result2['fs'].value)
            result['base_PSPL'].append(result2['base'].value)
            result['chisqr_PSPL'].append(chisqr_PSPL)
            result['chisqr_PSPL_err'].append(chisqr_PSPL_err)
            result['chisqr_PSPL_top'].append(chisqr_PSPL_top)
            result['xdata'].append(t)
            result['ydata'].append(m)
            result['yerr'].append(e)
            
            
        except (RuntimeError, TypeError, NameError, ValueError):
            traceback.print_exc()
            pass
#     if c == 4:
#         break

print 'done'
# Out:
#  58%|█████▊    | 5726/9948 [4:53:21<3:36:18,  3.07s/it]Traceback (most recent call last):
#   File "<ipython-input-71-f7b6ec9afa33>", line 26, in <module>
#     df, baseline, event, result1, result2, chisqr_bell, chisqr_bell_err, chisqr_PSPL, chisqr_PSPL_err, chisqr_bell_top, chisqr_PSPL_top  = Calculate_PSPL_minus_Cauchy(t, m, e)
#   File "<ipython-input-16-a1d134944d3d>", line 59, in Calculate_PSPL_minus_Cauchy
#     res2 = minimize(PSPL_data, params2, args=(df['t'].values, df['magnitude'].values))
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 2300, in minimize
#     return fitter.minimize(method=method)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 1949, in minimize
#     return function(**kwargs)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 1492, in leastsq
#     lsout = scipy_leastsq(self.__residual, variables, **lskws)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/minpack.py", line 384, in leastsq
#     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/minpack.py", line 26, in _check_func
#     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 538, in __residual
#     nan_policy=self.nan_policy)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 2166, in _nan_policy
#     raise ValueError("The input contains nan values")
# ValueError: The input contains nan values
#  62%|██████▏   | 6154/9948 [5:03:53<3:07:20,  2.96s/it]Traceback (most recent call last):
#   File "<ipython-input-71-f7b6ec9afa33>", line 26, in <module>
#     df, baseline, event, result1, result2, chisqr_bell, chisqr_bell_err, chisqr_PSPL, chisqr_PSPL_err, chisqr_bell_top, chisqr_PSPL_top  = Calculate_PSPL_minus_Cauchy(t, m, e)
#   File "<ipython-input-16-a1d134944d3d>", line 59, in Calculate_PSPL_minus_Cauchy
#     res2 = minimize(PSPL_data, params2, args=(df['t'].values, df['magnitude'].values))
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 2300, in minimize
#     return fitter.minimize(method=method)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 1949, in minimize
#     return function(**kwargs)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 1492, in leastsq
#     lsout = scipy_leastsq(self.__residual, variables, **lskws)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/minpack.py", line 384, in leastsq
#     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/minpack.py", line 26, in _check_func
#     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 538, in __residual
#     nan_policy=self.nan_policy)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 2166, in _nan_policy
#     raise ValueError("The input contains nan values")
# ValueError: The input contains nan values
# 100%|██████████| 9948/9948 [6:27:34<00:00,  2.34s/it]
# done

# %%
plt.plot(result['b_bell'])

# %%
info1 = pd.read_csv('ombin.CSV')
info2 = pd.read_csv('omcassan.CSV')
info3 = pd.read_csv('dccv.CSV')
info4 = pd.read_csv('dcnormffp.CSV')

# %%
np.sum((df['magnitude']-bellcurve_m)**2)
# Out:
# 2.6656564457172096

# %%
frames = [info1, info2, info3, info4]

info = pd.concat(frames)

# %%
info = info.rename(columns={"index": "name"})

# %%
info = info.reset_index()

# %%
for i in range(len(result['name'])):

    if result['name'][i].split('.lc')[0].endswith('all'): 
        result['name'][i] = result['name'][i].split('all')[0]+'det'+result['name'][i].split('all')[1]

# %%
c = 0
x = info.name
y = result['name']
for j in range(len(x)):
    
    if not x[j] in y:
        info = info.drop([j])
        c = c + 1
print c
# Out:
# 392

# %%
info = info.reset_index()

# %%
info['type'] = np.zeros(len(info))

for i in tqdm(range(len(info))):
    
    if info['name'][i].split('mag')[1].startswith('.ombin'):
        
        info.set_value(i, 'type', 1)
        
    if info['name'][i].split('mag')[1].startswith('.dccv'):
        
        info.set_value(i, 'type', 0)
        
    if info['name'][i].split('mag')[1].startswith('.dcnormffp'):
        
        info.set_value(i, 'type', 3)
        
    if info['name'][i].split('mag')[1].startswith('.omcassan'):
        
        info.set_value(i, 'type', 2)
# Out:
#   0%|          | 0/4378 [00:00<?, ?it/s]/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/ipykernel/__main__.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#  32%|███▏      | 1420/4378 [00:00<00:00, 14190.37it/s]/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/ipykernel/__main__.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/ipykernel/__main__.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#  61%|██████    | 2679/4378 [00:00<00:00, 13388.18it/s]/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/ipykernel/__main__.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# 100%|██████████| 4378/4378 [00:00<00:00, 12923.80it/s]

# %%
info['t0_bell'] = np.zeros(len(info))
info['tE_bell'] = np.zeros(len(info))
info['chisqr_bell'] = np.zeros(len(info))
info['chisqr_bell_err'] = np.zeros(len(info))
info['chisqr_bell_top'] = np.zeros(len(info))
info['b_bell'] = np.zeros(len(info))
info['amp_bell'] = np.zeros(len(info))
info['t0_PSPL'] = np.zeros(len(info))
info['tE_PSPL'] = np.zeros(len(info))
info['u0_PSPL'] = np.zeros(len(info))
info['fs_PSPL'] = np.zeros(len(info))
# info['fb_PSPL'] = np.zeros(len(info))
info['base_PSPL'] = np.zeros(len(info))
info['chisqr_PSPL'] = np.zeros(len(info))
info['chisqr_PSPL_err'] = np.zeros(len(info))
info['chisqr_PSPL_top'] = np.zeros(len(info))





for i in range(len(result['name'])):
    #print i
    
    info.loc[info.name == result['name'][i],'t0_bell'] = result['t0_bell'][i]-2458234
    info.loc[info.name == result['name'][i],'tE_bell'] = result['tE_bell'][i]
    info.loc[info.name == result['name'][i],'b_bell'] = result['b_bell'][i]
    info.loc[info.name == result['name'][i],'amp_bell'] = result['amp_bell'][i]
    info.loc[info.name == result['name'][i], 't0_PSPL'] = result['t0_PSPL'][i]-2458234
    info.loc[info.name == result['name'][i], 'tE_PSPL'] = result['tE_PSPL'][i]
    info.loc[info.name == result['name'][i], 'u0_PSPL'] = result['u0_PSPL'][i]
    info.loc[info.name == result['name'][i], 'fs_PSPL'] = result['fs_PSPL'][i]
#     info.loc[info.name == result['name'][i], 'fb_PSPL'] = result['fb_PSPL'][i].value
    info.loc[info.name == result['name'][i], 'chisqr_bell'] = result['chisqr_bell'][i]
    info.loc[info.name == result['name'][i], 'chisqr_PSPL'] = result['chisqr_PSPL'][i]
    info.loc[info.name == result['name'][i], 'chisqr_PSPL_err'] = result['chisqr_PSPL_err'][i]
    info.loc[info.name == result['name'][i], 'chisqr_PSPL_top'] = result['chisqr_PSPL_top'][i]
    info.loc[info.name == result['name'][i], 'chisqr_bell_err'] = result['chisqr_bell_err'][i]
    info.loc[info.name == result['name'][i], 'chisqr_bell_top'] = result['chisqr_bell_top'][i]



    

print 'done'
# Out:
# done

# %%
info['delta_chisqr_err'] = info.chisqr_PSPL_err - info.chisqr_bell_err

# %%
info['delta_chisqr_top'] = info.chisqr_PSPL_top - info.chisqr_bell_top

# %%
info['delta_chisqr'] = info.chisqr_PSPL - info.chisqr_bell

# %%
# info.to_csv('Cauchy_alllc_results.CSV')

# %%
# info = pd.read_csv('Cauchy_alllc_results.CSV')

# %%
# General format for plotting different parameters versus each other 

fig, axs = plt.subplots(2, 2, sharex=True, sharey=True)

x = 'chisqr_bell_top'
y = 'chisqr_PSPL_top'
c_y = 1
c_x = 1#2.0/(38568-7)

axs[0,0].plot(c_x*(info[x][info['type']==0]).astype(float).abs(),c_y*(info[y][info['type']==0]).astype(float).abs(), '.',markersize=18, label= 'CV',color='r')
axs[0,0].grid()
axs[0,0].legend()
axs[0,1].plot(c_x*(info[x][info['type']==1]).astype(float).abs(),c_y*(info[y][info['type']==1]).astype(float).abs(), '.',markersize=18, label= 'Binary', color='g')
#axs[0,1].plot(c_x*(info[x][info['type']==1]).astype(float).abs(),c_x*(info[x][info['type']==1]).astype(float).abs(), 'r-')
axs[0,1].grid()
axs[0,1].legend()
axs[1,0].plot(c_x*(info[x][info['type']==2]).astype(float).abs(),c_y*(info[y][info['type']==2]).astype(float).abs(), '.',markersize=18, label= 'Planetary',  color = 'orange')
#axs[1,0].plot(c_x*(info[x][info['type']==2]).astype(float).abs(),c_x*(info[x][info['type']==2]).astype(float).abs(), 'g-')
axs[1,0].grid()
axs[1,0].legend()
axs[1,1].plot(c_x*(info[x][info['type']==3]).astype(float).abs(),c_y*(info[y][info['type']==3]).astype(float).abs(), '.',markersize=18, label= 'PSPL/FFP', color='blue')
axs[1,1].plot(c_x*(info[x][info['type']==3]).astype(float).abs(),c_x*(info[x][info['type']==3]).astype(float).abs(), 'r-')
axs[1,1].grid()
axs[1,1].legend()


axs[0, 1].tick_params(axis='x',which='both', bottom='off', top='off',labelbottom='off')
axs[0, 1].tick_params(axis='y',which='both', bottom='right', top='left',labelleft='off',length=0)

axs[0, 0].tick_params(axis='y',which='both', labelsize=12)
axs[1, 0].tick_params(axis='both',which='both', labelsize=12)
axs[1, 1].tick_params(axis='x',which='both', labelsize=12)

plt.yscale('log')
plt.xscale('log')



axs[0, 0].tick_params(axis='x',which='both', bottom='off', top='off',labelbottom='off')
axs[1, 1].tick_params(axis='y',which='both', bottom='right', top='left',labelleft='off', length=0)

xlim = (1e-4,5)
ylim = (0.1,20)

# axs[0,0].set_ylim(ylim)
# axs[0,1].set_ylim(ylim)
# axs[1,0].set_ylim(ylim)
# axs[1,1].set_ylim(ylim)
# axs[0,0].set_xlim(xlim)
# axs[1,0].set_xlim(xlim)
# axs[0,1].set_xlim(xlim)
# axs[1,1].set_xlim(xlim)

plt.subplots_adjust(left=None, bottom=None, right=None, top=None,
                    wspace=0.05, hspace=0.08) 

fig.text(0.5, 0.02, x, ha='center',size=30)
fig.text(0.02, 0.5, y, va='center', rotation='vertical',size=30)

fig = plt.gcf()
fig.set_size_inches(20.0,15.0)
#fig.savefig('a4-a2.png')

# %%
info['delta_chisqr_log_fixed'] = np.sign(info.delta_chisqr)*np.log10(np.abs(info.delta_chisqr))

# %%
x = 'tE_bell'
y = 'delta_chisqr_top'
rho_lim = 0.01

fig, axs = plt.subplots(1, 2, sharex=True, sharey=True)

ttl = axs[0].set_title('$Events \;\; with \;\; {{\chi}^2}_{PSPL} \; - \; {{\chi}^2}_{Cauchy} > 0$', size =32)
ttl.set_position([.5, 1.01])

axs[0].plot(np.abs(info[x][(info.type==3) & (info.delta_chisqr>0) ]), 
         np.abs(info[y][(info.type==3)& (info.delta_chisqr>0) ]), 'b.', markersize = 20, 
            label='All events with ${{\chi}^2}_{PSPL} \; - \; {{\chi}^2}_{Cauchy} > 0$')
axs[0].plot(np.abs(info[x][(info.type==3)  & (info.rho<rho_lim)& (info.delta_chisqr>0)]), 
         np.abs(info[y][(info.type==3) &  (info.rho<rho_lim)& (info.delta_chisqr>0)]), 
            'r.', markersize = 20, label = r'$\rho < 0.01$')

axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[0].set_xticklabels(['', '','${10}^{-3}$','${10}^{-2}$','${10}^{-1}$',
                        '${10}^0$', '${10}^1$', '${10}^2$', ''],
                          rotation = 0, fontsize =25)
axs[0].tick_params(axis='y',which='both', left = True)


axs[0].set_yticklabels(['', '','${10}^{-6}$','${10}^{-5}$','${10}^{-4}$',
                        '${10}^{-3}$', '${10}^{-2}$', '${10}^{-1}$', 
                        '${10}^0$','${10}^1$',''], rotation = 90, fontsize =25)
# axs[0].set_xticks([1e-4, 1e-3, 1e-2, 1e-1,1e0,1e1,1e2, 1e3])
axs[0].grid()
axs[0].legend(loc='lower center', ncol=1, mode="expand",numpoints=1, shadow=True, fancybox=True,prop={'size': 25})

ttl = axs[1].set_title('$Events \;\; with \;\; {{\chi}^2}_{PSPL} \; - \; {{\chi}^2}_{Cauchy} < 0$', size =32)
ttl.set_position([.5, 1.01])

axs[1].plot(np.abs(info[x][(info.type==3) & (info.delta_chisqr<0) ]), 
         np.abs(info[y][(info.type==3)& (info.delta_chisqr<0) ]), 'b.', markersize = 20,
           label='All events with ${{\chi}^2}_{PSPL} \; - \; {{\chi}^2}_{Cauchy} < 0$')
axs[1].plot(np.abs(info[x][(info.type==3)  & (info.rho<rho_lim)& (info.delta_chisqr<0)]), 
         np.abs(info[y][(info.type==3) &  (info.rho<rho_lim)& (info.delta_chisqr<0)]), 
            'r.', markersize = 20, label = r'$\rho < 0.01$')

axs[1].legend(loc='best', ncol=1, mode="expand",numpoints=1, shadow=True, fancybox=True, prop={'size': 25})
axs[1].set_xscale('log')
axs[1].set_yscale('log')

axs[1].set_xticklabels(['','','${10}^{-3}$','${10}^{-2}$','${10}^{-1}$',
                        '${10}^0$', '${10}^1$', '${10}^2$', ''],
                          rotation = 0, fontsize =25)
# axs[0].set_yticklabels(['', '','${10}^{-6}$','${10}^{-5}$','${10}^{-4}$',
#                         '${10}^{-3}$', '${10}^{-2}$', '${10}^{-1}$', 
#                         '${10}^0$','${10}^1$',''], rotation = 0, fontsize =20)
# axs[1].tick_params(axis='both',which='both', labelsize=20)

axs[1].tick_params(axis='y',which='both', left=True,labelleft='off')
axs[1].set_yticklabels(['', '','${10}^{-6}$','${10}^{-5}$','${10}^{-4}$',
                        '${10}^{-3}$', '${10}^{-2}$', '${10}^{-1}$', 
                        '${10}^0$','${10}^1$',''], rotation = 90, fontsize =25)
axs[1].grid()
plt.subplots_adjust(left=None, bottom=0.08, right=None, top=None,
                    wspace=0.0, hspace=0.5) 

fig.text(0.5, 0.02, '$Estimated \;\; t_E$', ha='center',size=35)
fig.text(0.02, 0.5, '${{\chi}^2}_{PSPL} \; - \; {{\chi}^2}_{Cauchy}$', va='center', rotation='vertical',size=35)
fig = plt.gcf()
fig.set_size_inches(20.0,15.0)
fig.savefig('Cauchy_delta_chi_versus_tE.png')

# %%
info[['name', 't0', 't0_PSPL', 't0_bell', 'delta_chisqr', 'tE','rho']][(info.type==3) & (info.b_bell <2)]
# Out:
#                                      name           t0      t0_PSPL  \
# 2737     mag.dcnormffp_0_82_2.det.lc.W149   484.187275   484.194633
# 2738     mag.dcnormffp_0_82_3.det.lc.W149  1774.010804  1774.011262
# 2739     mag.dcnormffp_0_82_4.det.lc.W149  1593.232339  1593.234215
# 2740     mag.dcnormffp_0_82_5.det.lc.W149  1396.736013  1396.674763
# 2741     mag.dcnormffp_0_82_6.det.lc.W149  1601.832206  1601.831449
# 2742     mag.dcnormffp_0_82_7.det.lc.W149  1419.633569  1419.633401
# 2743    mag.dcnormffp_0_82_10.det.lc.W149  1398.030151  1397.982083
# 2744    mag.dcnormffp_0_82_11.det.lc.W149   529.053655   528.280655
# 2745    mag.dcnormffp_0_82_12.det.lc.W149   148.625558   148.612614
# 2746    mag.dcnormffp_0_82_13.det.lc.W149  1790.829316  1790.817413
# 2747    mag.dcnormffp_0_82_14.det.lc.W149  1628.730780  1628.731182
# 2748    mag.dcnormffp_0_82_15.det.lc.W149  1626.389784  1626.348564
# 2749    mag.dcnormffp_0_82_18.det.lc.W149   148.480339   148.478513
# 2750    mag.dcnormffp_0_82_19.det.lc.W149  1809.280416  1809.281979
# 2751    mag.dcnormffp_0_82_20.det.lc.W149  1392.635915  1392.637006
# 2752    mag.dcnormffp_0_82_21.det.lc.W149   523.527394   523.527753
# 2753    mag.dcnormffp_0_82_22.det.lc.W149  1770.752698  1770.752484
# 2754    mag.dcnormffp_0_82_23.det.lc.W149  1814.833993  1814.834453
# 2755    mag.dcnormffp_0_82_24.det.lc.W149   313.939460   313.940203
# 2756    mag.dcnormffp_0_82_25.det.lc.W149  1796.998932  1796.995336
# 2757    mag.dcnormffp_0_82_26.det.lc.W149  1395.860835  1395.861089
# 2758    mag.dcnormffp_0_82_27.det.lc.W149   295.899232   295.899579
# 2759    mag.dcnormffp_0_82_28.det.lc.W149   326.977006   326.972169
# 2760    mag.dcnormffp_0_82_29.det.lc.W149   297.212059   297.209890
# 2761    mag.dcnormffp_0_82_30.det.lc.W149  1429.963185  1429.963208
# 2762    mag.dcnormffp_0_82_31.det.lc.W149  1781.291973  1781.302537
# 2763    mag.dcnormffp_0_82_32.det.lc.W149   362.510101   362.508517
# 2764    mag.dcnormffp_0_82_33.det.lc.W149   176.718097   176.727463
# 2765    mag.dcnormffp_0_82_34.det.lc.W149   502.038749   502.040910
# 2766    mag.dcnormffp_0_82_36.det.lc.W149  1399.310271  1399.255909
# ...                                   ...          ...          ...
# 4347  mag.dcnormffp_0_82_1961.det.lc.W149  1615.574357  1615.584032
# 4348  mag.dcnormffp_0_82_1962.det.lc.W149  1804.285133  1804.287579
# 4349  mag.dcnormffp_0_82_1963.det.lc.W149   160.318873   160.319764
# 4350  mag.dcnormffp_0_82_1964.det.lc.W149  1812.744108  1812.744435
# 4351  mag.dcnormffp_0_82_1965.det.lc.W149   490.206565   490.206578
# 4352  mag.dcnormffp_0_82_1966.det.lc.W149   295.323448   295.330164
# 4353  mag.dcnormffp_0_82_1967.det.lc.W149  1420.482749  1420.469342
# 4354  mag.dcnormffp_0_82_1968.det.lc.W149   532.945351   532.945178
# 4355  mag.dcnormffp_0_82_1970.det.lc.W149   306.743772   306.735019
# 4356  mag.dcnormffp_0_82_1971.det.lc.W149  1810.651588  1810.651945
# 4357  mag.dcnormffp_0_82_1972.det.lc.W149  1628.782176  1628.781263
# 4358  mag.dcnormffp_0_82_1973.det.lc.W149  1415.960577  1415.960158
# 4359  mag.dcnormffp_0_82_1974.det.lc.W149   521.438228   521.220756
# 4360  mag.dcnormffp_0_82_1976.det.lc.W149  1392.393789  1392.420194
# 4361  mag.dcnormffp_0_82_1977.det.lc.W149   527.998050   527.994371
# 4362  mag.dcnormffp_0_82_1978.det.lc.W149  1800.686540  1800.671264
# 4363  mag.dcnormffp_0_82_1979.det.lc.W149   512.093592   512.046242
# 4364  mag.dcnormffp_0_82_1980.det.lc.W149   325.336631   325.337411
# 4365  mag.dcnormffp_0_82_1983.det.lc.W149  1792.786456  1792.786430
# 4366  mag.dcnormffp_0_82_1985.det.lc.W149   362.037499   362.044377
# 4367  mag.dcnormffp_0_82_1986.det.lc.W149   500.479064   500.479133
# 4369  mag.dcnormffp_0_82_1988.det.lc.W149  1781.098248  1781.098238
# 4370  mag.dcnormffp_0_82_1989.det.lc.W149   503.113763   503.113371
# 4371  mag.dcnormffp_0_82_1991.det.lc.W149  1797.286584  1797.286386
# 4372  mag.dcnormffp_0_82_1992.det.lc.W149  1459.424874  1459.437809
# 4373  mag.dcnormffp_0_82_1994.det.lc.W149  1614.865828  1614.847775
# 4374  mag.dcnormffp_0_82_1996.det.lc.W149  1422.853097  1422.850067
# 4375  mag.dcnormffp_0_82_1997.det.lc.W149  1598.501138  1598.331012
# 4376  mag.dcnormffp_0_82_1998.det.lc.W149   485.569050   485.575156
# 4377  mag.dcnormffp_0_82_1999.det.lc.W149  1766.094786  1766.148455
#
#           t0_bell  delta_chisqr         tE       rho
# 2737   484.193399     -0.000071   0.591330  0.045620
# 2738  1774.011481     -0.002328   0.153560  0.255900
# 2739  1593.234230     -0.001009   0.366821  0.019235
# 2740  1396.674595     -0.000972   0.865141  0.029177
# 2741  1601.830928     -0.044567   1.005480  0.048696
# 2742  1419.633964     -0.003579   0.378760  0.058220
# 2743  1397.978889     -0.004499   3.778110  0.005349
# 2744   528.156114     -0.205685  28.938700  0.006025
# 2745   148.612355     -0.001509   6.815700  0.002209
# 2746  1790.817153     -0.010073   2.505870  0.005931
# 2747  1628.732223     -0.001867   4.540960  0.001448
# 2748  1626.347256     -0.000595   1.449490  0.002066
# 2749   148.479536     -0.047794   3.935900  0.001097
# 2750  1809.282689     -0.095581   9.639280  0.000831
# 2751  1392.636777     -0.000044   0.049625  0.166729
# 2752   523.527911     -0.004003   0.144267  0.359628
# 2753  1770.752441     -0.004073   0.042794  0.214925
# 2754  1814.834326     -0.000664   0.273165  0.034087
# 2755   313.940249     -0.000115   0.040370  0.453858
# 2756  1796.994446      0.000034   0.232677  0.031232
# 2757  1395.861413     -0.002208   0.333861  0.038566
# 2758   295.899921     -0.002757   0.493913  0.052816
# 2759   326.971580      0.000963   0.859044  0.024295
# 2760   297.207872     -0.000532   0.770687  0.017927
# 2761  1429.963767     -0.005683   0.362145  0.084669
# 2762  1781.302001     -0.005407   1.829200  0.004605
# 2763   362.508035     -0.006453   2.250570  0.008287
# 2764   176.687221     -0.026810   8.007170  0.008182
# 2765   502.040830     -0.521945   5.463750  0.013423
# 2766  1399.241863     -0.000622  13.090000  0.000354
# ...           ...           ...        ...       ...
# 4347  1615.582986     -0.000244   0.245094  0.053928
# 4348  1804.287780      0.000643   0.458513  0.147262
# 4349   160.320016     -0.001463   0.169163  0.178465
# 4350  1812.744694     -0.006496   2.169310  0.059628
# 4351   490.206711     -0.001311   0.119990  0.093210
# 4352   295.329716      0.000020   0.372328  0.013263
# 4353  1420.468596     -0.000842   0.830554  0.011059
# 4354   532.945314     -0.004967   0.464325  0.087336
# 4355   306.735531     -0.000052   1.285930  0.010601
# 4356  1810.652368     -0.026134   2.034570  0.007476
# 4357  1628.781465     -0.038796   2.033750  0.005125
# 4358  1415.959983     -0.065355   1.132250  0.005830
# 4359   521.227689     -0.000031   7.858710  0.001545
# 4360  1392.418400     -0.000900   3.981620  0.001523
# 4361   527.994995     -0.007267   5.165490  0.000730
# 4362  1800.676157     -0.041792  11.575100  0.001313
# 4363   512.044320      0.000287   2.692880  0.003068
# 4364   325.337358     -0.003409   0.031120  0.100052
# 4365  1792.786466     -0.062602   0.321264  0.053476
# 4366   362.044449     -0.000035   0.236773  0.020521
# 4367   500.479221     -0.023770   0.395186  0.041922
# 4369  1781.098205     -0.026467   0.636537  0.015760
# 4370   503.113615     -0.093157   0.799488  0.015306
# 4371  1797.286415     -0.002682   0.512019  0.012948
# 4372  1459.428681     -0.001381   1.142490  0.013083
# 4373  1614.847520     -0.000013   3.064980  0.004412
# 4374  1422.852859     -0.003569  10.204400  0.001167
# 4375  1598.310326     -0.007526  18.598700  0.000774
# 4376   485.574782     -0.000527   1.535950  0.025987
# 4377  1766.243700     -0.293220  24.908200  0.000632
#
# [1587 rows x 7 columns]

# %%
x = 'rho'
y = 'delta_chisqr_top'
z_lim = 0.1
z = 'tE_bell'

fig, axs = plt.subplots(2, 1, sharex=True)

# ttl = axs[0].set_title('$Events \;\; with \;\; {{\chi}^2}_{PSPL} \; - \; {{\chi}^2}_{Cauchy} > 0$', size =32)
# ttl.set_position([.25, 0.92])

axs[0].plot(np.abs(info[x][(info.type==3) & (info.delta_chisqr>0) ]), 
         np.abs(info[y][(info.type==3)& (info.delta_chisqr>0) ]), 'b.', markersize = 20, 
            label='$All$')
axs[0].plot(np.abs(info[x][(info.type==3)  & (info[z]<z_lim)& (info.delta_chisqr>0)]), 
         np.abs(info[y][(info.type==3) &  (info[z]<z_lim)& (info.delta_chisqr>0)]), 
            'g.', markersize = 20, label = '${t_E}_{fitted} < 1$')
# axs[0].plot(np.abs(info[x][(info.type==3)  & (info[z]<0.05)& (info.delta_chisqr>0)]), 
#          np.abs(info[y][(info.type==3) &  (info[z]<0.05)& (info.delta_chisqr>0)]), 
#             'k.', markersize = 20, label = '${t_E}_{fitted} < 1$')

print float(len(info[x][(info.type==3)  & (info['rho']>0.01)& (info.delta_chisqr>0)]))/ float(len(info[x][(info.type==3) & (info.delta_chisqr>0) ]))
print float(len(info[x][(info.type==3)  & (info[z]<z_lim)& (info.delta_chisqr>0)]))/ float(len(info[x][(info.type==3) & (info.delta_chisqr>0) ]))


axs[0].set_xscale('log')
axs[0].set_yscale('log')
# axs[0].set_xticklabels(['', '','${10}^{-3}$','${10}^{-2}$','${10}^{-1}$',
#                         '${10}^0$', '${10}^1$', '${10}^2$', ''],
#                           rotation = 0, fontsize =25)
# axs[0].tick_params(axis='y',which='both', left = True)


axs[0].set_yticklabels(['', '','${10}^{-6}$','${10}^{-5}$','${10}^{-4}$',
                        '${10}^{-3}$', '${10}^{-2}$', '${10}^{-1}$', 
                        '$1$', ''], rotation = 0, fontsize =25)
# # axs[0].set_xticks([1e-4, 1e-3, 1e-2, 1e-1,1e0,1e1,1e2, 1e3])
axs[0].grid()
axs[0].legend(loc='lower right', ncol=1,numpoints=1, shadow=True, fancybox=True,prop={'size': 25})

# ttl = axs[1].set_title('$Events \;\; with \;\; {{\chi}^2}_{PSPL} \; - \; {{\chi}^2}_{Cauchy} < 0$', size =32)
# ttl.set_position([.5, 1.01])

axs[1].plot(np.abs(info[x][(info.type==3) & (info.delta_chisqr<0) ]), 
         np.abs(info[y][(info.type==3)& (info.delta_chisqr<0) ]), 'b.', markersize = 20,
           label='$All$')
axs[1].plot(np.abs(info[x][(info.type==3)  & (info[z]<z_lim)& (info.delta_chisqr<0)]), 
         np.abs(info[y][(info.type==3) &  (info[z]<z_lim)& (info.delta_chisqr<0)]), 
            'g.', markersize = 20, label = '${t_E}_{fitted} < 1$')
# axs[1].plot(np.abs(info[x][(info.type==3)  & (info[z]<0.05)& (info.delta_chisqr<0)]), 
#          np.abs(info[y][(info.type==3) &  (info[z]<0.05)& (info.delta_chisqr<0)]), 
#             'k.', markersize = 20, label = '${t_E}_{fitted} < 1$')

axs[1].legend(loc='lower right', ncol=1,numpoints=1, shadow=True, fancybox=True, prop={'size': 25})

axs[1].set_xscale('log')
axs[1].set_yscale('log')
# axs[1].set_ylim(0.01,10)
axs[1].invert_yaxis()
# axs[1].set_xticklabels(['','${10}^{-4}$', '${10}^{-3}$','${10}^{-2}$','${10}^{-1}$',
#                         '$1$'],
#                           rotation = 0, fontsize =25)
axs[1].set_yticklabels(['', '0','$-{10}^{-6}$','$-{10}^{-5}$','$-{10}^{-4}$',
                        '$-{10}^{-3}$', '$-{10}^{-2}$', '$-{10}^{-1}$', 
                        '$-1$','$-{10}$',''], rotation = 0, fontsize =25)
# axs[1].set_xlim(1e-4, 5)
axs[1].grid()

print float(len(info[x][(info.type==3)  & (info['rho']>0.01)& (info.delta_chisqr<0)]))/ float(len(info[x][(info.type==3) & (info.delta_chisqr<0) ]))
print float(len(info[x][(info.type==3)  & (info[z]<z_lim)& (info.delta_chisqr<0)]))/ float(len(info[x][(info.type==3) & (info.delta_chisqr<0) ]))


plt.subplots_adjust(left=None, bottom=0.08, right=None, top=None,
                    wspace=0.0, hspace=0.0) 

fig.text(0.5, 0.02, r'$\rho$', ha='center',size=35)
fig.text(0.02, 0.5, '${{\chi}^2}_{PSPL} \; - \; {{\chi}^2}_{Cauchy}$', va='center', rotation='vertical',size=35)
fig = plt.gcf()
fig.set_size_inches(20.0,15.0)
#fig.savefig('Cauchy_delta_chi_rho.png')
# Out:
# 0.822085889571
# 0.546012269939
# 0.517917511832
# 0.228532792427

# %%
info[['rho']][(info.type==3) & (np.abs(info.t0-info.t0_bell)<5) & (info.delta_chisqr>0.1)]
# Out:
# 2994    1.761050
# 3057    0.289979
# 3076    0.015132
# 3175    0.614271
# 3315    0.345893
# 3334    0.131479
# 3419    0.875754
# 3431    0.000988
# 3491    0.744704
# 3870    0.313108
# 4189    0.431772
# Name: rho, dtype: float64

# %%
plt.plot(info['rho'][(info.type==3) & (np.abs(info.t0-info.t0_bell)<5)& (info.b_bell<2)], 
         info['b_bell'][(info.type==3) &(np.abs(info.t0-info.t0_bell)<5)& (info.b_bell<2)], 'b.', markersize=25)
plt.plot(info['rho'][(info.type==3) & (np.abs(info.t0-info.t0_bell)<5)& (info.b_bell>2) & (info.rho>1)], 
         info['b_bell'][(info.type==3) &(np.abs(info.t0-info.t0_bell)<5)& (info.b_bell>2)& (info.rho>1)], 'b.', markersize=25)
plt.xscale('log')
# plt.yscale('log')

plt.xlabel(r'$\rho$',size = 40)
plt.ylabel('b Value', size= 35)
plt.ylim(0.4, 4)

plt.grid()
ax = plt.gca()
ax.set_yticklabels(['',0.5,1,1.5,2,2.5,3,3.5,4], rotation = 90, fontsize = 30)
ax.set_xticklabels(['','', 0.001, 0.01, 0.1, 1, 10], rotation = 0, fontsize = 30)



fig = plt.gcf()
fig.set_size_inches(20.0,15.0)
# fig.savefig('b_vs_rho.png')

# %%
info[['name', 't0', 't0_bell', 'tE', 'tE_bell', 'rho', 'b_bell']][(info.type==3) &(np.abs(info.t0-info.t0_bell)<5)& (info.b_bell >2) & (info.rho<0.3)]
# Out:
#                                      name           t0      t0_bell  \
# 3076   mag.dcnormffp_0_82_427.det.lc.W149  1404.483705  1408.013695
# 3669  mag.dcnormffp_0_82_1146.det.lc.W149  1753.373017  1753.094549
#
#              tE    tE_bell       rho    b_bell
# 3076  24.160900  23.503416  0.015132  2.075478
# 3669   0.580561   0.803907  0.010286  2.644890

# %% [markdown]
# # In the following cells, I have selected a few of the wrong results and repeated the fitting process for them.

# %%
temp_info = (info[(info.type==3) & ((info.t0-info.t0_bell)<10) & (info.b_bell>2) &(info.rho>0.01)])

# %%
for f in temp_info.name:
    
    t,m,e = np.loadtxt(temp+str(f),unpack=True, usecols=(0,1, 2))

    f, baseline, event, result1, result2, chisqr_bell, chisqr_bell_err, chisqr_PSPL, chisqr_PSPL_err  = Calculate_PSPL_minus_Cauchy(t, m, e)
# Out:
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_1.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_100.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_161.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_180.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_201.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_323.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_343.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_400.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_427.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_581.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_641.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_820.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_843.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_848.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_987.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_1060.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_1103.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_1122.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_1146.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_1420.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_1601.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_1704.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_1743.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_1800.det.lc.W149
# /Users/Research/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/mag.dcnormffp_0_82_1921.det.lc.W149

# %%
for i in range(len(result['name'])):
    info.loc[info.name == result['name'][i], 'b_bell'] = result['b_bell'][i]
