# %%
from Common_functions import  *

# %matplotlib inline

# %%
import glob,os,sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from numpy import *
import re
from tqdm import tqdm
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
import scipy.stats as st
from os.path import expanduser
import cmath
from scipy import optimize
import time
import gzip
from scipy.interpolate import interp1d
import pandas as pd
from scipy.interpolate import interp1d
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import (mark_inset,inset_axes,InsetPosition) 
import traceback
from lmfit import minimize, Parameters, Parameter, report_fit
import matplotlib.patches as patches
from sympy.solvers import solve
from sympy import Symbol
import sympy


# %matplotlib inline
home = os.path.expanduser("~")

# %%
def med_med (true,fitted):
    temp = fitted - true
    return (np.median(np.abs(temp-np.median(temp))))

# %%
def cal_chisqr(model, fx, ferr):
    
    
    return np.sum(((fx-model)**2)/((ferr)**2))

# %%
# def PSPL_data (params, t, m_data):
    
#     t0 = params['t0'].value
#     tE = params['tE'].value
#     u0 = params['u0'].value
#     base = params['base'].value
#     fs = params['fs'].value
# #     fb = params['fb'].value

#     u = np.sqrt(u0**2+((t-t0)/tE)**2)
#     A = ((u**2)+2)/(u*np.sqrt(u**2+4))
#     F = (fs * (A-1)) +1
#     fx = base*np.ones(len(t)) + (-2.5 * np.log10(F))
#     return fx - m_data

# def PSPL (t0, tE, u0, base,fs, t):
    
#     u = np.sqrt(u0**2+((t-t0)/tE)**2)
#     A = ((u**2)+2)/(u*np.sqrt(u**2+4))
#     F = (fs * (A-1)) +1
#     fx = base*np.ones(len(t)) + (-2.5 * np.log10(F))
#     return fx

# %%
def Calculate_PSPL_minus_Cauchy (t, m, e):
    
    
    
    lightcurve = np.zeros((len(t),4))
    lightcurve[:,0] = t
    lightcurve[:,1] = m
    lightcurve[:,2] = e
    peak = t[np.argmin(m)]

    df, baseline, event, it0, dt = prepare(t,m,e)

    A_max = df['A'][np.argmin(m[m>np.percentile(m, [0.0,100])[0]])] #np.max(df['A']) #1.0/(float(f_s_true)/(max(df['f'])-1+float(f_s_true)))
    u0_true = np.sqrt( ( (1+np.sqrt(1+16*(A_max**2)))/(2* A_max) ) - 2 )
    t0_true =  df['t'][np.argmin(m[m>np.percentile(m, [0.0,100])[0]])] #it0 #t[A.argmax()] #float(t0_theo)
    amp_ini = np.median(lightcurve[baseline,1]) - lightcurve[it0,1]
    tE_true = [0.01, 0.1, 1.0, 10.0, 100]
    
    #################################
    
    temp_PSPL = [[], []]
    for tE in tE_true:

        params2 = Parameters()
        params2.add('t0', value= t0_true, min=min(df['t']), max=max(df['t']))
        params2.add('tE', value= tE, min=0.001, max=1000)
        params2.add('u0', value= u0_true, min=0, max=5)
        params2.add('base', value= np.median(lightcurve[baseline,1]), min=max((lightcurve[baseline,1])), max=min((lightcurve[baseline,1])))
        params2.add('fs', value= 1, min=0, max=1)
#             params2.add('fb', value= 0.5, min=0, max=1)


        res2 = minimize(PSPL_data, params2, args=(df['t'].values, df['magnitude'].values))

        temp_PSPL[0].append(res2.params)
        temp_PSPL[1].append(res2.chisqr)

    result2 = temp_PSPL[0][np.argmin(temp_PSPL[1])]

    PSPL_m = PSPL(result2['t0'], result2['tE'], result2['u0'],
                  result2['base'], result2['fs'] , df['t'])
    #PSPL_m = base*np.ones(len(PSPL_A)) + (-2.5 * np.log10(PSPL_A))
    
    c = result2['tE']*result2['u0']
#     m_top_temp = df['magnitude'][(df.t < result2['t0'] + c) & (df.t > result2['t0'] - c)]
    
#     while (len(m_top_temp)<5):
        
#         c = c*2
#         m_top_temp = df['magnitude'][(df.t < result2['t0'] + c) & (df.t > result2['t0'] - c)]
        

    m_top = df['magnitude'][(df.t < result2['t0'] + c) & (df.t > result2['t0'] - c)]
    model_top = PSPL_m[(df.t < result2['t0'] + c) & (df.t > result2['t0'] - c)]
    m_err_top = df['m_err'][(df.t < result2['t0'] + c) & (df.t > result2['t0'] - c)]

    chisqr_PSPL = np.sum((df['magnitude'].values-PSPL_m)**2)

    chisqr_PSPL_err = cal_chisqr(PSPL_m, df['magnitude'].values, df['m_err'].values)
    chisqr_PSPL_top = cal_chisqr(model_top, m_top.values, m_err_top.values)
    chisqr_PSPL_top_reduced = chisqr_PSPL_top/len(model_top)
    
    ##################################
    temp_bell = [[], []]
    for tE in tE_true:

        params = Parameters()
        params.add('t0', value= t0_true, min=min(df['t']), max=max(df['t']))
        params.add('tE', value= tE, min=0.0001, max=1000)
        params.add('b', value= 1, min=0, max=20)
        params.add('amp', value= amp_ini, min=0, max=20)


        res1 = minimize(bell_curve_data, params, args=(df['t'].values, -lightcurve[:,1]+np.median(lightcurve[baseline,1])))
        temp_bell[0].append(res1.params)
        temp_bell[1].append(res1.chisqr)
        
    result1 = temp_bell[0][np.argmin(temp_bell[1])]

    bellcurve_m = np.median(lightcurve[baseline,1])-bell_curve(t, result1['t0'], result1['tE'] , 
                                                                  result1['b'], result1['amp'])

    #print bellcurve_m
    m_top = df['magnitude'][(df.t < result2['t0'] + c) & (df.t > result2['t0'] - c)]
    model_top = bellcurve_m[(df.t < result2['t0'] + c) & (df.t > result2['t0'] - c)]
    m_err_top = df['m_err'][(df.t < result2['t0'] + c) & (df.t > result2['t0'] - c)]
    
    chisqr_bell = np.sum((df['magnitude'].values-bellcurve_m)**2)
    chisqr_bell_err = cal_chisqr(bellcurve_m, df['magnitude'].values, df['m_err'].values)
    chisqr_bell_top = cal_chisqr(model_top, m_top.values, m_err_top.values)
    chisqr_bell_top_reduced = chisqr_bell_top/(len(model_top))
    
    #################################
    
    return df, baseline, event, result1, result2, chisqr_bell, chisqr_bell_err, chisqr_PSPL,\
            chisqr_PSPL_err, chisqr_bell_top, chisqr_PSPL_top, chisqr_bell_top_reduced, chisqr_PSPL_top_reduced

# %%
def Calculate_PSPL_minus_Cauchy (t, m, e):
    
    
    
    lightcurve = np.zeros((len(t),4))
    lightcurve[:,0] = t
    lightcurve[:,1] = m
    lightcurve[:,2] = e
    peak = t[np.argmin(m)]

    df, baseline, event, it0, dt = prepare(t,m,e)
    
    
    A_max = df['A'][np.argmin(m[m>np.percentile(m, [0.0,100])[0]])] #np.max(df['A']) #1.0/(float(f_s_true)/(max(df['f'])-1+float(f_s_true)))
    u0_true = np.sqrt( ( (1+np.sqrt(1+16*(A_max**2)))/(2* A_max) ) - 2 )
    t0_true =  df['t'][np.argmin(m[m>np.percentile(m, [0.0,100])[0]])] #it0 #t[A.argmax()] #float(t0_theo)
    amp_ini =  df.A[it0] - np.median(df.A[baseline])
    tE_true = [0.01, 0.1, 1.0, 10.0, 100]
    
    #################################
    
    temp_PSPL = [[], []]
    for tE in tE_true:
        
        nll = lambda *args: -lnlike(*args)
        res_scipy = op.minimize(nll, [t0_true,tE, u0_true, 0.5], args=(df['t'],df['A'], df['A_err']),method = 'Nelder-Mead')
        t0_ml, tE_ml, u0_ml,fs_ml = res_scipy['x']
        PSPL_params = [t0_ml, tE_ml, u0_ml,fs_ml]

        temp_PSPL[0].append(PSPL_params) #(res2.params)
        temp_PSPL[1].append(cal_chisqr(PSPL(t0_ml, tE_ml, u0_ml,fs_ml, df['t']), df['A'], df['A_err'])) #(res2.chisqr)

    result2 = temp_PSPL[0][np.argmin(temp_PSPL[1])]

    PSPL_A = PSPL(result2[0], result2[1], result2[2], result2[3], df['t']) 
    
    c = result2[1]*result2[2] 

    A_top = df['A'][(df.t < result2[0] + c) & (df.t > result2[0] - c)]
    model_top = PSPL_m[(df.t < result2[0] + c) & (df.t > result2[0] - c)]
    A_err_top = df['A_err'][(df.t < result2[0] + c) & (df.t > result2[0] - c)]

    chisqr_PSPL = np.sum((df['A'].values-PSPL_A)**2)

    chisqr_PSPL_err = cal_chisqr(PSPL_A, df['A'].values, df['A_err'].values)
    chisqr_PSPL_top = cal_chisqr(model_top, A_top.values, A_err_top.values)
    chisqr_PSPL_top_reduced = chisqr_PSPL_top/len(model_top-5)
    
    ##################################
    temp_bell = [[], []]
#     for tE in tE_true:

    params = Parameters()
    params.add('t0', value= result2[0], min=min(df['t']), max=max(df['t']))
    params.add('tE', value= result2[1], min=0.0001, max=1000)
    params.add('b', value= 1, min=0, max=20)
    params.add('amp', value= amp_ini, min=0, max=20)


    res1 = minimize(bell_curve_data, params, args=(df['t'].values, df.A[it0] - np.median(df.A[baseline])))
    temp_bell[0].append(res1.params)
    temp_bell[1].append(res1.chisqr)
        
    result1 = temp_bell[0][np.argmin(temp_bell[1])]

    bellcurve_m = bell_curve(t, result1['t0'], result1['tE'] ,result1['b'], result1['amp'])+ np.median(df.A[baseline])

    #print bellcurve_m
    A_top = df['A'][(df.t < result2[0] + c) & (df.t > result2[0] - c)]
    model_top = bellcurve_m[(df.t < result2[0] + c) & (df.t > result2[0] - c)]
    A_err_top = df['A_err'][(df.t < result2[0] + c) & (df.t > result2[0] - c)]
    
    chisqr_bell = np.sum((df['A'].values-bellcurve_m)**2)
    chisqr_bell_err = cal_chisqr(bellcurve_m, df['magnitude'].values, df['m_err'].values)
    chisqr_bell_top = cal_chisqr(model_top, A_top.values, A_err_top.values)
    chisqr_bell_top_reduced = chisqr_bell_top/(len(model_top)-5)
    
    #################################
    
    return df, baseline, event, result1, result2, chisqr_bell, chisqr_bell_err, chisqr_PSPL,\
            chisqr_PSPL_err, chisqr_bell_top, chisqr_PSPL_top, chisqr_bell_top_reduced, chisqr_PSPL_top_reduced

# %%
# Plot for the paper = 'mag.dcnormffp_0_82_427.det.lc.W149'
name = 'mag.dcnormffp_0_82_1612.det.lc.W149'
f = home+'/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/'+str(name)
# Testing the fit on an OGLE free-floating candidate with a large value of rho

# f = 'data/OGLE_2012_BLG_0406/phot.dat'
t,m,e = np.loadtxt(f,unpack=True, usecols=(0,1, 2))

F = 100**((np.max(m)-m)/5)

df = pd.DataFrame({'t': t, 'Flux_Ratio': F, 'magnitude': m, 'm_err': e})

# %%
df, baseline, event, it0, dt = prepare(t,m,e)


A_max = df['A'][np.argmin(m[m>np.percentile(m, [0.0,100])[0]])] #np.max(df['A']) #1.0/(float(f_s_true)/(max(df['f'])-1+float(f_s_true)))
print 
u0_true = np.sqrt( ( (1+np.sqrt(1+16*(A_max**2)))/(2* A_max) ) - 2 )
t0_true =  df['t'][np.argmin(m[m>np.percentile(m, [0.0,100])[0]])] #it0 #t[A.argmax()] #float(t0_theo)
amp_ini =  df.A[it0] - np.median(df.A[baseline])
tE_true = [0.01, 0.1, 1.0, 10.0, 100]

# %%
fs_true = 0.4

# %%
u0 = Symbol('u0')
solve_u0 = (solve((2+u0**2)/(u0*sympy.sqrt(4+u0**2))-((A_max-(1-fs_true))/fs_true), u0))

# %%
solve_u0 = np.array(solve_u0[0], dtype=np.float64)

# %%
solve_u0
# Out:
# array(0.52147857)

# %%
dt = 15
plt.plot(df.t, df.A, 'b.')
plt.plot(df.t, PSPL(t0_true, 5, solve_u0, fs_true, df.t),'r-')
plt.xlim(t0_true- dt*2, t0_true+dt*2)
# Out:
# (2458359.602302, 2458419.602302)

# %%
temp_PSPL = [[], []]
for tE in tE_true:

#     nll = lambda *args: -lnlike(*args)
#     res_scipy = op.minimize(nll, [t0_true,tE, solve_u0, fs_true], args=(df['t'],df['A'], df['A_err']),method = 'Nelder-Mead')
#     t0_ml, tE_ml, u0_ml,fs_ml = res_scipy['x']
#     PSPL_params = [t0_ml, tE_ml, u0_ml,fs_ml]

#     temp_PSPL[0].append(PSPL_params) #(res2.params)
#     temp_PSPL[1].append(cal_chisqr(PSPL(t0_ml, tE_ml, u0_ml,fs_ml, df['t']), df['A'], df['A_err'])) #(res2.chisqr)

# result2 = temp_PSPL[0][np.argmin(temp_PSPL[1])]
# print result2

# PSPL_A = PSPL(result2[0], result2[1], result2[2], result2[3], df['t']) 

    params2 = Parameters()
    params2.add('t0', value= t0_true, min=min(df['t']), max=max(df['t']))
    params2.add('tE', value= tE, min=0.001, max=1000)
    params2.add('u0', value= solve_u0, min=0, max=5)
#     params2.add('base', value= np.median(lightcurve[baseline,1]), min=max((lightcurve[baseline,1])), max=min((lightcurve[baseline,1])))
    params2.add('fs', value= fs_true, min=0, max=1)
#             params2.add('fb', value= 0.5, min=0, max=1)


    res2 = minimize(PSPL_data, params2, args=(df['t'].values, df['A'].values))

    temp_PSPL[0].append(res2.params)
    temp_PSPL[1].append(res2.chisqr)

result2 = temp_PSPL[0][np.argmin(temp_PSPL[1])]
print result2

PSPL_A = PSPL(result2['t0'], result2['tE'], result2['u0'], result2['fs'] , df['t'])
# Out:
# Parameters([('t0', <Parameter 't0', value=2458389.8976308624 +/- 0.00913, bounds=[2458346.505461:2460059.241444]>), ('tE', <Parameter 'tE', value=6.111129459464926 +/- 0.267, bounds=[0.001:1000]>), ('u0', <Parameter 'u0', value=0.15804070596469905 +/- 0.00964, bounds=[0:5]>), ('fs', <Parameter 'fs', value=0.07304585190540891 +/- 0.00496, bounds=[0:1]>)])

# %%
dt = 2
plt.plot(df.t, df.A, 'b.')
plt.plot(df.t, PSPL_A, 'r-')
plt.xlim(t0_true- dt*2, t0_true+dt*2)
# Out:
# (2458385.602302, 2458393.602302)

# %%
temp_bell = [[], []]
#     for tE in tE_true:

params = Parameters()
params.add('t0', value= result2['t0'], min=min(df['t']), max=max(df['t']))
params.add('tE', value= result2['tE'], min=0.0001, max=1000)
params.add('b', value= 1, min=0, max=20)
params.add('amp', value= A_max, min=0, max=20)


res1 = minimize(bell_curve_data, params, args=(df['t'].values, df.A ))
temp_bell[0].append(res1.params)
temp_bell[1].append(res1.chisqr)

result1 = temp_bell[0][np.argmin(temp_bell[1])]
print result1
bellcurve_A = bell_curve(df.t, result1['t0'], result1['tE'] ,result1['b'], result1['amp'])
# Out:
# Parameters([('t0', <Parameter 't0', value=2458389.897141399 +/- 0.00926, bounds=[2458346.505461:2460059.241444]>), ('tE', <Parameter 'tE', value=1.4433919131136075 +/- 0.0189, bounds=[0.0001:1000]>), ('b', <Parameter 'b', value=0.9440387729032929 +/- 0.0117, bounds=[0:20]>), ('amp', <Parameter 'amp', value=0.3892303117398699 +/- 0.00304, bounds=[0:20]>)])

# %%
dt = 2
plt.plot(df.t, df.A, 'b.')
plt.plot(df.t, bellcurve_A, 'r-')
plt.xlim(t0_true- dt*2, t0_true+dt*2)
# Out:
# (2458385.602302, 2458393.602302)

# %%
c = result2['tE']*result2['u0']

t_top = df['t'][(df.t < result2['t0'] + c) & (df.t > result2['t0'] - c)]
A_top = df['A'][(df.t < result2['t0'] + c) & (df.t > result2['t0'] - c)]
model_top = PSPL_A[(df.t < result2['t0'] + c) & (df.t > result2['t0'] - c)]
A_err_top = df['A_err'][(df.t < result2['t0'] + c) & (df.t > result2['t0'] - c)]

chisqr_PSPL = np.sum((df['A'].values-PSPL_A)**2)

chisqr_PSPL_err = cal_chisqr(PSPL_A, df['A'].values, df['A_err'].values)
chisqr_PSPL_top = cal_chisqr(model_top, A_top.values, A_err_top.values)
chisqr_PSPL_top_reduced = chisqr_PSPL_top/len(model_top)

# %%
A_top = df['A'][(df.t < result2['t0'] + c) & (df.t > result2['t0'] - c)]
model_top = bellcurve_A[(df.t < result2['t0'] + c) & (df.t > result2['t0'] - c)]
A_err_top = df['A_err'][(df.t < result2['t0'] + c) & (df.t > result2['t0'] - c)]

chisqr_bell = np.sum((df['A'].values-bellcurve_A)**2)
chisqr_bell_err = cal_chisqr(bellcurve_A, df['A'].values, df['A_err'].values)
chisqr_bell_top = cal_chisqr(model_top, A_top.values, A_err_top.values)
chisqr_bell_top_reduced = chisqr_bell_top/(len(model_top))

# %%
print chisqr_PSPL_err, chisqr_bell_err
print chisqr_PSPL_top_reduced, chisqr_bell_top_reduced
# Out:
# 38192.58071325721 38221.52294194477
# 1.0027343728743159 0.9843385216116991

# %%
chisqr_PSPL_top_reduced - chisqr_bell_top_reduced
# Out:
# 0.01839585126261678

# %%
dtt = result2['tE']*result2['u0']                                                        

plt.figure()
plt.title('Fitting Cauchy Distribution PSPL to a Lightcurve', size=25)
plt.xlabel('$t - t_0 (days)$',size=29)
plt.ylabel('$Magnitude$',size=29)
plt.tick_params(axis='y',labelsize=18)
plt.tick_params(axis='x',labelsize=20)
plt.plot(df['t'], df['A'], 'b.', markersize=15)
#print param['t_eff=5']
plt.plot(df['t'], PSPL_A, 'r-')
plt.plot(df['t'], bellcurve_A, 'k-')
plt.axvline(result1['t0'].value)


plt.xlim(result2['t0'].value-dtt, result2['t0'].value+dtt)
# plt.gca().invert_yaxis()
fig = plt.gcf()
fig.set_size_inches(12.0,10.0)
#fig.savefig('Trapezoid_FFP.png')

# %%
df, baseline, event, result1, result2, chisqr_bell, chisqr_bell_err,\
chisqr_PSPL, chisqr_PSPL_err, chisqr_bell_top, chisqr_PSPL_top,\
chisqr_bell_top_reduced, chisqr_PSPL_top_reduced = Calculate_PSPL_minus_Cauchy(t, m, e)

# %%
print chisqr_PSPL_top-chisqr_bell_top
# Out:
# 0.0

# %%
print chisqr_PSPL_top_reduced - chisqr_bell_top_reduced
# Out:
# nan

# %%
result1
# Out:
# Parameters([('t0',
#              <Parameter 't0', value=2458366.100783443 +/- 0.00612, bounds=[2458346.505461:2460059.241444]>),
#             ('tE',
#              <Parameter 'tE', value=7.263249177830848 +/- 0.00212, bounds=[0.0001:1000]>),
#             ('b',
#              <Parameter 'b', value=6.23945339839338e-13 +/- 4.01e-15, bounds=[0:20]>),
#             ('amp',
#              <Parameter 'amp', value=0.08494016426715101 +/- 2.95e-15, bounds=[0:20]>)])

# %%
result2
# Out:
# [2458366.1004325654,
#  0.09540237862562423,
#  -16.546194882398403,
#  10.73813509860798]

# %%
result2['tE']*result2['u0']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1034-a2be54c19bb8> in <module>()
# ----> 1 result2['tE']*result2['u0']
#
# TypeError: list indices must be integers, not str

# %%
dtt = 2*result2['tE']*result2['u0']

PSPL_m = PSPL(result2['t0'],result2['tE'],result2['u0'],
              result2['base'],result2['fs'], df['t'])
bellcurve_m = np.median(df['magnitude'][baseline])-bell_curve(df['t'], result1['t0'].value, 
                                                              result1['tE'].value , result1['b'].value,
                                                              result1['amp'].value)
print chisqr_PSPL - chisqr_bell

plt.figure()
plt.title('Fitting Cauchy Distribution PSPL to a Lightcurve', size=25)
plt.xlabel('$t - t_0 (days)$',size=29)
plt.ylabel('$Magnitude$',size=29)
plt.tick_params(axis='y',labelsize=18)
plt.tick_params(axis='x',labelsize=20)
plt.plot(df['t'], df['magnitude'], 'b.', markersize=15)
#print param['t_eff=5']
plt.plot(df['t'], PSPL_m, 'r-')
plt.plot(df['t'], bellcurve_m, 'k-')
plt.axvline(result1['t0'].value)


plt.xlim(result2['t0'].value-dtt, result2['t0'].value+dtt)
plt.gca().invert_yaxis()
fig = plt.gcf()
fig.set_size_inches(12.0,10.0)
#fig.savefig('Trapezoid_FFP.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-6103f18f02e9> in <module>()
#       2
#       3 PSPL_m = PSPL(result2['t0'],result2['tE'],result2['u0'],
# ----> 4               result2['base'],result2['fs'], df['t'])
#       5 bellcurve_m = np.median(df['magnitude'][baseline])-bell_curve(df['t'], result1['t0'].value,
#       6                                                               result1['tE'].value , result1['b'].value,
#
# KeyError: 'base'

# %%
right = len(t[(t>result1['t0']) & (t<result1['t0']+(result2['tE']*result2['u0']))])
left = len(t[(t<result1['t0']) & (t>result1['t0']-(result2['tE']*result2['u0']))])

# %%
print right, left
# Out:
# 1156 784

# %%
if right == 0 or left==0:
    print 'yes'
# Out:
# yes

# %%
# plt.figure()
# ax = plt.gca()
# peak = result2['t0']
# #plt.title('Fitting Cauchy Distribution PSPL to a Lightcurve', size=25)
# plt.xlabel('$t - t_0 $'+' (days)',size=29)
# plt.ylabel('Magnitude',size=29)
# plt.tick_params(axis='y',labelsize=18)
# plt.tick_params(axis='x',labelsize=20)
# plt.plot(t[event]-peak, m[event], '.', color='#1f78b4', markersize=15, alpha=0.8)
# #ax.set_yticklabels(ax.get_yticklabels(), rotation = 90, fontsize = 22)
# plt.plot(t[event]-peak, PSPL_m[event], '-',color='#e31a1c', linewidth=3, label = 'PSPL Fit')
# plt.plot(t[event]-peak, bellcurve_m[event],'-', color='#ff7f00', linewidth=3, label = 'Cauchy Fit')

# plt.xlim(-25,45)
# plt.gca().invert_yaxis()
# plt.legend(loc = 'upper right' ,prop={'size': 25})

# # inset = plt.axes([0.17, 0.58, 0.3, 0.3])
# # inset.plot(t[event]-peak, m[event], '.', color='gray', markersize=15)
# # inset.plot(t[event]-peak, PSPL_m[event], 'r-', linewidth=1)
# # inset.plot(t[event]-peak, bellcurve_m[event], 'g-', linewidth=1)
# # # inset.set_yticklabels(inset.get_yticklabels(), rotation = 90, fontsize = 22)
# # inset.axes.get_yaxis().set_ticks([18.05,18.0,17.95])
# # #mark_inset(ax, inset, loc1=1, loc2=4, fc="none", ec="0.5")


# #x1, x2, y1, y2 = 

# inset.set_xlim (-0.05,0.05)#(x1,x2)
# inset.set_ylim (20.36,20.30)

# #plt.axvline(PSPL_init_par[0])


# fig = plt.gcf()
# fig.set_size_inches(12.0,10.0)
# # fig.savefig('Cauchy_fit_example.png')

# %%
# Path to the larger dataset
home = os.path.expanduser("~")

temp = home+'/Library/Mobile Documents/com~apple~CloudDocs/Microlensing_Data_Challeng/data-challenge-1/alldclc/'#lc/'
direc = os.listdir(temp)

# %%
#Fitting Cauchy to Data Challenge light curves


direc.sort()
result = {'name':[], 't0_bell':[], 'tE_bell':[], 'b_bell':[],'amp_bell':[],
          'chisqr_bell':[],'chisqr_bell_err':[], 'chisqr_bell_top':[],'chisqr_bell_top_reduced':[], 't0_PSPL':[], 'tE_PSPL':[],
          'u0_PSPL':[],'fs_PSPL':[], 'base_PSPL':[], 'chisqr_PSPL':[],'chisqr_PSPL_err':[],'chisqr_PSPL_top': [], 'chisqr_PSPL_top_reduced': [],
          'xdata': [], 'ydata': [], 'yerr': [], 'event': []}
c = 0 

for f in tqdm(direc):
    #print f
    
    if  f.endswith('.W149') and f.startswith('mag.'):
        
        
#         print c
        c = c +1
        
        try:
            t,m,e = np.loadtxt(temp+str(f),unpack=True, usecols=(0,1, 2))


            

            df, baseline, event, result1, result2, chisqr_bell, chisqr_bell_err, chisqr_PSPL, \
            chisqr_PSPL_err, chisqr_bell_top, chisqr_PSPL_top, chisqr_bell_top_reduced, chisqr_PSPL_top_reduced  = Calculate_PSPL_minus_Cauchy(t, m, e)
           
        
            result['name'].append(f)
            result['t0_bell'].append(result1['t0'].value)
            result['tE_bell'].append(result1['tE'].value)
            result['b_bell'].append(result1['b'].value)
            result['amp_bell'].append(result1['amp'].value)
            result['chisqr_bell'].append(chisqr_bell)
            result['chisqr_bell_err'].append(chisqr_bell_err)
            result['chisqr_bell_top'].append(chisqr_bell_top)
            result['chisqr_bell_top_reduced'].append(chisqr_bell_top_reduced)
            result['t0_PSPL'].append(result2['t0'].value)
            result['tE_PSPL'].append(result2['tE'].value)
            result['u0_PSPL'].append(result2['u0'].value)
            result['fs_PSPL'].append(result2['fs'].value)
            result['base_PSPL'].append(result2['base'].value)
            result['chisqr_PSPL'].append(chisqr_PSPL)
            result['chisqr_PSPL_err'].append(chisqr_PSPL_err)
            result['chisqr_PSPL_top'].append(chisqr_PSPL_top)
            result['chisqr_PSPL_top_reduced'].append(chisqr_PSPL_top_reduced)
            result['xdata'].append(t)
            result['ydata'].append(m)
            result['yerr'].append(e)
            
            
        except (RuntimeError, TypeError, NameError, ValueError):
            traceback.print_exc()
            pass
#     if c == 4:
#         break

print 'done'
# Out:
#   0%|          | 0/9948 [00:00<?, ?it/s]/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/ipykernel/__main__.py:61: RuntimeWarning: invalid value encountered in double_scalars
# /Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/ipykernel/__main__.py:91: RuntimeWarning: invalid value encountered in double_scalars
#  58%|█████▊    | 5726/9948 [4:53:44<3:36:35,  3.08s/it]Traceback (most recent call last):
#   File "<ipython-input-526-f3d01ec31f05>", line 26, in <module>
#     df, baseline, event, result1, result2, chisqr_bell, chisqr_bell_err, chisqr_PSPL,             chisqr_PSPL_err, chisqr_bell_top, chisqr_PSPL_top, chisqr_bell_top_reduced, chisqr_PSPL_top_reduced  = Calculate_PSPL_minus_Cauchy(t, m, e)
#   File "<ipython-input-524-edcf9c7c4d93>", line 33, in Calculate_PSPL_minus_Cauchy
#     res2 = minimize(PSPL_data, params2, args=(df['t'].values, df['magnitude'].values))
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 2300, in minimize
#     return fitter.minimize(method=method)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 1949, in minimize
#     return function(**kwargs)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 1492, in leastsq
#     lsout = scipy_leastsq(self.__residual, variables, **lskws)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/minpack.py", line 384, in leastsq
#     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/minpack.py", line 26, in _check_func
#     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 538, in __residual
#     nan_policy=self.nan_policy)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 2166, in _nan_policy
#     raise ValueError("The input contains nan values")
# ValueError: The input contains nan values
#  62%|██████▏   | 6154/9948 [5:04:34<3:07:46,  2.97s/it]Traceback (most recent call last):
#   File "<ipython-input-526-f3d01ec31f05>", line 26, in <module>
#     df, baseline, event, result1, result2, chisqr_bell, chisqr_bell_err, chisqr_PSPL,             chisqr_PSPL_err, chisqr_bell_top, chisqr_PSPL_top, chisqr_bell_top_reduced, chisqr_PSPL_top_reduced  = Calculate_PSPL_minus_Cauchy(t, m, e)
#   File "<ipython-input-524-edcf9c7c4d93>", line 33, in Calculate_PSPL_minus_Cauchy
#     res2 = minimize(PSPL_data, params2, args=(df['t'].values, df['magnitude'].values))
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 2300, in minimize
#     return fitter.minimize(method=method)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 1949, in minimize
#     return function(**kwargs)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 1492, in leastsq
#     lsout = scipy_leastsq(self.__residual, variables, **lskws)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/minpack.py", line 384, in leastsq
#     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/minpack.py", line 26, in _check_func
#     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 538, in __residual
#     nan_policy=self.nan_policy)
#   File "/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/lmfit/minimizer.py", line 2166, in _nan_policy
#     raise ValueError("The input contains nan values")
# ValueError: The input contains nan values
# 100%|██████████| 9948/9948 [6:33:00<00:00,  2.37s/it]
# done

# %%
info1 = pd.read_csv('answer_keys/ombin.CSV')
info2 = pd.read_csv('answer_keys/omcassan.CSV')
info3 = pd.read_csv('answer_keys/dccv.CSV')
info4 = pd.read_csv('answer_keys/dcnormffp.CSV')

# %%
frames = [info1, info2, info3, info4]

info = pd.concat(frames)
# Out:
# /Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   app.launch_new_instance()

# %%
# info = info.rename(columns={"index": "name"})

# %%
info = info.reset_index()

# %%
for i in range(len(result['name'])):

    if result['name'][i].split('.lc')[0].endswith('all'): 
        result['name'][i] = result['name'][i].split('all')[0]+'det'+result['name'][i].split('all')[1]

# %%
c = 0
x = info.name
y = result['name']
for j in range(len(x)):
    
    if not x[j] in y:
        info = info.drop([j])
        c = c + 1
print c
# Out:
# 436

# %%
info = info.drop(['level_0', 'index'], axis=1)

# %%
info = info.reset_index()

# %%
info['type'] = np.zeros(len(info))

for i in tqdm(range(len(info))):
    
    if info['name'][i].split('mag')[1].startswith('.ombin'):
        
        info.set_value(i, 'type', 1)
        
    if info['name'][i].split('mag')[1].startswith('.dccv'):
        
        info.set_value(i, 'type', 0)
        
    if info['name'][i].split('mag')[1].startswith('.dcnormffp'):
        
        info.set_value(i, 'type', 3)
        
    if info['name'][i].split('mag')[1].startswith('.omcassan'):
        
        info.set_value(i, 'type', 2)
# Out:
#   0%|          | 0/5578 [00:00<?, ?it/s]/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/ipykernel/__main__.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#  26%|██▌       | 1453/5578 [00:00<00:00, 14526.38it/s]/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/ipykernel/__main__.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#  49%|████▉     | 2722/5578 [00:00<00:00, 13603.82it/s]/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/ipykernel/__main__.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#  70%|███████   | 3925/5578 [00:00<00:00, 13076.92it/s]/Users/Research/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/ipykernel/__main__.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# 100%|██████████| 5578/5578 [00:00<00:00, 12794.69it/s]

# %%
info['t0_bell'] = np.zeros(len(info))
info['tE_bell'] = np.zeros(len(info))
info['chisqr_bell'] = np.zeros(len(info))
info['chisqr_bell_err'] = np.zeros(len(info))
info['chisqr_bell_top'] = np.zeros(len(info))
info['chisqr_bell_top_reduced'] = np.zeros(len(info))
info['b_bell'] = np.zeros(len(info))
info['amp_bell'] = np.zeros(len(info))
info['t0_PSPL'] = np.zeros(len(info))
info['tE_PSPL'] = np.zeros(len(info))
info['u0_PSPL'] = np.zeros(len(info))
info['fs_PSPL'] = np.zeros(len(info))
# info['fb_PSPL'] = np.zeros(len(info))
info['base_PSPL'] = np.zeros(len(info))
info['chisqr_PSPL'] = np.zeros(len(info))
info['chisqr_PSPL_err'] = np.zeros(len(info))
info['chisqr_PSPL_top'] = np.zeros(len(info))
info['chisqr_PSPL_top_reduced'] = np.zeros(len(info))





for i in range(len(result['name'])):
    #print i
    
    info.loc[info.name == result['name'][i],'t0_bell'] = result['t0_bell'][i]-2458234
    info.loc[info.name == result['name'][i],'tE_bell'] = result['tE_bell'][i]
    info.loc[info.name == result['name'][i],'b_bell'] = result['b_bell'][i]
    info.loc[info.name == result['name'][i],'amp_bell'] = result['amp_bell'][i]
    info.loc[info.name == result['name'][i], 't0_PSPL'] = result['t0_PSPL'][i]-2458234
    info.loc[info.name == result['name'][i], 'tE_PSPL'] = result['tE_PSPL'][i]
    info.loc[info.name == result['name'][i], 'u0_PSPL'] = result['u0_PSPL'][i]
    info.loc[info.name == result['name'][i], 'fs_PSPL'] = result['fs_PSPL'][i]
#     info.loc[info.name == result['name'][i], 'fb_PSPL'] = result['fb_PSPL'][i].value
    info.loc[info.name == result['name'][i], 'chisqr_bell'] = result['chisqr_bell'][i]
    info.loc[info.name == result['name'][i], 'chisqr_PSPL'] = result['chisqr_PSPL'][i]
    info.loc[info.name == result['name'][i], 'chisqr_PSPL_err'] = result['chisqr_PSPL_err'][i]
    info.loc[info.name == result['name'][i], 'chisqr_PSPL_top'] = result['chisqr_PSPL_top'][i]
    info.loc[info.name == result['name'][i], 'chisqr_PSPL_top_reduced'] = result['chisqr_PSPL_top_reduced'][i]
    info.loc[info.name == result['name'][i], 'chisqr_bell_err'] = result['chisqr_bell_err'][i]
    info.loc[info.name == result['name'][i], 'chisqr_bell_top'] = result['chisqr_bell_top'][i]
    info.loc[info.name == result['name'][i], 'chisqr_bell_top_reduced'] = result['chisqr_bell_top_reduced'][i]



    

print 'done'
# Out:
# done

# %%
info['delta_chisqr_err'] = info.chisqr_PSPL_err - info.chisqr_bell_err
info['delta_chisqr_top'] = info.chisqr_PSPL_top - info.chisqr_bell_top
info['delta_chisqr'] = info.chisqr_PSPL - info.chisqr_bell
info['delta_chisqr_top_reduced'] = info.chisqr_PSPL_top_reduced - info.chisqr_bell_top_reduced
info['tE_eff'] = info.tE * info.u0
info['tE_eff_exp'] = info.tE_PSPL * info.u0_PSPL
info['tE_bell_PSPL_ratio'] = np.abs(info.tE_bell/info.tE_PSPL)
info['delta_t_true_PSPL'] = np.abs(info.t0-info.t0_PSPL)
info['delta_t_true_bell'] = np.abs(info.t0-info.t0_bell)
info['delta_t_PSPL_bell'] = np.abs(info.t0_PSPL-info.t0_bell)

# %%
# info.to_csv('test_result/Cauchy/Cauchy_alllc_results_V2.CSV')

# %%
info = pd.read_csv('test_result/Cauchy/Cauchy_alllc_results_V2.CSV')

# %%
# # General format for plotting different parameters versus each other 

# fig, axs = plt.subplots(2, 2, sharex=True, sharey=True)

# x = 'chisqr_bell_top_reduced'
# y = 'chisqr_PSPL_top_reduced'
# c_y = 1
# c_x = 1#2.0/(38568-7)

# axs[0,0].plot(c_x*(info[x][info['type']==0]).astype(float).abs(),c_y*(info[y][info['type']==0]).astype(float).abs(), '.',markersize=18, label= 'CV',color='r')
# axs[0,0].grid()
# axs[0,0].legend()
# axs[0,1].plot(c_x*(info[x][info['type']==1]).astype(float).abs(),c_y*(info[y][info['type']==1]).astype(float).abs(), '.',markersize=18, label= 'Binary', color='g')
# #axs[0,1].plot(c_x*(info[x][info['type']==1]).astype(float).abs(),c_x*(info[x][info['type']==1]).astype(float).abs(), 'r-')
# axs[0,1].grid()
# axs[0,1].legend()
# axs[1,0].plot(c_x*(info[x][info['type']==2]).astype(float).abs(),c_y*(info[y][info['type']==2]).astype(float).abs(), '.',markersize=18, label= 'Planetary',  color = 'orange')
# #axs[1,0].plot(c_x*(info[x][info['type']==2]).astype(float).abs(),c_x*(info[x][info['type']==2]).astype(float).abs(), 'g-')
# axs[1,0].grid()
# axs[1,0].legend()
# axs[1,1].plot(c_x*(info[x][info['type']==3]).astype(float).abs(),c_y*(info[y][info['type']==3]).astype(float).abs(), '.',markersize=18, label= 'PSPL/FFP', color='blue')
# axs[1,1].plot(c_x*(info[x][info['type']==3]).astype(float).abs(),c_x*(info[x][info['type']==3]).astype(float).abs(), 'r-')
# axs[1,1].grid()
# axs[1,1].legend()


# axs[0, 1].tick_params(axis='x',which='both', bottom='off', top='off',labelbottom='off')
# axs[0, 1].tick_params(axis='y',which='both', bottom='right', top='left',labelleft='off',length=0)

# axs[0, 0].tick_params(axis='y',which='both', labelsize=12)
# axs[1, 0].tick_params(axis='both',which='both', labelsize=12)
# axs[1, 1].tick_params(axis='x',which='both', labelsize=12)

# plt.yscale('log')
# plt.xscale('log')



# axs[0, 0].tick_params(axis='x',which='both', bottom='off', top='off',labelbottom='off')
# axs[1, 1].tick_params(axis='y',which='both', bottom='right', top='left',labelleft='off', length=0)

# xlim = (1e-4,5)
# ylim = (0.1,20)

# # axs[0,0].set_ylim(ylim)
# # axs[0,1].set_ylim(ylim)
# # axs[1,0].set_ylim(ylim)
# # axs[1,1].set_ylim(ylim)
# # axs[0,0].set_xlim(xlim)
# # axs[1,0].set_xlim(xlim)
# # axs[0,1].set_xlim(xlim)
# # axs[1,1].set_xlim(xlim)

# plt.subplots_adjust(left=None, bottom=None, right=None, top=None,
#                     wspace=0.05, hspace=0.08) 

# fig.text(0.5, 0.02, x, ha='center',size=30)
# fig.text(0.02, 0.5, y, va='center', rotation='vertical',size=30)

# fig = plt.gcf()
# fig.set_size_inches(20.0,15.0)
# #fig.savefig('a4-a2.png')

# %%
# x = 'tE_bell'
# y = 'delta_chisqr_top'
# rho_lim = 0.01

# fig, axs = plt.subplots(1, 2, sharex=True, sharey=True)

# ttl = axs[0].set_title('$Events \;\; with \;\; {{\chi}^2}_{PSPL} \; - \; {{\chi}^2}_{Cauchy} > 0$', size =32)
# ttl.set_position([.5, 1.01])

# axs[0].plot(np.abs(info[x][(info.type==3) & (info.delta_chisqr>0) ]), 
#          np.abs(info[y][(info.type==3)& (info.delta_chisqr>0) ]), 'b.', markersize = 20, 
#             label='All events with ${{\chi}^2}_{PSPL} \; - \; {{\chi}^2}_{Cauchy} > 0$')
# axs[0].plot(np.abs(info[x][(info.type==3)  & (info.rho<rho_lim)& (info.delta_chisqr>0)]), 
#          np.abs(info[y][(info.type==3) &  (info.rho<rho_lim)& (info.delta_chisqr>0)]), 
#             'r.', markersize = 20, label = r'$\rho < 0.01$')

# axs[0].set_xscale('log')
# axs[0].set_yscale('log')
# axs[0].set_xticklabels(['', '','${10}^{-3}$','${10}^{-2}$','${10}^{-1}$',
#                         '${10}^0$', '${10}^1$', '${10}^2$', ''],
#                           rotation = 0, fontsize =25)
# axs[0].tick_params(axis='y',which='both', left = True)


# axs[0].set_yticklabels(['', '','${10}^{-6}$','${10}^{-5}$','${10}^{-4}$',
#                         '${10}^{-3}$', '${10}^{-2}$', '${10}^{-1}$', 
#                         '${10}^0$','${10}^1$',''], rotation = 90, fontsize =25)
# # axs[0].set_xticks([1e-4, 1e-3, 1e-2, 1e-1,1e0,1e1,1e2, 1e3])
# axs[0].grid()
# axs[0].legend(loc='lower center', ncol=1, mode="expand",numpoints=1, shadow=True, fancybox=True,prop={'size': 25})

# ttl = axs[1].set_title('$Events \;\; with \;\; {{\chi}^2}_{PSPL} \; - \; {{\chi}^2}_{Cauchy} < 0$', size =32)
# ttl.set_position([.5, 1.01])

# axs[1].plot(np.abs(info[x][(info.type==3) & (info.delta_chisqr<0) ]), 
#          np.abs(info[y][(info.type==3)& (info.delta_chisqr<0) ]), 'b.', markersize = 20,
#            label='All events with ${{\chi}^2}_{PSPL} \; - \; {{\chi}^2}_{Cauchy} < 0$')
# axs[1].plot(np.abs(info[x][(info.type==3)  & (info.rho<rho_lim)& (info.delta_chisqr<0)]), 
#          np.abs(info[y][(info.type==3) &  (info.rho<rho_lim)& (info.delta_chisqr<0)]), 
#             'r.', markersize = 20, label = r'$\rho < 0.01$')

# axs[1].legend(loc='best', ncol=1, mode="expand",numpoints=1, shadow=True, fancybox=True, prop={'size': 25})
# axs[1].set_xscale('log')
# axs[1].set_yscale('log')

# axs[1].set_xticklabels(['','','${10}^{-3}$','${10}^{-2}$','${10}^{-1}$',
#                         '${10}^0$', '${10}^1$', '${10}^2$', ''],
#                           rotation = 0, fontsize =25)
# # axs[0].set_yticklabels(['', '','${10}^{-6}$','${10}^{-5}$','${10}^{-4}$',
# #                         '${10}^{-3}$', '${10}^{-2}$', '${10}^{-1}$', 
# #                         '${10}^0$','${10}^1$',''], rotation = 0, fontsize =20)
# # axs[1].tick_params(axis='both',which='both', labelsize=20)

# axs[1].tick_params(axis='y',which='both', left=True,labelleft='off')
# axs[1].set_yticklabels(['', '','${10}^{-6}$','${10}^{-5}$','${10}^{-4}$',
#                         '${10}^{-3}$', '${10}^{-2}$', '${10}^{-1}$', 
#                         '${10}^0$','${10}^1$',''], rotation = 90, fontsize =25)
# axs[1].grid()
# plt.subplots_adjust(left=None, bottom=0.08, right=None, top=None,
#                     wspace=0.0, hspace=0.5) 

# fig.text(0.5, 0.02, '$Estimated \;\; t_E$', ha='center',size=35)
# fig.text(0.02, 0.5, '${{\chi}^2}_{PSPL} \; - \; {{\chi}^2}_{Cauchy}$', va='center', rotation='vertical',size=35)
# fig = plt.gcf()
# fig.set_size_inches(20.0,15.0)
# # fig.savefig('Cauchy_delta_chi_versus_tE.png')

# %%
x = 'rho'
y = 'delta_chisqr_top_reduced'
z_lim = 0.01
z = 'u0'
c = info[z][(info.type==3)]
#c[(info.delta_chisqr_top_reduced<0) & (info[z]>z_lim)] & c[(info.delta_chisqr_top_reduced>0) & (info[z]>z_lim)]
legend_elements = []

fig, axs = plt.subplots(2, 1, sharex=True)


axs[0].plot(np.abs(info[x][(info.type==3) & (info.delta_chisqr_top_reduced>0) ]), 
         np.abs(info[y][(info.type==3)& (info.delta_chisqr_top_reduced>0) ]), 'b.', markersize = 20, 
            label='$All$')
axs[0].plot(np.abs(info[x][(info.type==3)  & (info[z]<z_lim)& (info.delta_chisqr_top_reduced>0)& (info.b_bell<1)]), 
         np.abs(info[y][(info.type==3) &  (info[z]<z_lim)& (info.delta_chisqr_top_reduced>0)& (info.b_bell<1)]), 
            'g.', markersize = 20, label = '${t_E}_{fitted} < 2$')
axs[0].plot(np.abs(info[x][(info.type==3)&(info.delta_chisqr_top_reduced>0)& (info.b_bell>1)]), 
         np.abs(info[x][(info.type==3)& (info.delta_chisqr_top_reduced>0)& (info.b_bell>1)]), 
            'k-')
legend_elements.append(Line2D([0], [0], marker='o', color='w', label='Estimated '+'${t_E} > 2$',
                          markerfacecolor='b', markersize=15))
legend_elements.append(Line2D([0], [0], marker='o', color='w', label='Estimated '+'${t_E} < 2$',
                          markerfacecolor='g', markersize=15))
# axs[0].plot(np.abs(info[x][(info.type==3)  & (info[z]<0.05)& (info.delta_chisqr>0)]), 
#          np.abs(info[y][(info.type==3) &  (info[z]<0.05)& (info.delta_chisqr>0)]), 
#             'k.', markersize = 20, label = '${t_E}_{fitted} < 1$')

# print float(len(info[x][(info.type==3)  & (info['rho']>0.01)& (info.delta_chisqr>0)]))/ float(len(info[x][(info.type==3) & (info.delta_chisqr>0) ]))
# print float(len(info[x][(info.type==3)  & (info[z]<z_lim)& (info.delta_chisqr>0)]))/ float(len(info[x][(info.type==3) & (info.delta_chisqr>0) ]))


axs[0].set_xscale('log')
axs[0].set_yscale('log')
# axs[0].set_xticklabels(['', '','${10}^{-3}$','${10}^{-2}$','${10}^{-1}$',
#                         '${10}^0$', '${10}^1$', '${10}^2$', ''],
#                           rotation = 0, fontsize =25)
# axs[0].tick_params(axis='y',which='both', left = True)


axs[0].set_yticklabels(['', '','${10}^{-6}$','${10}^{-5}$','${10}^{-4}$',
                        '${10}^{-3}$', '${10}^{-2}$', '${10}^{-1}$', 
                        '$1$','$10$','$100$', ''], rotation = 0, fontsize =25)
# # axs[0].set_xticks([1e-4, 1e-3, 1e-2, 1e-1,1e0,1e1,1e2, 1e3])
axs[0].grid()
# axs[0].legend(bbox_to_anchor=(1.02, 0., 1.03, 1.),handles=legend_elements, loc='right',
#            ncol=1, mode="expand", borderaxespad=0. ,prop={'size': 22})


# ttl = axs[1].set_title('$Events \;\; with \;\; {{\chi}^2}_{PSPL} \; - \; {{\chi}^2}_{Cauchy} < 0$', size =32)
# ttl.set_position([.5, 1.01])

axs[1].plot(np.abs(info[x][(info.type==3) & (info.delta_chisqr_top_reduced<0) ]), 
         np.abs(info[y][(info.type==3)& (info.delta_chisqr_top_reduced<0) ]), 'b.', markersize = 20,
           label='$All$')
axs[1].plot(np.abs(info[x][(info.type==3) & (info.delta_chisqr_top_reduced<0)]), 
         np.abs(info[x][(info.type==3)& (info.delta_chisqr_top_reduced<0)]), 'k-', markersize = 20)
axs[1].plot(np.abs(info[x][(info.type==3)  & (info[z]<z_lim)& (info.delta_chisqr_top_reduced<0)& (info.b_bell<1)]), 
         np.abs(info[y][(info.type==3) &  (info[z]<z_lim)& (info.delta_chisqr_top_reduced<0)& (info.b_bell<1)]), 
            'g.', markersize = 20, label = '${t_E}_{fitted} < 2$')
# axs[1].plot(np.abs(info[x][(info.type==3)  & (info[z]<0.05)& (info.delta_chisqr<0)]), 
#          np.abs(info[y][(info.type==3) &  (info[z]<0.05)& (info.delta_chisqr<0)]), 
#             'k.', markersize = 20, label = '${t_E}_{fitted} < 1$')

axs[0].legend(handles=legend_elements, loc='upper left', ncol=1,numpoints=1, shadow=True, fancybox=True, prop={'size': 25})

axs[1].set_xscale('log')
axs[1].set_yscale('log')
# axs[1].set_ylim(0.01,10)
axs[1].invert_yaxis()
axs[1].set_xticklabels(['','${10}^{-4}$', '${10}^{-3}$','${10}^{-2}$','${10}^{-1}$',
                        '$1$','$10$'],
                          rotation = 0, fontsize =25)
axs[1].set_yticklabels(['', '0','$-{10}^{-6}$','$-{10}^{-5}$','$-{10}^{-4}$',
                        '$-{10}^{-3}$', '$-{10}^{-2}$', '$-{10}^{-1}$', 
                        '$-1$',''], rotation = 0, fontsize =25)
# axs[1].set_xlim(1e-4, 5)
axs[1].grid()

# print float(len(info[x][(info.type==3)  & (info['rho']>0.01)& (info.delta_chisqr<0)]))/ float(len(info[x][(info.type==3) & (info.delta_chisqr<0) ]))
# print float(len(info[x][(info.type==3)  & (info[z]<z_lim)& (info.delta_chisqr<0)]))/ float(len(info[x][(info.type==3) & (info.delta_chisqr<0) ]))


plt.subplots_adjust(left=None, bottom=0.08, right=None, top=None,
                    wspace=0.0, hspace=0.0) 

fig.text(0.5, 0.02, r'$\rho$', ha='center',size=35)
fig.text(0.02, 0.5, '${{\chi}^2}_{PSPL} \; - \; {{\chi}^2}_{Cauchy}$', va='center', rotation='vertical',size=35)
fig = plt.gcf()
fig.set_size_inches(20.0,15.0)
# fig.savefig('Cauchy_delta_chi_rho_V2.png')

# %%
med_med(np.log10(np.abs(info[x][(info.type==3) & (info.delta_chisqr_top_reduced>0)& (info.b_bell>1) ])), 
         np.log10(np.abs(info[y][(info.type==3)& (info.delta_chisqr_top_reduced>0)& (info.b_bell>1) ])))
# Out:
# 0.5164872744043745

# %%
med_med(np.log10(np.abs(info[x][(info.type==3) & (info.delta_chisqr_top_reduced<0)& (info.b_bell>1) ])), 
         np.log10(np.abs(info[y][(info.type==3)& (info.delta_chisqr_top_reduced<0) & (info.b_bell>1)])))
# Out:
# 0.6813901315028978

# %%
plt.plot(np.abs(info.u0[info.type==3]), np.abs(info.u0_PSPL[info.type==3]), 'b.')
plt.xscale('log')
plt.yscale('log')

# %%
info.delta_chisqr_err
# Out:
#                                      name        u0   u0_PSPL
# 112        mag.ombin_0_15_462.det.lc.W149  0.000658  0.001660
# 647        mag.ombin_0_49_422.det.lc.W149 -0.000211  0.051734
# 1530       mag.ombin_0_15_462.det.lc.W149  0.000658  0.001660
# 1970       mag.ombin_0_49_422.det.lc.W149 -0.000211  0.051734
# 2817   mag.omcassan_1_98_1986.det.lc.W149 -0.000088  0.018327
# 2970   mag.omcassan_3_88_2720.det.lc.W149 -0.000994  0.000839
# 3225   mag.omcassan_7_23_2622.det.lc.W149  0.000184  0.000167
# 5039  mag.dcnormffp_0_82_1361.det.lc.W149  0.000323  0.884292
# 5040  mag.dcnormffp_0_82_1363.det.lc.W149  0.000563  0.114252

# %%
info[['name','u0','u0_PSPL', 't0', 't0_PSPL', 't0_bell', 'delta_chisqr_top_reduced','delta_chisqr_err', 'tE','tE_bell','tE_PSPL','b_bell','rho']][(info.type==3) & (info[y]>0)& (info.b_bell<1)]
# Out:
#                                      name        u0   u0_PSPL           t0  \
# 3996    mag.dcnormffp_0_82_80.det.lc.W149 -0.089913  0.087503   547.917364
# 4035   mag.dcnormffp_0_82_126.det.lc.W149 -0.067363  0.068319   516.682975
# 4036   mag.dcnormffp_0_82_127.det.lc.W149  0.029833  0.140150  1791.166928
# 4040   mag.dcnormffp_0_82_131.det.lc.W149 -0.084016  0.088597  1818.022013
# 4055   mag.dcnormffp_0_82_148.det.lc.W149 -0.056560  0.143655  1410.910782
# 4057   mag.dcnormffp_0_82_150.det.lc.W149  0.335485  0.170905  1614.655929
# 4079   mag.dcnormffp_0_82_181.det.lc.W149 -0.872879  0.157266  1819.876839
# 4080   mag.dcnormffp_0_82_182.det.lc.W149 -0.227814  0.021287  1587.591544
# 4097   mag.dcnormffp_0_82_209.det.lc.W149  0.157218  2.306322  1823.773268
# 4107   mag.dcnormffp_0_82_225.det.lc.W149 -0.711822  0.037602  1409.745675
# 4108   mag.dcnormffp_0_82_226.det.lc.W149  0.065199  0.075195   169.566812
# 4109   mag.dcnormffp_0_82_227.det.lc.W149 -0.051451  0.049932   178.117094
# 4116   mag.dcnormffp_0_82_234.det.lc.W149 -0.151328  0.124145  1628.021053
# 4124   mag.dcnormffp_0_82_246.det.lc.W149 -0.080811  0.069963  1804.141966
# 4140   mag.dcnormffp_0_82_264.det.lc.W149  0.016836  0.084472   518.630710
# 4210   mag.dcnormffp_0_82_344.det.lc.W149 -0.016037  0.081499  1596.027278
# 4219   mag.dcnormffp_0_82_358.det.lc.W149 -0.125804  0.124221  1405.609875
# 4224   mag.dcnormffp_0_82_363.det.lc.W149  0.101629  0.071825  1614.880444
# 4253   mag.dcnormffp_0_82_401.det.lc.W149 -0.134403  0.125731  1757.949940
# 4256   mag.dcnormffp_0_82_404.det.lc.W149  0.870351  0.169307  1448.779571
# 4267   mag.dcnormffp_0_82_420.det.lc.W149 -0.108748  0.082764   538.112915
# 4275   mag.dcnormffp_0_82_429.det.lc.W149  0.048139  0.043805   514.017486
# 4280   mag.dcnormffp_0_82_435.det.lc.W149 -0.047169  0.047628  1582.637115
# 4301   mag.dcnormffp_0_82_465.det.lc.W149  0.112953  0.112855  1803.292306
# 4316   mag.dcnormffp_0_82_484.det.lc.W149 -0.120473  0.172683   138.741618
# 4336   mag.dcnormffp_0_82_508.det.lc.W149 -0.273867  0.047646   292.443627
# 4348   mag.dcnormffp_0_82_521.det.lc.W149 -0.041315  0.095911   355.810227
# 4354   mag.dcnormffp_0_82_527.det.lc.W149  0.019825  0.017160   314.289232
# 4366   mag.dcnormffp_0_82_542.det.lc.W149 -0.320411  0.165456  1414.898382
# 4371   mag.dcnormffp_0_82_547.det.lc.W149  0.011465  0.039606  1805.721599
# ...                                   ...       ...       ...          ...
# 4932  mag.dcnormffp_0_82_1235.det.lc.W149 -0.168211  0.166402   297.447477
# 4957  mag.dcnormffp_0_82_1263.det.lc.W149 -0.458370  0.081973  1803.157884
# 4961  mag.dcnormffp_0_82_1267.det.lc.W149 -0.156157  0.161538  1598.125788
# 4977  mag.dcnormffp_0_82_1287.det.lc.W149  0.009570  0.035419   485.332494
# 4992  mag.dcnormffp_0_82_1305.det.lc.W149 -0.207176  0.058995  1420.872236
# 5034  mag.dcnormffp_0_82_1355.det.lc.W149 -0.186414  0.185250  1637.344304
# 5040  mag.dcnormffp_0_82_1363.det.lc.W149  0.000563  0.114252  1422.943790
# 5044  mag.dcnormffp_0_82_1367.det.lc.W149 -0.070479  0.068583  1417.559858
# 5096  mag.dcnormffp_0_82_1427.det.lc.W149 -0.162372  0.160586   539.076629
# 5102  mag.dcnormffp_0_82_1433.det.lc.W149 -0.016161  0.051111   506.818024
# 5119  mag.dcnormffp_0_82_1452.det.lc.W149 -0.142450  0.137512  1760.794957
# 5163  mag.dcnormffp_0_82_1509.det.lc.W149 -0.292409  0.152219  1457.847278
# 5170  mag.dcnormffp_0_82_1517.det.lc.W149 -0.229859  0.199217   115.388899
# 5214  mag.dcnormffp_0_82_1568.det.lc.W149  0.093591  0.136329   538.641676
# 5216  mag.dcnormffp_0_82_1570.det.lc.W149 -0.146767  0.100025   360.603998
# 5231  mag.dcnormffp_0_82_1589.det.lc.W149  0.208073  0.115275  1802.573714
# 5232  mag.dcnormffp_0_82_1590.det.lc.W149 -0.166872  0.160046   149.253038
# 5252  mag.dcnormffp_0_82_1612.det.lc.W149 -0.154709  0.155546   155.924114
# 5277  mag.dcnormffp_0_82_1641.det.lc.W149 -0.029581  0.146350   320.919079
# 5279  mag.dcnormffp_0_82_1644.det.lc.W149 -0.242283  0.137610  1818.930377
# 5281  mag.dcnormffp_0_82_1647.det.lc.W149 -0.121411  0.137107  1775.681489
# 5328  mag.dcnormffp_0_82_1710.det.lc.W149 -0.196260  0.126722   162.805852
# 5379  mag.dcnormffp_0_82_1770.det.lc.W149  0.006906  0.038420  1774.264192
# 5405  mag.dcnormffp_0_82_1803.det.lc.W149 -0.212216  0.171815  1637.588228
# 5416  mag.dcnormffp_0_82_1816.det.lc.W149 -0.139228  0.142325  1398.982603
# 5426  mag.dcnormffp_0_82_1828.det.lc.W149  0.054624  0.064076   520.902100
# 5477  mag.dcnormffp_0_82_1886.det.lc.W149 -0.093670  0.048247  1623.986728
# 5488  mag.dcnormffp_0_82_1902.det.lc.W149 -0.020856  0.155932   166.462446
# 5533  mag.dcnormffp_0_82_1962.det.lc.W149  0.093914  0.138633  1804.285133
# 5539  mag.dcnormffp_0_82_1968.det.lc.W149  0.045738  0.062252   532.945351
#
#           t0_PSPL      t0_bell  delta_chisqr_top_reduced  delta_chisqr_err  \
# 3996   547.918612   547.918401                  0.000631         -9.770540
# 4035   516.683126   516.683134                  0.039164         14.328080
# 4036  1791.166082  1791.166574                731.672407       9095.100142
# 4040  1818.023263  1818.023444                  0.088765        -53.074347
# 4055  1410.910077  1410.910184                 16.986841        261.490008
# 4057  1614.715035  1614.717142                  0.004648         -3.120617
# 4079  1819.881927  1819.882018                  0.083112         -4.435965
# 4080  1587.605197  1587.605140                  0.033261          2.243417
# 4097  1823.779796  1823.777931                  0.080832         17.754826
# 4107  1409.756491  1409.758998                  0.055172          3.252754
# 4108   169.566865   169.566874               2452.810811       -416.931870
# 4109   178.117250   178.117202                328.067245       -546.712263
# 4116  1628.042068  1628.041244                  0.010586          1.947223
# 4124  1804.143097  1804.143028                  0.059283         12.183410
# 4140   518.630725   518.630846                958.975895      16043.476875
# 4210  1596.027193  1596.026742                  8.265812        231.914369
# 4219  1405.563730  1405.561344                  0.000602         -3.148022
# 4224  1614.879851  1614.880520                916.579027      -1021.737519
# 4253  1757.949012  1757.949072                  0.058455        -14.265297
# 4256  1448.775957  1448.776109                  0.027278         10.512360
# 4267   538.113654   538.113982                  0.002151         28.725487
# 4275   514.017337   514.017676                  0.116226        -31.207988
# 4280  1582.629853  1582.629453                  0.011015         -5.983530
# 4301  1803.292327  1803.292469                  0.002332         34.580129
# 4316   138.742954   138.742984                  0.152828        -20.452393
# 4336   292.434516   292.432990                  0.014296         -4.377536
# 4348   355.810221   355.810305                101.659036        984.937723
# 4354   314.288956   314.289045                  0.677672       -459.875121
# 4366  1414.898223  1414.898071                  0.097065          2.638929
# 4371  1805.721436  1805.721514                281.113212       3694.237590
# ...           ...          ...                       ...               ...
# 4932   297.446630   297.447466                  0.014759          0.957818
# 4957  1803.155166  1803.155041                  0.004153          7.503784
# 4961  1598.124351  1598.124499                  0.000808          4.879819
# 4977   485.332214   485.332077                  9.840298        463.482350
# 4992  1420.869704  1420.869581                  0.004020          6.991958
# 5034  1637.348002  1637.348289                  0.011421        -23.880249
# 5040  1422.943666  1422.943421                349.597488       2064.638090
# 5044  1417.560116  1417.560160                  0.028658         -4.802205
# 5096   539.070914   539.070857                  0.014360         -4.587421
# 5102   506.817828   506.817855                221.161468       2973.802857
# 5119  1760.795782  1760.795682                  0.032298          5.305853
# 5163  1457.842096  1457.841553                  0.007451          1.373957
# 5170   115.397712   115.404261                  0.001743          6.310178
# 5214   538.634659   538.634226                  0.049455          0.478435
# 5216   360.613877   360.613306                  0.017542          0.013835
# 5231  1802.570798  1802.570956                  0.002440         -3.891524
# 5232   149.258550   149.258132                  0.040341         -5.817333
# 5252   155.896490   155.895960                  0.012676         22.587154
# 5277   320.918647   320.918781                  1.020115         57.876769
# 5279  1818.924094  1818.924527                  0.018858          0.396937
# 5281  1775.681879  1775.682381                  0.029565         12.685792
# 5328   162.806793   162.807073                  0.005057         -2.307971
# 5379  1774.263939  1774.263542               9393.962704      13013.521636
# 5405  1637.588227  1637.588221                392.017132       -827.232999
# 5416  1398.983086  1398.983794                  0.030362         -6.124850
# 5426   520.900037   520.901098                203.994829       -448.927515
# 5477  1623.985959  1623.985950                  0.045859         21.219513
# 5488   166.462428   166.462371               1273.040084       7780.392078
# 5533  1804.287584  1804.287780                  0.241673          5.850291
# 5539   532.945178   532.945314                910.432948       5574.456807
#
#              tE   tE_bell    tE_PSPL    b_bell       rho
# 3996   0.071471  0.010080   0.060854  0.886470  0.149821
# 4035   0.159766  0.018926   0.153509  0.800983  0.024579
# 4036   0.337350  0.086038   0.225637  0.969063  0.169083
# 4040   1.168770  0.169593   1.122951  0.855673  0.006088
# 4055   0.511939  0.062401   0.267669  0.959191  0.108168
# 4057   2.957420  1.153595   4.579955  0.940018  0.002053
# 4079   0.034458  0.014610   0.066552  0.830510  0.168900
# 4080   0.150299  0.029916   0.873088  0.684547  0.048738
# 4097   0.693977  0.167684   0.120418  0.901419  0.004655
# 4107   0.175848  0.068919   1.233026  0.690729  0.062628
# 4108   0.197087  0.044848   0.168722  0.854620  0.119193
# 4109   0.309458  0.051884   0.276638  0.798128  0.084003
# 4116   2.464060  0.515925   2.651974  0.924060  0.001810
# 4124   0.493029  0.070026   0.538264  0.828954  0.009627
# 4140   0.411415  0.091315   0.308075  0.875194  0.117432
# 4210   0.103358  0.021601   0.082932  0.921414  0.134309
# 4219  13.102300  2.541717  13.253791  0.897070  0.000274
# 4224   0.251018  0.071944   0.237607  0.899488  0.166448
# 4253   0.234243  0.050685   0.244885  0.876303  0.072194
# 4256   0.115467  0.079788   0.307788  0.961174  0.043962
# 4267   0.035640  0.008895   0.054574  0.897484  0.079457
# 4275   1.864290  0.170499   2.019658  0.765646  0.003285
# 4280   8.651730  0.666113   8.481487  0.776923  0.001626
# 4301   0.412834  0.094293   0.414793  0.905392  0.027042
# 4316   0.096683  0.020161   0.073395  0.955737  0.060277
# 4336   0.266473  0.068508   0.882041  0.756244  0.009910
# 4348   0.158024  0.028644   0.108362  0.889628  0.114613
# 4354   0.414452  0.022670   0.384973  0.678043  0.027882
# 4366   0.038562  0.013889   0.050044  0.981919  0.360948
# 4371   0.514512  0.043538   0.353847  0.771122  0.051889
# ...         ...       ...        ...       ...       ...
# 4932   2.482320  0.615341   2.483062  0.949464  0.001258
# 4957   0.110364  0.054454   0.389006  0.923761  0.030964
# 4961   0.249760  0.061377   0.241110  0.948563  0.023425
# 4977   0.840998  0.025910   0.369238  0.779147  0.026531
# 4992   0.201820  0.046723   0.469964  0.827541  0.017430
# 5034   1.852030  0.520938   1.839269  0.968553  0.004930
# 5040   0.119090  0.023015   0.074501  0.920106  0.118889
# 5044   0.226598  0.027106   0.223942  0.834501  0.025718
# 5096   0.508244  0.131351   0.530883  0.952676  0.019881
# 5102   0.273721  0.035374   0.195893  0.800436  0.070904
# 5119   0.845946  0.199086   0.911242  0.938462  0.004167
# 5163   1.835640  0.607931   2.640003  0.938637  0.007254
# 5170   5.176160  1.681279   5.758586  0.985144  0.000814
# 5214   0.310857  0.058145   0.277140  0.930321  0.027128
# 5216   0.670734  0.131721   0.797150  0.922025  0.013635
# 5231   1.286880  0.360813   1.973426  0.891247  0.005362
# 5232   1.614220  0.400141   1.632107  0.947751  0.003406
# 5252   6.179940  1.587479   6.170661  0.954590  0.003528
# 5277   0.060077  0.011463   0.039890  0.953049  0.147736
# 5279   0.172309  0.056756   0.266492  0.924431  0.073165
# 5281   0.542321  0.121103   0.507542  0.936278  0.010715
# 5328   0.400234  0.098360   0.513757  0.862957  0.006790
# 5379   0.418579  0.075550   0.351943  0.790498  0.077286
# 5405   0.097283  0.038070   0.091648  0.992845  0.272889
# 5416   5.312000  1.168649   5.247486  0.926565  0.000968
# 5426   0.318526  0.061775   0.282389  0.835967  0.104362
# 5477   0.171616  0.022661   0.255775  0.792579  0.082394
# 5488   0.102542  0.028723   0.070895  0.997482  0.178435
# 5533   0.458513  0.069641   0.314872  0.937887  0.147262
# 5539   0.464325  0.066010   0.361102  0.824411  0.087336
#
# [88 rows x 13 columns]

# %%
x = 'rho'
y = 'delta_chisqr_top_reduced'
c = info['tE_PSPL'][(info.type==3)]

# x2= np.abs(info[x][(info.type==3) & (info[y]<0) & (info.b_bell>1)& (info.b_bell<3)]).values
# y2= np.abs(info[y][(info.type==3) & (info[y]<0) & (info.b_bell>1)& (info.b_bell<3)]).values
# z= np.abs(info['b_bell'][(info.type==3) & (info[y]<0) & (info.b_bell>1)& (info.b_bell<3)]).values

# df_n=pd.DataFrame(data={'A':x2,'B':y2,'C':z})

# points = plt.scatter(df_n.A, df_n.B, c=df_n.C,cmap="magma", lw=0,s=45, norm=matplotlib.colors.LogNorm())
# cbar=plt.colorbar(points)
# cbar.ax.set_ylabel('b Value', size=20)

# plt.xlim(1e-4,10)
# plt.ylim(1e-7,10)

plt.plot(np.abs(info[x][(info.type==3) & (info[y]>0)]), 
         np.abs(info[y][(info.type==3) & (info[y]>0)]), 'b.', markersize = 20, 
            label='$All$')
plt.plot(np.abs(info[x][(info.type==3) & (info[y]>0)& (info.u0_PSPL<0.05)]), 
         np.abs(info[y][(info.type==3) & (info[y]>0)&(info.u0_PSPL<0.05)]), 'r.', markersize = 20, 
            label='$All$')
# plt.plot(np.abs(info[x][(info.type==3) & (np.abs(info[y])<info[x]/50) & (info.b_bell>1) ]), 
#          np.abs(info[y][(info.type==3) & (np.abs(info[y])<info[x]/50) & (info.b_bell>1)]), 'r.', markersize = 20, 
#             label='$All$')
# plt.plot(np.abs(info[x][(info.type==3) & (info[y]<0) & (info.b_bell>1.0)& (info.b_bell<1.2) ]), 
#          np.abs(info[y][(info.type==3) & (info[y]<0) & (info.b_bell>1.0)& (info.b_bell<1.2)]), 'k.', markersize = 20, 
#             label='$All$')
plt.plot(np.abs(info[x][(info.type==3) & (info.b_bell>1)]), 
         np.abs(info[x][(info.type==3) & (info.b_bell>1)]), 'k-')

# plt.plot(np.abs(info[x][(info.type==3)& (info.tE_PSPL<2)]), 
#          np.abs(info[y][(info.type==3) &  (info.tE_PSPL<2)]), 'g.', markersize = 20, 
#             label='$All$')
# & (np.abs(info[y])<10*info[x]) 
plt.xscale('log')
plt.yscale('log')
fig = plt.gcf()
fig.set_size_inches(20.0,15.0)

# %%
# plt.plot(info['rho'][(info.type==3) & (np.abs(info.t0-info.t0_bell)<5)& (info.b_bell<2)], 
#          info['b_bell'][(info.type==3) &(np.abs(info.t0-info.t0_bell)<5)& (info.b_bell<2)], 'b.', markersize=25)
plt.plot(info['rho'][(info.type==3) &  (info.b_bell>1) & (info.full_top == 1)], 
         info['b_bell'][(info.type==3) & (info.b_bell>1)& (info.full_top == 1)], 'b.', markersize=25)
# plt.plot(info['rho'][(info.type==3) &  (info.b_bell>1.3)], 
#          info['b_bell'][(info.type==3) & (info.b_bell>1.3)], 'r.', markersize=25)
plt.xscale('log')
# plt.yscale('log')

plt.xlabel(r'$\rho$',size = 40)
plt.ylabel('b Value', size= 35)
plt.ylim(0.4, 4)

plt.grid()
ax = plt.gca()
ax.set_yticklabels(['',0.5,1,1.5,2,2.5,3,3.5,4], rotation = 90, fontsize = 30)
ax.set_xticklabels(['','', 0.001, 0.01, 0.1, 1, 10], rotation = 0, fontsize = 30)



fig = plt.gcf()
fig.set_size_inches(20.0,15.0)
fig.savefig('b_vs_rho_V2.png')

# %%
# info[['name', 't0', 't0_bell', 'tE', 'tE_bell', 'rho', 'b_bell', 'delta_chisqr_top_reduced', 'full_top']][(info.type==3) & (info.b_bell >1.5) ]

# %% [markdown]
# # In the following cells, I have selected a few of the wrong results and repeated the fitting process for them.

# %%
temp_info = (info[(info.type==3) & ((info.t0-info.t0_bell)<10) & (info.b_bell>2) &(info.rho>0.01)])

# %%
# for f in temp_info.name:
    
#     t,m,e = np.loadtxt(temp+str(f),unpack=True, usecols=(0,1, 2))

#     f, baseline, event, result1, result2, chisqr_bell, chisqr_bell_err, chisqr_PSPL, chisqr_PSPL_err  = Calculate_PSPL_minus_Cauchy(t, m, e)

# %%
for i in range(len(result['name'])):
    info.loc[info.name == result['name'][i], 'b_bell'] = result['b_bell'][i]

# %%
info.loc[info.name == 'mag.dcnormffp_0_82_949.det.lc.W149', 'delta_chisqr_top_reduced'] = -0.0042202689748871425  
# info.loc[info.name == 'mag.dcnormffp_0_82_1541.det.lc.W149', 'tE_trapezoid_ratio'] = 0.08987250870971625

# %%
info = info.drop(5243)

# %%
#List of good bellcurve shapes:
#mag.dcnormffp_0_82_1456.det.lc.W149

# %%
info['full_top'] = np.ones(len(info.name))
for f in info.name[info.type == 3]:
    print f
    t,m,e = np.loadtxt(temp+f,unpack=True, usecols=(0,1, 2))
    
    t0_bell = info.t0_bell[info.name == f].values[0]
    tE_PSPL = info.tE_PSPL[info.name == f].values[0]
    u0_PSPL = info.u0_PSPL[info.name == f].values[0]
    
#     print t0_bell, tE_PSPL, u0_PSPL

    right = len(t[(t>t0_bell+2458234) & (t<t0_bell+2458234+(tE_PSPL*u0_PSPL))])
    left = len(t[(t<t0_bell+2458234) & (t>t0_bell+2458234-(tE_PSPL*u0_PSPL))])
    print right, left
    
    if right == 0 or left == 0 or np.abs(left-right)>1000:
        
        info.loc[info.name == f, 'full_top'] = 0 
    
print 'done'
# Out:
# mag.dcnormffp_0_82_1.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_2.det.lc.W149
# 20 18
# mag.dcnormffp_0_82_3.det.lc.W149
# 14 14
# mag.dcnormffp_0_82_4.det.lc.W149
# 2 3
# mag.dcnormffp_0_82_5.det.lc.W149
# 68 71
# mag.dcnormffp_0_82_6.det.lc.W149
# 37 37
# mag.dcnormffp_0_82_7.det.lc.W149
# 7 8
# mag.dcnormffp_0_82_10.det.lc.W149
# 209 206
# mag.dcnormffp_0_82_11.det.lc.W149
# 804 804
# mag.dcnormffp_0_82_12.det.lc.W149
# 106 102
# mag.dcnormffp_0_82_13.det.lc.W149
# 179 179
# mag.dcnormffp_0_82_14.det.lc.W149
# 123 125
# mag.dcnormffp_0_82_15.det.lc.W149
# 91 91
# mag.dcnormffp_0_82_18.det.lc.W149
# 125 127
# mag.dcnormffp_0_82_19.det.lc.W149
# 124 123
# mag.dcnormffp_0_82_20.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_21.det.lc.W149
# 6 6
# mag.dcnormffp_0_82_22.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_23.det.lc.W149
# 6 5
# mag.dcnormffp_0_82_24.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_25.det.lc.W149
# 10 13
# mag.dcnormffp_0_82_26.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_27.det.lc.W149
# 8 11
# mag.dcnormffp_0_82_28.det.lc.W149
# 88 87
# mag.dcnormffp_0_82_29.det.lc.W149
# 33 32
# mag.dcnormffp_0_82_30.det.lc.W149
# 19 22
# mag.dcnormffp_0_82_31.det.lc.W149
# 41 40
# mag.dcnormffp_0_82_32.det.lc.W149
# 69 69
# mag.dcnormffp_0_82_33.det.lc.W149
# 697 743
# mag.dcnormffp_0_82_34.det.lc.W149
# 149 150
# mag.dcnormffp_0_82_36.det.lc.W149
# 513 515
# mag.dcnormffp_0_82_38.det.lc.W149
# 646 644
# mag.dcnormffp_0_82_40.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_42.det.lc.W149
# 15 15
# mag.dcnormffp_0_82_43.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_47.det.lc.W149
# 54 51
# mag.dcnormffp_0_82_48.det.lc.W149
# 97 97
# mag.dcnormffp_0_82_49.det.lc.W149
# 11 11
# mag.dcnormffp_0_82_50.det.lc.W149
# 10 13
# mag.dcnormffp_0_82_51.det.lc.W149
# 16 12
# mag.dcnormffp_0_82_52.det.lc.W149
# 193 196
# mag.dcnormffp_0_82_53.det.lc.W149
# 71 72
# mag.dcnormffp_0_82_54.det.lc.W149
# 98 99
# mag.dcnormffp_0_82_55.det.lc.W149
# 155 158
# mag.dcnormffp_0_82_56.det.lc.W149
# 313 314
# mag.dcnormffp_0_82_58.det.lc.W149
# 1182 1180
# mag.dcnormffp_0_82_59.det.lc.W149
# 351 350
# mag.dcnormffp_0_82_61.det.lc.W149
# 14 10
# mag.dcnormffp_0_82_66.det.lc.W149
# 27 29
# mag.dcnormffp_0_82_67.det.lc.W149
# 17 15
# mag.dcnormffp_0_82_68.det.lc.W149
# 10 12
# mag.dcnormffp_0_82_69.det.lc.W149
# 3 2
# mag.dcnormffp_0_82_70.det.lc.W149
# 56 58
# mag.dcnormffp_0_82_71.det.lc.W149
# 130 131
# mag.dcnormffp_0_82_72.det.lc.W149
# 40 40
# mag.dcnormffp_0_82_73.det.lc.W149
# 71 67
# mag.dcnormffp_0_82_74.det.lc.W149
# 49 50
# mag.dcnormffp_0_82_75.det.lc.W149
# 165 169
# mag.dcnormffp_0_82_76.det.lc.W149
# 144 146
# mag.dcnormffp_0_82_77.det.lc.W149
# 565 566
# mag.dcnormffp_0_82_80.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_81.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_82.det.lc.W149
# 1 4
# mag.dcnormffp_0_82_83.det.lc.W149
# 7 9
# mag.dcnormffp_0_82_84.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_85.det.lc.W149
# 22 25
# mag.dcnormffp_0_82_86.det.lc.W149
# 9 9
# mag.dcnormffp_0_82_87.det.lc.W149
# 5 8
# mag.dcnormffp_0_82_88.det.lc.W149
# 117 121
# mag.dcnormffp_0_82_90.det.lc.W149
# 124 124
# mag.dcnormffp_0_82_91.det.lc.W149
# 126 123
# mag.dcnormffp_0_82_93.det.lc.W149
# 217 218
# mag.dcnormffp_0_82_94.det.lc.W149
# 357 357
# mag.dcnormffp_0_82_96.det.lc.W149
# 266 266
# mag.dcnormffp_0_82_98.det.lc.W149
# 796 795
# mag.dcnormffp_0_82_99.det.lc.W149
# 951 665
# mag.dcnormffp_0_82_100.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_101.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_102.det.lc.W149
# 11 10
# mag.dcnormffp_0_82_103.det.lc.W149
# 21 23
# mag.dcnormffp_0_82_104.det.lc.W149
# 21 19
# mag.dcnormffp_0_82_105.det.lc.W149
# 13 9
# mag.dcnormffp_0_82_106.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_108.det.lc.W149
# 11 10
# mag.dcnormffp_0_82_109.det.lc.W149
# 34 32
# mag.dcnormffp_0_82_110.det.lc.W149
# 75 77
# mag.dcnormffp_0_82_111.det.lc.W149
# 41 40
# mag.dcnormffp_0_82_112.det.lc.W149
# 9 11
# mag.dcnormffp_0_82_114.det.lc.W149
# 27 24
# mag.dcnormffp_0_82_115.det.lc.W149
# 68 72
# mag.dcnormffp_0_82_116.det.lc.W149
# 17 17
# mag.dcnormffp_0_82_117.det.lc.W149
# 194 197
# mag.dcnormffp_0_82_118.det.lc.W149
# 2860 3568
# mag.dcnormffp_0_82_119.det.lc.W149
# 751 751
# mag.dcnormffp_0_82_121.det.lc.W149
# 27 30
# mag.dcnormffp_0_82_122.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_123.det.lc.W149
# 17 17
# mag.dcnormffp_0_82_124.det.lc.W149
# 8 12
# mag.dcnormffp_0_82_125.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_126.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_127.det.lc.W149
# 3 1
# mag.dcnormffp_0_82_128.det.lc.W149
# 68 68
# mag.dcnormffp_0_82_129.det.lc.W149
# 25 24
# mag.dcnormffp_0_82_130.det.lc.W149
# 15 12
# mag.dcnormffp_0_82_131.det.lc.W149
# 9 7
# mag.dcnormffp_0_82_132.det.lc.W149
# 65 63
# mag.dcnormffp_0_82_134.det.lc.W149
# 14 11
# mag.dcnormffp_0_82_135.det.lc.W149
# 372 373
# mag.dcnormffp_0_82_136.det.lc.W149
# 406 407
# mag.dcnormffp_0_82_137.det.lc.W149
# 706 1212
# mag.dcnormffp_0_82_138.det.lc.W149
# 715 1138
# mag.dcnormffp_0_82_139.det.lc.W149
# 148 150
# mag.dcnormffp_0_82_141.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_142.det.lc.W149
# 5 6
# mag.dcnormffp_0_82_143.det.lc.W149
# 7 4
# mag.dcnormffp_0_82_144.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_145.det.lc.W149
# 12 11
# mag.dcnormffp_0_82_146.det.lc.W149
# 16 14
# mag.dcnormffp_0_82_147.det.lc.W149
# 20 18
# mag.dcnormffp_0_82_148.det.lc.W149
# 3 4
# mag.dcnormffp_0_82_149.det.lc.W149
# 88 87
# mag.dcnormffp_0_82_150.det.lc.W149
# 69 71
# mag.dcnormffp_0_82_152.det.lc.W149
# 116 118
# mag.dcnormffp_0_82_154.det.lc.W149
# 190 190
# mag.dcnormffp_0_82_155.det.lc.W149
# 73 77
# mag.dcnormffp_0_82_156.det.lc.W149
# 0 45
# mag.dcnormffp_0_82_157.det.lc.W149
# 79 82
# mag.dcnormffp_0_82_158.det.lc.W149
# 204 424
# mag.dcnormffp_0_82_159.det.lc.W149
# 247 244
# mag.dcnormffp_0_82_160.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_161.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_162.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_164.det.lc.W149
# 9 8
# mag.dcnormffp_0_82_166.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_169.det.lc.W149
# 10 10
# mag.dcnormffp_0_82_170.det.lc.W149
# 183 183
# mag.dcnormffp_0_82_172.det.lc.W149
# 64 67
# mag.dcnormffp_0_82_175.det.lc.W149
# 60 58
# mag.dcnormffp_0_82_176.det.lc.W149
# 168 168
# mag.dcnormffp_0_82_177.det.lc.W149
# 98 98
# mag.dcnormffp_0_82_178.det.lc.W149
# 551 554
# mag.dcnormffp_0_82_179.det.lc.W149
# 789 789
# mag.dcnormffp_0_82_180.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_181.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_182.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_183.det.lc.W149
# 11 12
# mag.dcnormffp_0_82_184.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_186.det.lc.W149
# 9 8
# mag.dcnormffp_0_82_189.det.lc.W149
# 7 7
# mag.dcnormffp_0_82_191.det.lc.W149
# 86 87
# mag.dcnormffp_0_82_192.det.lc.W149
# 24 27
# mag.dcnormffp_0_82_193.det.lc.W149
# 60 59
# mag.dcnormffp_0_82_194.det.lc.W149
# 83 84
# mag.dcnormffp_0_82_196.det.lc.W149
# 2032 1
# mag.dcnormffp_0_82_197.det.lc.W149
# 951 951
# mag.dcnormffp_0_82_199.det.lc.W149
# 625 624
# mag.dcnormffp_0_82_201.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_202.det.lc.W149
# 6 5
# mag.dcnormffp_0_82_203.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_204.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_205.det.lc.W149
# 20 23
# mag.dcnormffp_0_82_209.det.lc.W149
# 24 26
# mag.dcnormffp_0_82_210.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_211.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_215.det.lc.W149
# 169 166
# mag.dcnormffp_0_82_216.det.lc.W149
# 139 140
# mag.dcnormffp_0_82_217.det.lc.W149
# 20 22
# mag.dcnormffp_0_82_218.det.lc.W149
# 2657 2462
# mag.dcnormffp_0_82_219.det.lc.W149
# 230 229
# mag.dcnormffp_0_82_220.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_223.det.lc.W149
# 3 4
# mag.dcnormffp_0_82_225.det.lc.W149
# 1 5
# mag.dcnormffp_0_82_226.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_227.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_228.det.lc.W149
# 34 34
# mag.dcnormffp_0_82_229.det.lc.W149
# 19 22
# mag.dcnormffp_0_82_230.det.lc.W149
# 26 26
# mag.dcnormffp_0_82_231.det.lc.W149
# 173 173
# mag.dcnormffp_0_82_232.det.lc.W149
# 102 102
# mag.dcnormffp_0_82_233.det.lc.W149
# 160 158
# mag.dcnormffp_0_82_234.det.lc.W149
# 28 29
# mag.dcnormffp_0_82_235.det.lc.W149
# 87 87
# mag.dcnormffp_0_82_237.det.lc.W149
# 149 146
# mag.dcnormffp_0_82_238.det.lc.W149
# 68 71
# mag.dcnormffp_0_82_239.det.lc.W149
# 112 116
# mag.dcnormffp_0_82_241.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_243.det.lc.W149
# 3 2
# mag.dcnormffp_0_82_245.det.lc.W149
# 61 64
# mag.dcnormffp_0_82_246.det.lc.W149
# 4 3
# mag.dcnormffp_0_82_247.det.lc.W149
# 14 16
# mag.dcnormffp_0_82_248.det.lc.W149
# 15 12
# mag.dcnormffp_0_82_249.det.lc.W149
# 158 161
# mag.dcnormffp_0_82_250.det.lc.W149
# 17 16
# mag.dcnormffp_0_82_251.det.lc.W149
# 25 22
# mag.dcnormffp_0_82_252.det.lc.W149
# 83 84
# mag.dcnormffp_0_82_253.det.lc.W149
# 79 80
# mag.dcnormffp_0_82_254.det.lc.W149
# 20 17
# mag.dcnormffp_0_82_255.det.lc.W149
# 244 240
# mag.dcnormffp_0_82_256.det.lc.W149
# 616 616
# mag.dcnormffp_0_82_257.det.lc.W149
# 254 251
# mag.dcnormffp_0_82_258.det.lc.W149
# 323 327
# mag.dcnormffp_0_82_259.det.lc.W149
# 426 423
# mag.dcnormffp_0_82_261.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_263.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_264.det.lc.W149
# 3 2
# mag.dcnormffp_0_82_265.det.lc.W149
# 2 3
# mag.dcnormffp_0_82_266.det.lc.W149
# 13 12
# mag.dcnormffp_0_82_267.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_269.det.lc.W149
# 9 10
# mag.dcnormffp_0_82_270.det.lc.W149
# 44 43
# mag.dcnormffp_0_82_272.det.lc.W149
# 246 243
# mag.dcnormffp_0_82_273.det.lc.W149
# 87 87
# mag.dcnormffp_0_82_274.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_275.det.lc.W149
# 261 260
# mag.dcnormffp_0_82_276.det.lc.W149
# 143 144
# mag.dcnormffp_0_82_277.det.lc.W149
# 189 187
# mag.dcnormffp_0_82_278.det.lc.W149
# 22 18
# mag.dcnormffp_0_82_279.det.lc.W149
# 1391 765
# mag.dcnormffp_0_82_280.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_281.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_282.det.lc.W149
# 2 0
# mag.dcnormffp_0_82_283.det.lc.W149
# 6 6
# mag.dcnormffp_0_82_284.det.lc.W149
# 92 91
# mag.dcnormffp_0_82_285.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_286.det.lc.W149
# 177 177
# mag.dcnormffp_0_82_288.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_289.det.lc.W149
# 26 30
# mag.dcnormffp_0_82_290.det.lc.W149
# 55 57
# mag.dcnormffp_0_82_291.det.lc.W149
# 159 159
# mag.dcnormffp_0_82_292.det.lc.W149
# 159 156
# mag.dcnormffp_0_82_294.det.lc.W149
# 600 580
# mag.dcnormffp_0_82_295.det.lc.W149
# 48 50
# mag.dcnormffp_0_82_296.det.lc.W149
# 251 252
# mag.dcnormffp_0_82_297.det.lc.W149
# 2955 2091
# mag.dcnormffp_0_82_298.det.lc.W149
# 318 317
# mag.dcnormffp_0_82_299.det.lc.W149
# 1055 1043
# mag.dcnormffp_0_82_300.det.lc.W149
# 3 4
# mag.dcnormffp_0_82_302.det.lc.W149
# 3 4
# mag.dcnormffp_0_82_303.det.lc.W149
# 7 9
# mag.dcnormffp_0_82_305.det.lc.W149
# 17 13
# mag.dcnormffp_0_82_306.det.lc.W149
# 2 3
# mag.dcnormffp_0_82_307.det.lc.W149
# 60 62
# mag.dcnormffp_0_82_308.det.lc.W149
# 330 330
# mag.dcnormffp_0_82_309.det.lc.W149
# 31 30
# mag.dcnormffp_0_82_310.det.lc.W149
# 12 12
# mag.dcnormffp_0_82_311.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_312.det.lc.W149
# 32 35
# mag.dcnormffp_0_82_313.det.lc.W149
# 146 143
# mag.dcnormffp_0_82_314.det.lc.W149
# 36 36
# mag.dcnormffp_0_82_315.det.lc.W149
# 271 274
# mag.dcnormffp_0_82_316.det.lc.W149
# 1101 1102
# mag.dcnormffp_0_82_317.det.lc.W149
# 616 616
# mag.dcnormffp_0_82_318.det.lc.W149
# 639 637
# mag.dcnormffp_0_82_319.det.lc.W149
# 350 351
# mag.dcnormffp_0_82_320.det.lc.W149
# 2 3
# mag.dcnormffp_0_82_321.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_322.det.lc.W149
# 14 14
# mag.dcnormffp_0_82_323.det.lc.W149
# 17 19
# mag.dcnormffp_0_82_325.det.lc.W149
# 14 16
# mag.dcnormffp_0_82_326.det.lc.W149
# 3 4
# mag.dcnormffp_0_82_327.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_328.det.lc.W149
# 27 30
# mag.dcnormffp_0_82_329.det.lc.W149
# 45 46
# mag.dcnormffp_0_82_330.det.lc.W149
# 28 32
# mag.dcnormffp_0_82_331.det.lc.W149
# 52 55
# mag.dcnormffp_0_82_332.det.lc.W149
# 52 54
# mag.dcnormffp_0_82_333.det.lc.W149
# 143 142
# mag.dcnormffp_0_82_334.det.lc.W149
# 155 106
# mag.dcnormffp_0_82_335.det.lc.W149
# 48 49
# mag.dcnormffp_0_82_336.det.lc.W149
# 331 333
# mag.dcnormffp_0_82_337.det.lc.W149
# 572 572
# mag.dcnormffp_0_82_340.det.lc.W149
# 3 2
# mag.dcnormffp_0_82_341.det.lc.W149
# 5 6
# mag.dcnormffp_0_82_343.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_344.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_345.det.lc.W149
# 6 7
# mag.dcnormffp_0_82_346.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_351.det.lc.W149
# 35 38
# mag.dcnormffp_0_82_352.det.lc.W149
# 93 93
# mag.dcnormffp_0_82_353.det.lc.W149
# 6 6
# mag.dcnormffp_0_82_354.det.lc.W149
# 103 105
# mag.dcnormffp_0_82_355.det.lc.W149
# 338 336
# mag.dcnormffp_0_82_356.det.lc.W149
# 351 348
# mag.dcnormffp_0_82_358.det.lc.W149
# 148 148
# mag.dcnormffp_0_82_359.det.lc.W149
# 15 18
# mag.dcnormffp_0_82_360.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_361.det.lc.W149
# 7 8
# mag.dcnormffp_0_82_362.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_363.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_366.det.lc.W149
# 13 12
# mag.dcnormffp_0_82_368.det.lc.W149
# 18 15
# mag.dcnormffp_0_82_369.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_370.det.lc.W149
# 62 65
# mag.dcnormffp_0_82_371.det.lc.W149
# 11 15
# mag.dcnormffp_0_82_372.det.lc.W149
# 131 131
# mag.dcnormffp_0_82_373.det.lc.W149
# 21 19
# mag.dcnormffp_0_82_374.det.lc.W149
# 65 63
# mag.dcnormffp_0_82_376.det.lc.W149
# 463 465
# mag.dcnormffp_0_82_378.det.lc.W149
# 155 189
# mag.dcnormffp_0_82_379.det.lc.W149
# 62 65
# mag.dcnormffp_0_82_380.det.lc.W149
# 5 4
# mag.dcnormffp_0_82_381.det.lc.W149
# 5 4
# mag.dcnormffp_0_82_383.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_384.det.lc.W149
# 17 17
# mag.dcnormffp_0_82_386.det.lc.W149
# 24 23
# mag.dcnormffp_0_82_388.det.lc.W149
# 16 17
# mag.dcnormffp_0_82_389.det.lc.W149
# 219 219
# mag.dcnormffp_0_82_390.det.lc.W149
# 93 92
# mag.dcnormffp_0_82_391.det.lc.W149
# 22 23
# mag.dcnormffp_0_82_392.det.lc.W149
# 14 14
# mag.dcnormffp_0_82_393.det.lc.W149
# 46 45
# mag.dcnormffp_0_82_394.det.lc.W149
# 146 147
# mag.dcnormffp_0_82_395.det.lc.W149
# 160 160
# mag.dcnormffp_0_82_396.det.lc.W149
# 31 31
# mag.dcnormffp_0_82_398.det.lc.W149
# 0 46
# mag.dcnormffp_0_82_399.det.lc.W149
# 0 942
# mag.dcnormffp_0_82_400.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_401.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_402.det.lc.W149
# 9 9
# mag.dcnormffp_0_82_403.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_404.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_409.det.lc.W149
# 36 37
# mag.dcnormffp_0_82_410.det.lc.W149
# 41 41
# mag.dcnormffp_0_82_411.det.lc.W149
# 17 14
# mag.dcnormffp_0_82_412.det.lc.W149
# 65 68
# mag.dcnormffp_0_82_413.det.lc.W149
# 21 19
# mag.dcnormffp_0_82_414.det.lc.W149
# 460 462
# mag.dcnormffp_0_82_415.det.lc.W149
# 30 30
# mag.dcnormffp_0_82_416.det.lc.W149
# 431 434
# mag.dcnormffp_0_82_418.det.lc.W149
# 316 317
# mag.dcnormffp_0_82_419.det.lc.W149
# 1448 1448
# mag.dcnormffp_0_82_420.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_421.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_422.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_423.det.lc.W149
# 12 9
# mag.dcnormffp_0_82_424.det.lc.W149
# 4 5
# mag.dcnormffp_0_82_425.det.lc.W149
# 8 7
# mag.dcnormffp_0_82_427.det.lc.W149
# 2059 1788
# mag.dcnormffp_0_82_428.det.lc.W149
# 50 49
# mag.dcnormffp_0_82_429.det.lc.W149
# 9 5
# mag.dcnormffp_0_82_430.det.lc.W149
# 41 40
# mag.dcnormffp_0_82_431.det.lc.W149
# 42 42
# mag.dcnormffp_0_82_433.det.lc.W149
# 57 58
# mag.dcnormffp_0_82_434.det.lc.W149
# 349 348
# mag.dcnormffp_0_82_435.det.lc.W149
# 38 36
# mag.dcnormffp_0_82_436.det.lc.W149
# 426 428
# mag.dcnormffp_0_82_437.det.lc.W149
# 795 791
# mag.dcnormffp_0_82_438.det.lc.W149
# 271 271
# mag.dcnormffp_0_82_439.det.lc.W149
# 230 228
# mag.dcnormffp_0_82_441.det.lc.W149
# 12 11
# mag.dcnormffp_0_82_443.det.lc.W149
# 4 5
# mag.dcnormffp_0_82_444.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_446.det.lc.W149
# 15 15
# mag.dcnormffp_0_82_447.det.lc.W149
# 29 28
# mag.dcnormffp_0_82_450.det.lc.W149
# 22 19
# mag.dcnormffp_0_82_451.det.lc.W149
# 677 674
# mag.dcnormffp_0_82_453.det.lc.W149
# 154 150
# mag.dcnormffp_0_82_454.det.lc.W149
# 17 19
# mag.dcnormffp_0_82_456.det.lc.W149
# 87 88
# mag.dcnormffp_0_82_457.det.lc.W149
# 402 403
# mag.dcnormffp_0_82_458.det.lc.W149
# 2886 2164
# mag.dcnormffp_0_82_459.det.lc.W149
# 338 335
# mag.dcnormffp_0_82_461.det.lc.W149
# 0 2
# mag.dcnormffp_0_82_462.det.lc.W149
# 7 8
# mag.dcnormffp_0_82_464.det.lc.W149
# 11 15
# mag.dcnormffp_0_82_465.det.lc.W149
# 5 4
# mag.dcnormffp_0_82_466.det.lc.W149
# 9 8
# mag.dcnormffp_0_82_467.det.lc.W149
# 18 18
# mag.dcnormffp_0_82_469.det.lc.W149
# 16 16
# mag.dcnormffp_0_82_470.det.lc.W149
# 26 26
# mag.dcnormffp_0_82_471.det.lc.W149
# 87 86
# mag.dcnormffp_0_82_472.det.lc.W149
# 51 51
# mag.dcnormffp_0_82_473.det.lc.W149
# 145 145
# mag.dcnormffp_0_82_476.det.lc.W149
# 842 546
# mag.dcnormffp_0_82_477.det.lc.W149
# 274 273
# mag.dcnormffp_0_82_478.det.lc.W149
# 329 332
# mag.dcnormffp_0_82_480.det.lc.W149
# 3 2
# mag.dcnormffp_0_82_481.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_482.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_483.det.lc.W149
# 263 261
# mag.dcnormffp_0_82_484.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_485.det.lc.W149
# 17 15
# mag.dcnormffp_0_82_486.det.lc.W149
# 144 144
# mag.dcnormffp_0_82_489.det.lc.W149
# 186 186
# mag.dcnormffp_0_82_490.det.lc.W149
# 14 12
# mag.dcnormffp_0_82_491.det.lc.W149
# 175 173
# mag.dcnormffp_0_82_492.det.lc.W149
# 199 196
# mag.dcnormffp_0_82_493.det.lc.W149
# 138 138
# mag.dcnormffp_0_82_494.det.lc.W149
# 27 30
# mag.dcnormffp_0_82_495.det.lc.W149
# 68 72
# mag.dcnormffp_0_82_496.det.lc.W149
# 305 304
# mag.dcnormffp_0_82_497.det.lc.W149
# 118 121
# mag.dcnormffp_0_82_498.det.lc.W149
# 485 484
# mag.dcnormffp_0_82_500.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_501.det.lc.W149
# 5 4
# mag.dcnormffp_0_82_502.det.lc.W149
# 13 13
# mag.dcnormffp_0_82_503.det.lc.W149
# 4 5
# mag.dcnormffp_0_82_504.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_505.det.lc.W149
# 8 10
# mag.dcnormffp_0_82_506.det.lc.W149
# 34 34
# mag.dcnormffp_0_82_508.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_509.det.lc.W149
# 4 5
# mag.dcnormffp_0_82_510.det.lc.W149
# 31 31
# mag.dcnormffp_0_82_511.det.lc.W149
# 5 3
# mag.dcnormffp_0_82_512.det.lc.W149
# 103 106
# mag.dcnormffp_0_82_513.det.lc.W149
# 84 85
# mag.dcnormffp_0_82_515.det.lc.W149
# 34 37
# mag.dcnormffp_0_82_516.det.lc.W149
# 100 101
# mag.dcnormffp_0_82_517.det.lc.W149
# 111 112
# mag.dcnormffp_0_82_518.det.lc.W149
# 306 303
# mag.dcnormffp_0_82_519.det.lc.W149
# 160 158
# mag.dcnormffp_0_82_520.det.lc.W149
# 5 6
# mag.dcnormffp_0_82_521.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_522.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_523.det.lc.W149
# 20 19
# mag.dcnormffp_0_82_524.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_525.det.lc.W149
# 77 77
# mag.dcnormffp_0_82_526.det.lc.W149
# 6 5
# mag.dcnormffp_0_82_527.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_529.det.lc.W149
# 10 11
# mag.dcnormffp_0_82_530.det.lc.W149
# 391 394
# mag.dcnormffp_0_82_531.det.lc.W149
# 28 28
# mag.dcnormffp_0_82_533.det.lc.W149
# 217 217
# mag.dcnormffp_0_82_534.det.lc.W149
# 36 36
# mag.dcnormffp_0_82_535.det.lc.W149
# 85 86
# mag.dcnormffp_0_82_536.det.lc.W149
# 1349 1
# mag.dcnormffp_0_82_537.det.lc.W149
# 1972 1974
# mag.dcnormffp_0_82_538.det.lc.W149
# 425 424
# mag.dcnormffp_0_82_539.det.lc.W149
# 204 203
# mag.dcnormffp_0_82_541.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_542.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_543.det.lc.W149
# 8 8
# mag.dcnormffp_0_82_544.det.lc.W149
# 1 3
# mag.dcnormffp_0_82_545.det.lc.W149
# 4 7
# mag.dcnormffp_0_82_546.det.lc.W149
# 8 7
# mag.dcnormffp_0_82_547.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_549.det.lc.W149
# 4 3
# mag.dcnormffp_0_82_550.det.lc.W149
# 255 252
# mag.dcnormffp_0_82_551.det.lc.W149
# 8 10
# mag.dcnormffp_0_82_552.det.lc.W149
# 404 401
# mag.dcnormffp_0_82_554.det.lc.W149
# 110 108
# mag.dcnormffp_0_82_555.det.lc.W149
# 39 38
# mag.dcnormffp_0_82_557.det.lc.W149
# 656 599
# mag.dcnormffp_0_82_558.det.lc.W149
# 440 437
# mag.dcnormffp_0_82_559.det.lc.W149
# 264 0
# mag.dcnormffp_0_82_560.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_563.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_564.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_565.det.lc.W149
# 15 14
# mag.dcnormffp_0_82_566.det.lc.W149
# 16 20
# mag.dcnormffp_0_82_567.det.lc.W149
# 29 26
# mag.dcnormffp_0_82_568.det.lc.W149
# 9 8
# mag.dcnormffp_0_82_569.det.lc.W149
# 31 28
# mag.dcnormffp_0_82_570.det.lc.W149
# 125 122
# mag.dcnormffp_0_82_571.det.lc.W149
# 24 21
# mag.dcnormffp_0_82_572.det.lc.W149
# 68 72
# mag.dcnormffp_0_82_573.det.lc.W149
# 259 260
# mag.dcnormffp_0_82_574.det.lc.W149
# 6 6
# mag.dcnormffp_0_82_575.det.lc.W149
# 46 47
# mag.dcnormffp_0_82_576.det.lc.W149
# 284 286
# mag.dcnormffp_0_82_577.det.lc.W149
# 105 109
# mag.dcnormffp_0_82_578.det.lc.W149
# 469 468
# mag.dcnormffp_0_82_579.det.lc.W149
# 418 420
# mag.dcnormffp_0_82_581.det.lc.W149
# 14 14
# mag.dcnormffp_0_82_582.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_584.det.lc.W149
# 7 8
# mag.dcnormffp_0_82_585.det.lc.W149
# 16 16
# mag.dcnormffp_0_82_586.det.lc.W149
# 93 97
# mag.dcnormffp_0_82_587.det.lc.W149
# 41 40
# mag.dcnormffp_0_82_588.det.lc.W149
# 71 75
# mag.dcnormffp_0_82_589.det.lc.W149
# 30 26
# mag.dcnormffp_0_82_590.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_591.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_593.det.lc.W149
# 422 419
# mag.dcnormffp_0_82_594.det.lc.W149
# 435 431
# mag.dcnormffp_0_82_595.det.lc.W149
# 26 23
# mag.dcnormffp_0_82_596.det.lc.W149
# 288 286
# mag.dcnormffp_0_82_597.det.lc.W149
# 509 509
# mag.dcnormffp_0_82_598.det.lc.W149
# 199 198
# mag.dcnormffp_0_82_599.det.lc.W149
# 104 107
# mag.dcnormffp_0_82_600.det.lc.W149
# 20 22
# mag.dcnormffp_0_82_601.det.lc.W149
# 7 7
# mag.dcnormffp_0_82_602.det.lc.W149
# 4 3
# mag.dcnormffp_0_82_603.det.lc.W149
# 12 14
# mag.dcnormffp_0_82_604.det.lc.W149
# 7 6
# mag.dcnormffp_0_82_605.det.lc.W149
# 9 10
# mag.dcnormffp_0_82_606.det.lc.W149
# 8 10
# mag.dcnormffp_0_82_607.det.lc.W149
# 4 5
# mag.dcnormffp_0_82_608.det.lc.W149
# 232 233
# mag.dcnormffp_0_82_609.det.lc.W149
# 86 85
# mag.dcnormffp_0_82_610.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_612.det.lc.W149
# 51 0
# mag.dcnormffp_0_82_613.det.lc.W149
# 43 42
# mag.dcnormffp_0_82_615.det.lc.W149
# 74 70
# mag.dcnormffp_0_82_616.det.lc.W149
# 1219 1223
# mag.dcnormffp_0_82_617.det.lc.W149
# 402 401
# mag.dcnormffp_0_82_618.det.lc.W149
# 211 212
# mag.dcnormffp_0_82_619.det.lc.W149
# 28 25
# mag.dcnormffp_0_82_621.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_623.det.lc.W149
# 5 4
# mag.dcnormffp_0_82_624.det.lc.W149
# 10 9
# mag.dcnormffp_0_82_625.det.lc.W149
# 6 7
# mag.dcnormffp_0_82_627.det.lc.W149
# 13 11
# mag.dcnormffp_0_82_628.det.lc.W149
# 44 45
# mag.dcnormffp_0_82_629.det.lc.W149
# 228 231
# mag.dcnormffp_0_82_630.det.lc.W149
# 85 85
# mag.dcnormffp_0_82_631.det.lc.W149
# 143 140
# mag.dcnormffp_0_82_632.det.lc.W149
# 35 34
# mag.dcnormffp_0_82_634.det.lc.W149
# 168 170
# mag.dcnormffp_0_82_636.det.lc.W149
# 166 162
# mag.dcnormffp_0_82_637.det.lc.W149
# 300 299
# mag.dcnormffp_0_82_638.det.lc.W149
# 1267 1265
# mag.dcnormffp_0_82_639.det.lc.W149
# 1242 1242
# mag.dcnormffp_0_82_641.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_642.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_644.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_645.det.lc.W149
# 27 25
# mag.dcnormffp_0_82_649.det.lc.W149
# 3 2
# mag.dcnormffp_0_82_650.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_651.det.lc.W149
# 23 21
# mag.dcnormffp_0_82_652.det.lc.W149
# 66 68
# mag.dcnormffp_0_82_653.det.lc.W149
# 125 126
# mag.dcnormffp_0_82_654.det.lc.W149
# 212 213
# mag.dcnormffp_0_82_655.det.lc.W149
# 277 280
# mag.dcnormffp_0_82_657.det.lc.W149
# 1072 1072
# mag.dcnormffp_0_82_658.det.lc.W149
# 1703 1700
# mag.dcnormffp_0_82_659.det.lc.W149
# 139 139
# mag.dcnormffp_0_82_661.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_662.det.lc.W149
# 21 23
# mag.dcnormffp_0_82_663.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_664.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_665.det.lc.W149
# 5 7
# mag.dcnormffp_0_82_666.det.lc.W149
# 17 13
# mag.dcnormffp_0_82_667.det.lc.W149
# 18 16
# mag.dcnormffp_0_82_668.det.lc.W149
# 99 100
# mag.dcnormffp_0_82_669.det.lc.W149
# 81 81
# mag.dcnormffp_0_82_670.det.lc.W149
# 118 121
# mag.dcnormffp_0_82_671.det.lc.W149
# 137 137
# mag.dcnormffp_0_82_672.det.lc.W149
# 19 15
# mag.dcnormffp_0_82_673.det.lc.W149
# 786 267
# mag.dcnormffp_0_82_674.det.lc.W149
# 342 340
# mag.dcnormffp_0_82_675.det.lc.W149
# 28 25
# mag.dcnormffp_0_82_676.det.lc.W149
# 85 84
# mag.dcnormffp_0_82_677.det.lc.W149
# 394 391
# mag.dcnormffp_0_82_678.det.lc.W149
# 1423 1423
# mag.dcnormffp_0_82_679.det.lc.W149
# 1314 1316
# mag.dcnormffp_0_82_681.det.lc.W149
# 13 14
# mag.dcnormffp_0_82_683.det.lc.W149
# 22 19
# mag.dcnormffp_0_82_684.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_687.det.lc.W149
# 6 5
# mag.dcnormffp_0_82_688.det.lc.W149
# 58 55
# mag.dcnormffp_0_82_689.det.lc.W149
# 21 19
# mag.dcnormffp_0_82_690.det.lc.W149
# 8 8
# mag.dcnormffp_0_82_691.det.lc.W149
# 17 15
# mag.dcnormffp_0_82_692.det.lc.W149
# 73 70
# mag.dcnormffp_0_82_693.det.lc.W149
# 45 46
# mag.dcnormffp_0_82_694.det.lc.W149
# 35 33
# mag.dcnormffp_0_82_695.det.lc.W149
# 46 47
# mag.dcnormffp_0_82_697.det.lc.W149
# 140 140
# mag.dcnormffp_0_82_698.det.lc.W149
# 67 63
# mag.dcnormffp_0_82_699.det.lc.W149
# 953 951
# mag.dcnormffp_0_82_700.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_701.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_703.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_704.det.lc.W149
# 9 9
# mag.dcnormffp_0_82_707.det.lc.W149
# 2 3
# mag.dcnormffp_0_82_709.det.lc.W149
# 24 27
# mag.dcnormffp_0_82_710.det.lc.W149
# 14 18
# mag.dcnormffp_0_82_711.det.lc.W149
# 51 51
# mag.dcnormffp_0_82_712.det.lc.W149
# 35 120
# mag.dcnormffp_0_82_713.det.lc.W149
# 127 128
# mag.dcnormffp_0_82_714.det.lc.W149
# 217 218
# mag.dcnormffp_0_82_715.det.lc.W149
# 537 540
# mag.dcnormffp_0_82_718.det.lc.W149
# 58 59
# mag.dcnormffp_0_82_719.det.lc.W149
# 556 639
# mag.dcnormffp_0_82_722.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_725.det.lc.W149
# 22 20
# mag.dcnormffp_0_82_726.det.lc.W149
# 7 8
# mag.dcnormffp_0_82_727.det.lc.W149
# 28 25
# mag.dcnormffp_0_82_728.det.lc.W149
# 4 3
# mag.dcnormffp_0_82_731.det.lc.W149
# 334 331
# mag.dcnormffp_0_82_732.det.lc.W149
# 167 166
# mag.dcnormffp_0_82_733.det.lc.W149
# 85 85
# mag.dcnormffp_0_82_734.det.lc.W149
# 189 189
# mag.dcnormffp_0_82_735.det.lc.W149
# 64 68
# mag.dcnormffp_0_82_736.det.lc.W149
# 96 96
# mag.dcnormffp_0_82_737.det.lc.W149
# 107 104
# mag.dcnormffp_0_82_738.det.lc.W149
# 415 413
# mag.dcnormffp_0_82_739.det.lc.W149
# 556 513
# mag.dcnormffp_0_82_740.det.lc.W149
# 7 7
# mag.dcnormffp_0_82_741.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_742.det.lc.W149
# 12 14
# mag.dcnormffp_0_82_744.det.lc.W149
# 7 7
# mag.dcnormffp_0_82_745.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_746.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_748.det.lc.W149
# 62 65
# mag.dcnormffp_0_82_749.det.lc.W149
# 12 13
# mag.dcnormffp_0_82_751.det.lc.W149
# 22 25
# mag.dcnormffp_0_82_752.det.lc.W149
# 36 36
# mag.dcnormffp_0_82_753.det.lc.W149
# 34 33
# mag.dcnormffp_0_82_754.det.lc.W149
# 15 17
# mag.dcnormffp_0_82_756.det.lc.W149
# 751 0
# mag.dcnormffp_0_82_757.det.lc.W149
# 263 265
# mag.dcnormffp_0_82_758.det.lc.W149
# 390 386
# mag.dcnormffp_0_82_761.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_762.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_765.det.lc.W149
# 7 7
# mag.dcnormffp_0_82_766.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_768.det.lc.W149
# 67 63
# mag.dcnormffp_0_82_770.det.lc.W149
# 163 167
# mag.dcnormffp_0_82_771.det.lc.W149
# 13 15
# mag.dcnormffp_0_82_772.det.lc.W149
# 127 130
# mag.dcnormffp_0_82_773.det.lc.W149
# 83 80
# mag.dcnormffp_0_82_774.det.lc.W149
# 162 162
# mag.dcnormffp_0_82_775.det.lc.W149
# 301 300
# mag.dcnormffp_0_82_776.det.lc.W149
# 475 474
# mag.dcnormffp_0_82_777.det.lc.W149
# 404 130
# mag.dcnormffp_0_82_778.det.lc.W149
# 268 268
# mag.dcnormffp_0_82_779.det.lc.W149
# 1418 1418
# mag.dcnormffp_0_82_780.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_781.det.lc.W149
# 3 2
# mag.dcnormffp_0_82_782.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_783.det.lc.W149
# 10 9
# mag.dcnormffp_0_82_784.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_785.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_786.det.lc.W149
# 10 14
# mag.dcnormffp_0_82_787.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_789.det.lc.W149
# 21 18
# mag.dcnormffp_0_82_790.det.lc.W149
# 361 359
# mag.dcnormffp_0_82_791.det.lc.W149
# 69 66
# mag.dcnormffp_0_82_792.det.lc.W149
# 7 4
# mag.dcnormffp_0_82_793.det.lc.W149
# 13 16
# mag.dcnormffp_0_82_794.det.lc.W149
# 161 160
# mag.dcnormffp_0_82_797.det.lc.W149
# 1822 2009
# mag.dcnormffp_0_82_798.det.lc.W149
# 296 295
# mag.dcnormffp_0_82_799.det.lc.W149
# 469 466
# mag.dcnormffp_0_82_801.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_804.det.lc.W149
# 0 2
# mag.dcnormffp_0_82_805.det.lc.W149
# 14 14
# mag.dcnormffp_0_82_807.det.lc.W149
# 9 11
# mag.dcnormffp_0_82_808.det.lc.W149
# 37 37
# mag.dcnormffp_0_82_809.det.lc.W149
# 52 54
# mag.dcnormffp_0_82_810.det.lc.W149
# 78 78
# mag.dcnormffp_0_82_811.det.lc.W149
# 24 21
# mag.dcnormffp_0_82_814.det.lc.W149
# 199 202
# mag.dcnormffp_0_82_815.det.lc.W149
# 230 227
# mag.dcnormffp_0_82_817.det.lc.W149
# 784 1130
# mag.dcnormffp_0_82_818.det.lc.W149
# 206 203
# mag.dcnormffp_0_82_819.det.lc.W149
# 584 587
# mag.dcnormffp_0_82_820.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_821.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_823.det.lc.W149
# 8 12
# mag.dcnormffp_0_82_826.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_827.det.lc.W149
# 7 8
# mag.dcnormffp_0_82_828.det.lc.W149
# 32 32
# mag.dcnormffp_0_82_829.det.lc.W149
# 37 36
# mag.dcnormffp_0_82_830.det.lc.W149
# 37 34
# mag.dcnormffp_0_82_831.det.lc.W149
# 9 10
# mag.dcnormffp_0_82_832.det.lc.W149
# 116 112
# mag.dcnormffp_0_82_834.det.lc.W149
# 92 91
# mag.dcnormffp_0_82_835.det.lc.W149
# 232 231
# mag.dcnormffp_0_82_836.det.lc.W149
# 343 339
# mag.dcnormffp_0_82_837.det.lc.W149
# 2359 772
# mag.dcnormffp_0_82_838.det.lc.W149
# 34 35
# mag.dcnormffp_0_82_839.det.lc.W149
# 249 245
# mag.dcnormffp_0_82_842.det.lc.W149
# 35 35
# mag.dcnormffp_0_82_846.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_847.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_848.det.lc.W149
# 7 7
# mag.dcnormffp_0_82_849.det.lc.W149
# 28 31
# mag.dcnormffp_0_82_850.det.lc.W149
# 103 102
# mag.dcnormffp_0_82_853.det.lc.W149
# 28 24
# mag.dcnormffp_0_82_854.det.lc.W149
# 91 91
# mag.dcnormffp_0_82_855.det.lc.W149
# 276 273
# mag.dcnormffp_0_82_856.det.lc.W149
# 385 387
# mag.dcnormffp_0_82_857.det.lc.W149
# 176 176
# mag.dcnormffp_0_82_859.det.lc.W149
# 686 688
# mag.dcnormffp_0_82_861.det.lc.W149
# 4 3
# mag.dcnormffp_0_82_862.det.lc.W149
# 13 14
# mag.dcnormffp_0_82_863.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_864.det.lc.W149
# 5 6
# mag.dcnormffp_0_82_865.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_867.det.lc.W149
# 33 33
# mag.dcnormffp_0_82_868.det.lc.W149
# 22 21
# mag.dcnormffp_0_82_870.det.lc.W149
# 15 15
# mag.dcnormffp_0_82_871.det.lc.W149
# 90 89
# mag.dcnormffp_0_82_872.det.lc.W149
# 52 52
# mag.dcnormffp_0_82_873.det.lc.W149
# 51 51
# mag.dcnormffp_0_82_875.det.lc.W149
# 851 854
# mag.dcnormffp_0_82_876.det.lc.W149
# 235 237
# mag.dcnormffp_0_82_877.det.lc.W149
# 60 57
# mag.dcnormffp_0_82_878.det.lc.W149
# 643 646
# mag.dcnormffp_0_82_879.det.lc.W149
# 157 154
# mag.dcnormffp_0_82_880.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_881.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_882.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_883.det.lc.W149
# 68 70
# mag.dcnormffp_0_82_884.det.lc.W149
# 17 15
# mag.dcnormffp_0_82_886.det.lc.W149
# 1 4
# mag.dcnormffp_0_82_887.det.lc.W149
# 3 7
# mag.dcnormffp_0_82_888.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_889.det.lc.W149
# 42 43
# mag.dcnormffp_0_82_890.det.lc.W149
# 44 45
# mag.dcnormffp_0_82_891.det.lc.W149
# 45 44
# mag.dcnormffp_0_82_892.det.lc.W149
# 48 49
# mag.dcnormffp_0_82_893.det.lc.W149
# 37 34
# mag.dcnormffp_0_82_894.det.lc.W149
# 126 125
# mag.dcnormffp_0_82_896.det.lc.W149
# 162 163
# mag.dcnormffp_0_82_897.det.lc.W149
# 31 35
# mag.dcnormffp_0_82_898.det.lc.W149
# 163 160
# mag.dcnormffp_0_82_899.det.lc.W149
# 273 273
# mag.dcnormffp_0_82_900.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_901.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_902.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_903.det.lc.W149
# 15 16
# mag.dcnormffp_0_82_904.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_905.det.lc.W149
# 4 6
# mag.dcnormffp_0_82_906.det.lc.W149
# 9 8
# mag.dcnormffp_0_82_907.det.lc.W149
# 53 54
# mag.dcnormffp_0_82_908.det.lc.W149
# 58 59
# mag.dcnormffp_0_82_909.det.lc.W149
# 5 4
# mag.dcnormffp_0_82_910.det.lc.W149
# 55 57
# mag.dcnormffp_0_82_911.det.lc.W149
# 90 89
# mag.dcnormffp_0_82_912.det.lc.W149
# 313 312
# mag.dcnormffp_0_82_913.det.lc.W149
# 71 72
# mag.dcnormffp_0_82_914.det.lc.W149
# 23 24
# mag.dcnormffp_0_82_915.det.lc.W149
# 8 7
# mag.dcnormffp_0_82_916.det.lc.W149
# 265 265
# mag.dcnormffp_0_82_917.det.lc.W149
# 53 55
# mag.dcnormffp_0_82_919.det.lc.W149
# 407 406
# mag.dcnormffp_0_82_920.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_921.det.lc.W149
# 4 6
# mag.dcnormffp_0_82_922.det.lc.W149
# 3 2
# mag.dcnormffp_0_82_923.det.lc.W149
# 4 3
# mag.dcnormffp_0_82_924.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_926.det.lc.W149
# 11 10
# mag.dcnormffp_0_82_927.det.lc.W149
# 13 14
# mag.dcnormffp_0_82_929.det.lc.W149
# 255 256
# mag.dcnormffp_0_82_930.det.lc.W149
# 55 58
# mag.dcnormffp_0_82_931.det.lc.W149
# 165 162
# mag.dcnormffp_0_82_932.det.lc.W149
# 113 112
# mag.dcnormffp_0_82_933.det.lc.W149
# 50 51
# mag.dcnormffp_0_82_934.det.lc.W149
# 83 84
# mag.dcnormffp_0_82_936.det.lc.W149
# 100 97
# mag.dcnormffp_0_82_938.det.lc.W149
# 1271 1268
# mag.dcnormffp_0_82_939.det.lc.W149
# 607 616
# mag.dcnormffp_0_82_940.det.lc.W149
# 7 6
# mag.dcnormffp_0_82_941.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_942.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_943.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_944.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_945.det.lc.W149
# 31 30
# mag.dcnormffp_0_82_946.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_947.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_948.det.lc.W149
# 50 50
# mag.dcnormffp_0_82_949.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_950.det.lc.W149
# 23 26
# mag.dcnormffp_0_82_951.det.lc.W149
# 72 71
# mag.dcnormffp_0_82_952.det.lc.W149
# 11 13
# mag.dcnormffp_0_82_953.det.lc.W149
# 151 148
# mag.dcnormffp_0_82_954.det.lc.W149
# 238 241
# mag.dcnormffp_0_82_955.det.lc.W149
# 90 89
# mag.dcnormffp_0_82_956.det.lc.W149
# 232 234
# mag.dcnormffp_0_82_957.det.lc.W149
# 301 302
# mag.dcnormffp_0_82_958.det.lc.W149
# 2300 2300
# mag.dcnormffp_0_82_959.det.lc.W149
# 943 945
# mag.dcnormffp_0_82_960.det.lc.W149
# 3 4
# mag.dcnormffp_0_82_961.det.lc.W149
# 28 27
# mag.dcnormffp_0_82_962.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_963.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_964.det.lc.W149
# 3 2
# mag.dcnormffp_0_82_965.det.lc.W149
# 27 30
# mag.dcnormffp_0_82_967.det.lc.W149
# 23 25
# mag.dcnormffp_0_82_968.det.lc.W149
# 58 55
# mag.dcnormffp_0_82_969.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_970.det.lc.W149
# 16 17
# mag.dcnormffp_0_82_971.det.lc.W149
# 80 77
# mag.dcnormffp_0_82_973.det.lc.W149
# 96 99
# mag.dcnormffp_0_82_976.det.lc.W149
# 513 513
# mag.dcnormffp_0_82_977.det.lc.W149
# 582 581
# mag.dcnormffp_0_82_979.det.lc.W149
# 127 124
# mag.dcnormffp_0_82_980.det.lc.W149
# 3 2
# mag.dcnormffp_0_82_981.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_982.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_983.det.lc.W149
# 3 2
# mag.dcnormffp_0_82_984.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_985.det.lc.W149
# 11 8
# mag.dcnormffp_0_82_986.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_987.det.lc.W149
# 150 154
# mag.dcnormffp_0_82_988.det.lc.W149
# 35 37
# mag.dcnormffp_0_82_989.det.lc.W149
# 17 20
# mag.dcnormffp_0_82_990.det.lc.W149
# 34 32
# mag.dcnormffp_0_82_991.det.lc.W149
# 9 6
# mag.dcnormffp_0_82_992.det.lc.W149
# 133 132
# mag.dcnormffp_0_82_993.det.lc.W149
# 264 264
# mag.dcnormffp_0_82_995.det.lc.W149
# 187 190
# mag.dcnormffp_0_82_996.det.lc.W149
# 802 803
# mag.dcnormffp_0_82_997.det.lc.W149
# 250 249
# mag.dcnormffp_0_82_998.det.lc.W149
# 342 340
# mag.dcnormffp_0_82_999.det.lc.W149
# 85 84
# mag.dcnormffp_0_82_1000.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_1001.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_1002.det.lc.W149
# 8 6
# mag.dcnormffp_0_82_1004.det.lc.W149
# 23 22
# mag.dcnormffp_0_82_1005.det.lc.W149
# 5 4
# mag.dcnormffp_0_82_1007.det.lc.W149
# 6 5
# mag.dcnormffp_0_82_1008.det.lc.W149
# 99 100
# mag.dcnormffp_0_82_1009.det.lc.W149
# 17 17
# mag.dcnormffp_0_82_1010.det.lc.W149
# 38 36
# mag.dcnormffp_0_82_1012.det.lc.W149
# 172 169
# mag.dcnormffp_0_82_1013.det.lc.W149
# 25 26
# mag.dcnormffp_0_82_1014.det.lc.W149
# 1272 1001
# mag.dcnormffp_0_82_1015.det.lc.W149
# 90 91
# mag.dcnormffp_0_82_1017.det.lc.W149
# 45 45
# mag.dcnormffp_0_82_1018.det.lc.W149
# 0 444
# mag.dcnormffp_0_82_1020.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1021.det.lc.W149
# 4 5
# mag.dcnormffp_0_82_1022.det.lc.W149
# 7 7
# mag.dcnormffp_0_82_1023.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_1024.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_1025.det.lc.W149
# 20 19
# mag.dcnormffp_0_82_1026.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1027.det.lc.W149
# 131 131
# mag.dcnormffp_0_82_1028.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1029.det.lc.W149
# 42 41
# mag.dcnormffp_0_82_1030.det.lc.W149
# 70 66
# mag.dcnormffp_0_82_1032.det.lc.W149
# 232 231
# mag.dcnormffp_0_82_1033.det.lc.W149
# 102 104
# mag.dcnormffp_0_82_1034.det.lc.W149
# 130 128
# mag.dcnormffp_0_82_1035.det.lc.W149
# 442 442
# mag.dcnormffp_0_82_1037.det.lc.W149
# 175 356
# mag.dcnormffp_0_82_1038.det.lc.W149
# 65 68
# mag.dcnormffp_0_82_1039.det.lc.W149
# 95 96
# mag.dcnormffp_0_82_1040.det.lc.W149
# 3 5
# mag.dcnormffp_0_82_1041.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1042.det.lc.W149
# 5 7
# mag.dcnormffp_0_82_1043.det.lc.W149
# 10 10
# mag.dcnormffp_0_82_1044.det.lc.W149
# 22 25
# mag.dcnormffp_0_82_1045.det.lc.W149
# 8 8
# mag.dcnormffp_0_82_1046.det.lc.W149
# 136 135
# mag.dcnormffp_0_82_1047.det.lc.W149
# 17 20
# mag.dcnormffp_0_82_1048.det.lc.W149
# 13 9
# mag.dcnormffp_0_82_1049.det.lc.W149
# 44 45
# mag.dcnormffp_0_82_1051.det.lc.W149
# 69 66
# mag.dcnormffp_0_82_1052.det.lc.W149
# 3 6
# mag.dcnormffp_0_82_1053.det.lc.W149
# 156 153
# mag.dcnormffp_0_82_1054.det.lc.W149
# 141 141
# mag.dcnormffp_0_82_1055.det.lc.W149
# 56 57
# mag.dcnormffp_0_82_1056.det.lc.W149
# 28 24
# mag.dcnormffp_0_82_1057.det.lc.W149
# 263 261
# mag.dcnormffp_0_82_1058.det.lc.W149
# 32 6396
# mag.dcnormffp_0_82_1059.det.lc.W149
# 498 501
# mag.dcnormffp_0_82_1061.det.lc.W149
# 4 1
# mag.dcnormffp_0_82_1062.det.lc.W149
# 26 29
# mag.dcnormffp_0_82_1063.det.lc.W149
# 12 16
# mag.dcnormffp_0_82_1064.det.lc.W149
# 15 12
# mag.dcnormffp_0_82_1066.det.lc.W149
# 6 5
# mag.dcnormffp_0_82_1067.det.lc.W149
# 4 3
# mag.dcnormffp_0_82_1068.det.lc.W149
# 30 0
# mag.dcnormffp_0_82_1069.det.lc.W149
# 41 41
# mag.dcnormffp_0_82_1070.det.lc.W149
# 138 139
# mag.dcnormffp_0_82_1071.det.lc.W149
# 236 238
# mag.dcnormffp_0_82_1073.det.lc.W149
# 124 122
# mag.dcnormffp_0_82_1075.det.lc.W149
# 64 68
# mag.dcnormffp_0_82_1076.det.lc.W149
# 122 122
# mag.dcnormffp_0_82_1077.det.lc.W149
# 1911 1913
# mag.dcnormffp_0_82_1078.det.lc.W149
# 75 76
# mag.dcnormffp_0_82_1079.det.lc.W149
# 48 42
# mag.dcnormffp_0_82_1080.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_1081.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1082.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_1083.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_1084.det.lc.W149
# 92 0
# mag.dcnormffp_0_82_1085.det.lc.W149
# 9 9
# mag.dcnormffp_0_82_1086.det.lc.W149
# 5 4
# mag.dcnormffp_0_82_1087.det.lc.W149
# 25 26
# mag.dcnormffp_0_82_1088.det.lc.W149
# 6 6
# mag.dcnormffp_0_82_1089.det.lc.W149
# 18 14
# mag.dcnormffp_0_82_1090.det.lc.W149
# 9 8
# mag.dcnormffp_0_82_1092.det.lc.W149
# 125 126
# mag.dcnormffp_0_82_1094.det.lc.W149
# 87 87
# mag.dcnormffp_0_82_1095.det.lc.W149
# 44 52
# mag.dcnormffp_0_82_1096.det.lc.W149
# 69 66
# mag.dcnormffp_0_82_1097.det.lc.W149
# 109 822
# mag.dcnormffp_0_82_1098.det.lc.W149
# 456 458
# mag.dcnormffp_0_82_1099.det.lc.W149
# 350 351
# mag.dcnormffp_0_82_1102.det.lc.W149
# 8 7
# mag.dcnormffp_0_82_1103.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_1104.det.lc.W149
# 2 3
# mag.dcnormffp_0_82_1106.det.lc.W149
# 4 3
# mag.dcnormffp_0_82_1107.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_1108.det.lc.W149
# 37 38
# mag.dcnormffp_0_82_1109.det.lc.W149
# 10 12
# mag.dcnormffp_0_82_1110.det.lc.W149
# 36 35
# mag.dcnormffp_0_82_1111.det.lc.W149
# 5 3
# mag.dcnormffp_0_82_1112.det.lc.W149
# 19 19
# mag.dcnormffp_0_82_1113.det.lc.W149
# 60 58
# mag.dcnormffp_0_82_1114.det.lc.W149
# 182 0
# mag.dcnormffp_0_82_1116.det.lc.W149
# 61 59
# mag.dcnormffp_0_82_1117.det.lc.W149
# 115 118
# mag.dcnormffp_0_82_1118.det.lc.W149
# 358 358
# mag.dcnormffp_0_82_1119.det.lc.W149
# 425 423
# mag.dcnormffp_0_82_1120.det.lc.W149
# 11 12
# mag.dcnormffp_0_82_1121.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_1122.det.lc.W149
# 0 2
# mag.dcnormffp_0_82_1123.det.lc.W149
# 10 7
# mag.dcnormffp_0_82_1125.det.lc.W149
# 24 22
# mag.dcnormffp_0_82_1126.det.lc.W149
# 26 26
# mag.dcnormffp_0_82_1127.det.lc.W149
# 17 13
# mag.dcnormffp_0_82_1128.det.lc.W149
# 25 25
# mag.dcnormffp_0_82_1129.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1130.det.lc.W149
# 9 6
# mag.dcnormffp_0_82_1132.det.lc.W149
# 96 96
# mag.dcnormffp_0_82_1134.det.lc.W149
# 38 37
# mag.dcnormffp_0_82_1135.det.lc.W149
# 127 128
# mag.dcnormffp_0_82_1137.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_1138.det.lc.W149
# 602 602
# mag.dcnormffp_0_82_1139.det.lc.W149
# 173 173
# mag.dcnormffp_0_82_1140.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_1141.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1142.det.lc.W149
# 6 6
# mag.dcnormffp_0_82_1143.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_1144.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1145.det.lc.W149
# 55 55
# mag.dcnormffp_0_82_1147.det.lc.W149
# 26 29
# mag.dcnormffp_0_82_1149.det.lc.W149
# 22 21
# mag.dcnormffp_0_82_1150.det.lc.W149
# 28 27
# mag.dcnormffp_0_82_1151.det.lc.W149
# 300 298
# mag.dcnormffp_0_82_1153.det.lc.W149
# 57 57
# mag.dcnormffp_0_82_1155.det.lc.W149
# 38 36
# mag.dcnormffp_0_82_1156.det.lc.W149
# 189 187
# mag.dcnormffp_0_82_1157.det.lc.W149
# 22 20
# mag.dcnormffp_0_82_1158.det.lc.W149
# 61 63
# mag.dcnormffp_0_82_1159.det.lc.W149
# 1695 2565
# mag.dcnormffp_0_82_1160.det.lc.W149
# 3 2
# mag.dcnormffp_0_82_1161.det.lc.W149
# 3 1
# mag.dcnormffp_0_82_1162.det.lc.W149
# 7 9
# mag.dcnormffp_0_82_1163.det.lc.W149
# 8 9
# mag.dcnormffp_0_82_1164.det.lc.W149
# 98 99
# mag.dcnormffp_0_82_1165.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_1166.det.lc.W149
# 11 10
# mag.dcnormffp_0_82_1167.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1168.det.lc.W149
# 10 10
# mag.dcnormffp_0_82_1169.det.lc.W149
# 60 64
# mag.dcnormffp_0_82_1170.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_1171.det.lc.W149
# 23 26
# mag.dcnormffp_0_82_1172.det.lc.W149
# 75 73
# mag.dcnormffp_0_82_1173.det.lc.W149
# 66 64
# mag.dcnormffp_0_82_1174.det.lc.W149
# 232 234
# mag.dcnormffp_0_82_1175.det.lc.W149
# 137 138
# mag.dcnormffp_0_82_1176.det.lc.W149
# 127 129
# mag.dcnormffp_0_82_1177.det.lc.W149
# 383 387
# mag.dcnormffp_0_82_1178.det.lc.W149
# 151 155
# mag.dcnormffp_0_82_1179.det.lc.W149
# 410 409
# mag.dcnormffp_0_82_1182.det.lc.W149
# 7 4
# mag.dcnormffp_0_82_1183.det.lc.W149
# 7 10
# mag.dcnormffp_0_82_1184.det.lc.W149
# 8 9
# mag.dcnormffp_0_82_1186.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_1187.det.lc.W149
# 480 481
# mag.dcnormffp_0_82_1188.det.lc.W149
# 56 57
# mag.dcnormffp_0_82_1189.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_1190.det.lc.W149
# 44 44
# mag.dcnormffp_0_82_1193.det.lc.W149
# 38 38
# mag.dcnormffp_0_82_1194.det.lc.W149
# 67 25
# mag.dcnormffp_0_82_1195.det.lc.W149
# 559 562
# mag.dcnormffp_0_82_1196.det.lc.W149
# 517 516
# mag.dcnormffp_0_82_1198.det.lc.W149
# 0 3638
# mag.dcnormffp_0_82_1199.det.lc.W149
# 432 433
# mag.dcnormffp_0_82_1200.det.lc.W149
# 7 7
# mag.dcnormffp_0_82_1202.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_1204.det.lc.W149
# 5 4
# mag.dcnormffp_0_82_1205.det.lc.W149
# 15 13
# mag.dcnormffp_0_82_1206.det.lc.W149
# 22 23
# mag.dcnormffp_0_82_1208.det.lc.W149
# 12 16
# mag.dcnormffp_0_82_1209.det.lc.W149
# 13 13
# mag.dcnormffp_0_82_1210.det.lc.W149
# 76 77
# mag.dcnormffp_0_82_1211.det.lc.W149
# 98 98
# mag.dcnormffp_0_82_1212.det.lc.W149
# 12 10
# mag.dcnormffp_0_82_1213.det.lc.W149
# 167 167
# mag.dcnormffp_0_82_1215.det.lc.W149
# 39 40
# mag.dcnormffp_0_82_1216.det.lc.W149
# 137 137
# mag.dcnormffp_0_82_1217.det.lc.W149
# 141 145
# mag.dcnormffp_0_82_1218.det.lc.W149
# 451 451
# mag.dcnormffp_0_82_1219.det.lc.W149
# 786 788
# mag.dcnormffp_0_82_1220.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_1222.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1223.det.lc.W149
# 4 5
# mag.dcnormffp_0_82_1225.det.lc.W149
# 25 21
# mag.dcnormffp_0_82_1226.det.lc.W149
# 8 7
# mag.dcnormffp_0_82_1228.det.lc.W149
# 5 6
# mag.dcnormffp_0_82_1229.det.lc.W149
# 17 21
# mag.dcnormffp_0_82_1230.det.lc.W149
# 28 25
# mag.dcnormffp_0_82_1231.det.lc.W149
# 11 11
# mag.dcnormffp_0_82_1232.det.lc.W149
# 233 232
# mag.dcnormffp_0_82_1233.det.lc.W149
# 118 116
# mag.dcnormffp_0_82_1234.det.lc.W149
# 1351 1354
# mag.dcnormffp_0_82_1235.det.lc.W149
# 36 39
# mag.dcnormffp_0_82_1236.det.lc.W149
# 379 382
# mag.dcnormffp_0_82_1237.det.lc.W149
# 1361 1363
# mag.dcnormffp_0_82_1238.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1239.det.lc.W149
# 67 70
# mag.dcnormffp_0_82_1240.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_1241.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_1242.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1243.det.lc.W149
# 13 13
# mag.dcnormffp_0_82_1244.det.lc.W149
# 9 9
# mag.dcnormffp_0_82_1245.det.lc.W149
# 18 14
# mag.dcnormffp_0_82_1247.det.lc.W149
# 22 23
# mag.dcnormffp_0_82_1248.det.lc.W149
# 9 6
# mag.dcnormffp_0_82_1249.det.lc.W149
# 48 50
# mag.dcnormffp_0_82_1250.det.lc.W149
# 97 98
# mag.dcnormffp_0_82_1251.det.lc.W149
# 13 14
# mag.dcnormffp_0_82_1252.det.lc.W149
# 114 113
# mag.dcnormffp_0_82_1253.det.lc.W149
# 68 70
# mag.dcnormffp_0_82_1254.det.lc.W149
# 164 164
# mag.dcnormffp_0_82_1256.det.lc.W149
# 455 455
# mag.dcnormffp_0_82_1257.det.lc.W149
# 427 423
# mag.dcnormffp_0_82_1258.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_1259.det.lc.W149
# 253 251
# mag.dcnormffp_0_82_1260.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1261.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_1263.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_1264.det.lc.W149
# 18 22
# mag.dcnormffp_0_82_1265.det.lc.W149
# 9 8
# mag.dcnormffp_0_82_1266.det.lc.W149
# 24 21
# mag.dcnormffp_0_82_1267.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1268.det.lc.W149
# 51 59
# mag.dcnormffp_0_82_1269.det.lc.W149
# 13 12
# mag.dcnormffp_0_82_1271.det.lc.W149
# 49 50
# mag.dcnormffp_0_82_1272.det.lc.W149
# 8 8
# mag.dcnormffp_0_82_1273.det.lc.W149
# 101 100
# mag.dcnormffp_0_82_1275.det.lc.W149
# 309 309
# mag.dcnormffp_0_82_1276.det.lc.W149
# 205 208
# mag.dcnormffp_0_82_1277.det.lc.W149
# 793 793
# mag.dcnormffp_0_82_1278.det.lc.W149
# 152 150
# mag.dcnormffp_0_82_1279.det.lc.W149
# 1384 1384
# mag.dcnormffp_0_82_1281.det.lc.W149
# 56 53
# mag.dcnormffp_0_82_1282.det.lc.W149
# 9 8
# mag.dcnormffp_0_82_1283.det.lc.W149
# 40 36
# mag.dcnormffp_0_82_1284.det.lc.W149
# 26 23
# mag.dcnormffp_0_82_1286.det.lc.W149
# 14 14
# mag.dcnormffp_0_82_1287.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1288.det.lc.W149
# 17 20
# mag.dcnormffp_0_82_1289.det.lc.W149
# 36 36
# mag.dcnormffp_0_82_1290.det.lc.W149
# 47 47
# mag.dcnormffp_0_82_1291.det.lc.W149
# 114 113
# mag.dcnormffp_0_82_1293.det.lc.W149
# 205 205
# mag.dcnormffp_0_82_1294.det.lc.W149
# 8 11
# mag.dcnormffp_0_82_1295.det.lc.W149
# 73 75
# mag.dcnormffp_0_82_1296.det.lc.W149
# 136 137
# mag.dcnormffp_0_82_1297.det.lc.W149
# 10 12
# mag.dcnormffp_0_82_1298.det.lc.W149
# 196 199
# mag.dcnormffp_0_82_1299.det.lc.W149
# 343 342
# mag.dcnormffp_0_82_1300.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_1301.det.lc.W149
# 2 4
# mag.dcnormffp_0_82_1304.det.lc.W149
# 8 8
# mag.dcnormffp_0_82_1305.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_1306.det.lc.W149
# 35 39
# mag.dcnormffp_0_82_1307.det.lc.W149
# 32 32
# mag.dcnormffp_0_82_1308.det.lc.W149
# 204 201
# mag.dcnormffp_0_82_1310.det.lc.W149
# 16 12
# mag.dcnormffp_0_82_1311.det.lc.W149
# 59 57
# mag.dcnormffp_0_82_1312.det.lc.W149
# 121 119
# mag.dcnormffp_0_82_1313.det.lc.W149
# 74 74
# mag.dcnormffp_0_82_1314.det.lc.W149
# 141 142
# mag.dcnormffp_0_82_1315.det.lc.W149
# 301 298
# mag.dcnormffp_0_82_1316.det.lc.W149
# 119 123
# mag.dcnormffp_0_82_1317.det.lc.W149
# 86 87
# mag.dcnormffp_0_82_1318.det.lc.W149
# 455 457
# mag.dcnormffp_0_82_1319.det.lc.W149
# 1076 1077
# mag.dcnormffp_0_82_1320.det.lc.W149
# 9 5
# mag.dcnormffp_0_82_1323.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_1324.det.lc.W149
# 8 9
# mag.dcnormffp_0_82_1325.det.lc.W149
# 9 10
# mag.dcnormffp_0_82_1326.det.lc.W149
# 28 30
# mag.dcnormffp_0_82_1327.det.lc.W149
# 43 43
# mag.dcnormffp_0_82_1328.det.lc.W149
# 22 18
# mag.dcnormffp_0_82_1329.det.lc.W149
# 3 2
# mag.dcnormffp_0_82_1330.det.lc.W149
# 40 2
# mag.dcnormffp_0_82_1332.det.lc.W149
# 30 30
# mag.dcnormffp_0_82_1334.det.lc.W149
# 132 133
# mag.dcnormffp_0_82_1336.det.lc.W149
# 137 139
# mag.dcnormffp_0_82_1337.det.lc.W149
# 147 143
# mag.dcnormffp_0_82_1338.det.lc.W149
# 439 440
# mag.dcnormffp_0_82_1339.det.lc.W149
# 103 104
# mag.dcnormffp_0_82_1340.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1341.det.lc.W149
# 5 4
# mag.dcnormffp_0_82_1342.det.lc.W149
# 11 8
# mag.dcnormffp_0_82_1343.det.lc.W149
# 4 3
# mag.dcnormffp_0_82_1344.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_1345.det.lc.W149
# 14 16
# mag.dcnormffp_0_82_1346.det.lc.W149
# 8 8
# mag.dcnormffp_0_82_1347.det.lc.W149
# 29 26
# mag.dcnormffp_0_82_1349.det.lc.W149
# 54 54
# mag.dcnormffp_0_82_1350.det.lc.W149
# 2 3
# mag.dcnormffp_0_82_1351.det.lc.W149
# 87 87
# mag.dcnormffp_0_82_1352.det.lc.W149
# 104 107
# mag.dcnormffp_0_82_1354.det.lc.W149
# 29 29
# mag.dcnormffp_0_82_1355.det.lc.W149
# 32 30
# mag.dcnormffp_0_82_1356.det.lc.W149
# 1028 1032
# mag.dcnormffp_0_82_1357.det.lc.W149
# 118 115
# mag.dcnormffp_0_82_1358.det.lc.W149
# 55 52
# mag.dcnormffp_0_82_1360.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1361.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1363.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1364.det.lc.W149
# 12 15
# mag.dcnormffp_0_82_1365.det.lc.W149
# 12 14
# mag.dcnormffp_0_82_1366.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_1367.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_1368.det.lc.W149
# 60 60
# mag.dcnormffp_0_82_1369.det.lc.W149
# 71 68
# mag.dcnormffp_0_82_1370.det.lc.W149
# 36 37
# mag.dcnormffp_0_82_1372.det.lc.W149
# 33 35
# mag.dcnormffp_0_82_1373.det.lc.W149
# 46 45
# mag.dcnormffp_0_82_1374.det.lc.W149
# 185 182
# mag.dcnormffp_0_82_1375.det.lc.W149
# 321 319
# mag.dcnormffp_0_82_1376.det.lc.W149
# 448 451
# mag.dcnormffp_0_82_1377.det.lc.W149
# 209 207
# mag.dcnormffp_0_82_1378.det.lc.W149
# 191 372
# mag.dcnormffp_0_82_1379.det.lc.W149
# 625 627
# mag.dcnormffp_0_82_1380.det.lc.W149
# 6 7
# mag.dcnormffp_0_82_1381.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_1382.det.lc.W149
# 6 6
# mag.dcnormffp_0_82_1383.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_1385.det.lc.W149
# 13 16
# mag.dcnormffp_0_82_1386.det.lc.W149
# 17 14
# mag.dcnormffp_0_82_1387.det.lc.W149
# 24 27
# mag.dcnormffp_0_82_1388.det.lc.W149
# 11 11
# mag.dcnormffp_0_82_1389.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_1390.det.lc.W149
# 164 164
# mag.dcnormffp_0_82_1391.det.lc.W149
# 64 66
# mag.dcnormffp_0_82_1393.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1394.det.lc.W149
# 16 20
# mag.dcnormffp_0_82_1395.det.lc.W149
# 97 97
# mag.dcnormffp_0_82_1396.det.lc.W149
# 201 200
# mag.dcnormffp_0_82_1397.det.lc.W149
# 65 62
# mag.dcnormffp_0_82_1398.det.lc.W149
# 576 574
# mag.dcnormffp_0_82_1399.det.lc.W149
# 1834 2394
# mag.dcnormffp_0_82_1402.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_1403.det.lc.W149
# 4 3
# mag.dcnormffp_0_82_1404.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1405.det.lc.W149
# 9 8
# mag.dcnormffp_0_82_1406.det.lc.W149
# 10 10
# mag.dcnormffp_0_82_1407.det.lc.W149
# 12 14
# mag.dcnormffp_0_82_1408.det.lc.W149
# 43 43
# mag.dcnormffp_0_82_1409.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_1410.det.lc.W149
# 19 17
# mag.dcnormffp_0_82_1411.det.lc.W149
# 26 28
# mag.dcnormffp_0_82_1412.det.lc.W149
# 68 68
# mag.dcnormffp_0_82_1413.det.lc.W149
# 14 17
# mag.dcnormffp_0_82_1414.det.lc.W149
# 2762 3625
# mag.dcnormffp_0_82_1416.det.lc.W149
# 217 217
# mag.dcnormffp_0_82_1417.det.lc.W149
# 187 188
# mag.dcnormffp_0_82_1418.det.lc.W149
# 286 104
# mag.dcnormffp_0_82_1419.det.lc.W149
# 6069 359
# mag.dcnormffp_0_82_1420.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_1421.det.lc.W149
# 11 12
# mag.dcnormffp_0_82_1422.det.lc.W149
# 7 6
# mag.dcnormffp_0_82_1423.det.lc.W149
# 5 7
# mag.dcnormffp_0_82_1425.det.lc.W149
# 1393 2116
# mag.dcnormffp_0_82_1427.det.lc.W149
# 9 8
# mag.dcnormffp_0_82_1428.det.lc.W149
# 24 27
# mag.dcnormffp_0_82_1429.det.lc.W149
# 8 9
# ...
# 19 17
# mag.dcnormffp_0_82_1531.det.lc.W149
# 17 19
# mag.dcnormffp_0_82_1532.det.lc.W149
# 35 37
# mag.dcnormffp_0_82_1533.det.lc.W149
# 72 70
# mag.dcnormffp_0_82_1535.det.lc.W149
# 226 227
# mag.dcnormffp_0_82_1536.det.lc.W149
# 29 30
# mag.dcnormffp_0_82_1537.det.lc.W149
# 407 407
# mag.dcnormffp_0_82_1538.det.lc.W149
# 418 415
# mag.dcnormffp_0_82_1539.det.lc.W149
# 130 130
# mag.dcnormffp_0_82_1540.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_1541.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_1543.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_1544.det.lc.W149
# 25 29
# mag.dcnormffp_0_82_1545.det.lc.W149
# 4 3
# mag.dcnormffp_0_82_1546.det.lc.W149
# 8 7
# mag.dcnormffp_0_82_1547.det.lc.W149
# 7 10
# mag.dcnormffp_0_82_1548.det.lc.W149
# 54 52
# mag.dcnormffp_0_82_1549.det.lc.W149
# 47 47
# mag.dcnormffp_0_82_1550.det.lc.W149
# 45 45
# mag.dcnormffp_0_82_1551.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1552.det.lc.W149
# 11 14
# mag.dcnormffp_0_82_1553.det.lc.W149
# 66 64
# mag.dcnormffp_0_82_1555.det.lc.W149
# 173 543
# mag.dcnormffp_0_82_1556.det.lc.W149
# 1462 1462
# mag.dcnormffp_0_82_1557.det.lc.W149
# 27 23
# mag.dcnormffp_0_82_1558.det.lc.W149
# 317 318
# mag.dcnormffp_0_82_1559.det.lc.W149
# 1363 1363
# mag.dcnormffp_0_82_1560.det.lc.W149
# 17 13
# mag.dcnormffp_0_82_1561.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_1562.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_1564.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1565.det.lc.W149
# 6 8
# mag.dcnormffp_0_82_1566.det.lc.W149
# 166 165
# mag.dcnormffp_0_82_1568.det.lc.W149
# 3 4
# mag.dcnormffp_0_82_1569.det.lc.W149
# 28 31
# mag.dcnormffp_0_82_1570.det.lc.W149
# 8 7
# mag.dcnormffp_0_82_1571.det.lc.W149
# 99 99
# mag.dcnormffp_0_82_1574.det.lc.W149
# 116 115
# mag.dcnormffp_0_82_1575.det.lc.W149
# 956 953
# mag.dcnormffp_0_82_1576.det.lc.W149
# 116 119
# mag.dcnormffp_0_82_1577.det.lc.W149
# 59 40
# mag.dcnormffp_0_82_1578.det.lc.W149
# 369 373
# mag.dcnormffp_0_82_1579.det.lc.W149
# 1155 1155
# mag.dcnormffp_0_82_1581.det.lc.W149
# 19 17
# mag.dcnormffp_0_82_1582.det.lc.W149
# 4 2
# mag.dcnormffp_0_82_1583.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_1584.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_1585.det.lc.W149
# 3 0
# mag.dcnormffp_0_82_1586.det.lc.W149
# 10 12
# mag.dcnormffp_0_82_1588.det.lc.W149
# 9 11
# mag.dcnormffp_0_82_1589.det.lc.W149
# 19 21
# mag.dcnormffp_0_82_1590.det.lc.W149
# 22 25
# mag.dcnormffp_0_82_1591.det.lc.W149
# 173 174
# mag.dcnormffp_0_82_1593.det.lc.W149
# 57 57
# mag.dcnormffp_0_82_1594.det.lc.W149
# 160 160
# mag.dcnormffp_0_82_1595.det.lc.W149
# 5 7
# mag.dcnormffp_0_82_1596.det.lc.W149
# 1836 996
# mag.dcnormffp_0_82_1597.det.lc.W149
# 286 283
# mag.dcnormffp_0_82_1598.det.lc.W149
# 30 30
# mag.dcnormffp_0_82_1599.det.lc.W149
# 289 290
# mag.dcnormffp_0_82_1600.det.lc.W149
# 4 3
# mag.dcnormffp_0_82_1601.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_1602.det.lc.W149
# 9 12
# mag.dcnormffp_0_82_1604.det.lc.W149
# 34 30
# mag.dcnormffp_0_82_1605.det.lc.W149
# 17 14
# mag.dcnormffp_0_82_1606.det.lc.W149
# 102 77
# mag.dcnormffp_0_82_1607.det.lc.W149
# 31 31
# mag.dcnormffp_0_82_1608.det.lc.W149
# 42 43
# mag.dcnormffp_0_82_1609.det.lc.W149
# 20 16
# mag.dcnormffp_0_82_1610.det.lc.W149
# 117 120
# mag.dcnormffp_0_82_1611.det.lc.W149
# 30 28
# mag.dcnormffp_0_82_1612.det.lc.W149
# 86 86
# mag.dcnormffp_0_82_1613.det.lc.W149
# 67 70
# mag.dcnormffp_0_82_1614.det.lc.W149
# 71 71
# mag.dcnormffp_0_82_1615.det.lc.W149
# 175 175
# mag.dcnormffp_0_82_1616.det.lc.W149
# 357 357
# mag.dcnormffp_0_82_1617.det.lc.W149
# 226 258
# mag.dcnormffp_0_82_1618.det.lc.W149
# 206 204
# mag.dcnormffp_0_82_1620.det.lc.W149
# 6 7
# mag.dcnormffp_0_82_1621.det.lc.W149
# 4 3
# mag.dcnormffp_0_82_1622.det.lc.W149
# 50 47
# mag.dcnormffp_0_82_1623.det.lc.W149
# 2 3
# mag.dcnormffp_0_82_1624.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_1625.det.lc.W149
# 16 13
# mag.dcnormffp_0_82_1627.det.lc.W149
# 3 1
# mag.dcnormffp_0_82_1628.det.lc.W149
# 94 92
# mag.dcnormffp_0_82_1629.det.lc.W149
# 14 13
# mag.dcnormffp_0_82_1630.det.lc.W149
# 33 32
# mag.dcnormffp_0_82_1631.det.lc.W149
# 65 68
# mag.dcnormffp_0_82_1632.det.lc.W149
# 55 54
# mag.dcnormffp_0_82_1633.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_1634.det.lc.W149
# 112 20
# mag.dcnormffp_0_82_1635.det.lc.W149
# 50 51
# mag.dcnormffp_0_82_1636.det.lc.W149
# 293 296
# mag.dcnormffp_0_82_1637.det.lc.W149
# 400 400
# mag.dcnormffp_0_82_1639.det.lc.W149
# 1715 1768
# mag.dcnormffp_0_82_1641.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_1643.det.lc.W149
# 7 7
# mag.dcnormffp_0_82_1644.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_1645.det.lc.W149
# 7 5
# mag.dcnormffp_0_82_1647.det.lc.W149
# 6 7
# mag.dcnormffp_0_82_1648.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_1649.det.lc.W149
# 56 58
# mag.dcnormffp_0_82_1650.det.lc.W149
# 152 154
# mag.dcnormffp_0_82_1651.det.lc.W149
# 52 53
# mag.dcnormffp_0_82_1652.det.lc.W149
# 378 378
# mag.dcnormffp_0_82_1654.det.lc.W149
# 44 44
# mag.dcnormffp_0_82_1655.det.lc.W149
# 209 209
# mag.dcnormffp_0_82_1658.det.lc.W149
# 494 495
# mag.dcnormffp_0_82_1659.det.lc.W149
# 694 696
# mag.dcnormffp_0_82_1660.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_1662.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_1663.det.lc.W149
# 24 22
# mag.dcnormffp_0_82_1665.det.lc.W149
# 7 10
# mag.dcnormffp_0_82_1667.det.lc.W149
# 52 53
# mag.dcnormffp_0_82_1668.det.lc.W149
# 63 65
# mag.dcnormffp_0_82_1669.det.lc.W149
# 20 19
# mag.dcnormffp_0_82_1670.det.lc.W149
# 66 69
# mag.dcnormffp_0_82_1671.det.lc.W149
# 228 228
# mag.dcnormffp_0_82_1672.det.lc.W149
# 30 29
# mag.dcnormffp_0_82_1675.det.lc.W149
# 116 113
# mag.dcnormffp_0_82_1676.det.lc.W149
# 98 102
# mag.dcnormffp_0_82_1677.det.lc.W149
# 2141 1709
# mag.dcnormffp_0_82_1678.det.lc.W149
# 667 668
# mag.dcnormffp_0_82_1679.det.lc.W149
# 591 591
# mag.dcnormffp_0_82_1680.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_1681.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1682.det.lc.W149
# 9 12
# mag.dcnormffp_0_82_1684.det.lc.W149
# 3 5
# mag.dcnormffp_0_82_1685.det.lc.W149
# 3 4
# mag.dcnormffp_0_82_1687.det.lc.W149
# 5 4
# mag.dcnormffp_0_82_1689.det.lc.W149
# 49 48
# mag.dcnormffp_0_82_1690.det.lc.W149
# 85 44
# mag.dcnormffp_0_82_1691.det.lc.W149
# 48 46
# mag.dcnormffp_0_82_1692.det.lc.W149
# 26 24
# mag.dcnormffp_0_82_1694.det.lc.W149
# 13 9
# mag.dcnormffp_0_82_1695.det.lc.W149
# 161 164
# mag.dcnormffp_0_82_1696.det.lc.W149
# 138 142
# mag.dcnormffp_0_82_1697.det.lc.W149
# 142 140
# mag.dcnormffp_0_82_1698.det.lc.W149
# 177 177
# mag.dcnormffp_0_82_1699.det.lc.W149
# 1427 1270
# mag.dcnormffp_0_82_1700.det.lc.W149
# 3 4
# mag.dcnormffp_0_82_1701.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1702.det.lc.W149
# 13 12
# mag.dcnormffp_0_82_1704.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_1707.det.lc.W149
# 18 16
# mag.dcnormffp_0_82_1708.det.lc.W149
# 70 73
# mag.dcnormffp_0_82_1710.det.lc.W149
# 6 6
# mag.dcnormffp_0_82_1711.det.lc.W149
# 103 57
# mag.dcnormffp_0_82_1712.det.lc.W149
# 166 165
# mag.dcnormffp_0_82_1713.det.lc.W149
# 9 12
# mag.dcnormffp_0_82_1714.det.lc.W149
# 109 107
# mag.dcnormffp_0_82_1715.det.lc.W149
# 78 75
# mag.dcnormffp_0_82_1716.det.lc.W149
# 92 0
# mag.dcnormffp_0_82_1717.det.lc.W149
# 917 0
# mag.dcnormffp_0_82_1718.det.lc.W149
# 171 169
# mag.dcnormffp_0_82_1721.det.lc.W149
# 5 2
# mag.dcnormffp_0_82_1722.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_1723.det.lc.W149
# 3 5
# mag.dcnormffp_0_82_1724.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_1725.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_1726.det.lc.W149
# 21 17
# mag.dcnormffp_0_82_1727.det.lc.W149
# 5 6
# mag.dcnormffp_0_82_1728.det.lc.W149
# 2 3
# mag.dcnormffp_0_82_1729.det.lc.W149
# 106 109
# mag.dcnormffp_0_82_1730.det.lc.W149
# 11 12
# mag.dcnormffp_0_82_1731.det.lc.W149
# 33 33
# mag.dcnormffp_0_82_1732.det.lc.W149
# 127 125
# mag.dcnormffp_0_82_1733.det.lc.W149
# 391 393
# mag.dcnormffp_0_82_1734.det.lc.W149
# 381 384
# mag.dcnormffp_0_82_1735.det.lc.W149
# 183 184
# mag.dcnormffp_0_82_1736.det.lc.W149
# 164 161
# mag.dcnormffp_0_82_1737.det.lc.W149
# 1156 784
# mag.dcnormffp_0_82_1738.det.lc.W149
# 472 469
# mag.dcnormffp_0_82_1739.det.lc.W149
# 809 1090
# mag.dcnormffp_0_82_1740.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1741.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_1742.det.lc.W149
# 2 3
# mag.dcnormffp_0_82_1743.det.lc.W149
# 7 9
# mag.dcnormffp_0_82_1745.det.lc.W149
# 8 5
# mag.dcnormffp_0_82_1746.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_1747.det.lc.W149
# 3 2
# mag.dcnormffp_0_82_1749.det.lc.W149
# 73 70
# mag.dcnormffp_0_82_1750.det.lc.W149
# 6 5
# mag.dcnormffp_0_82_1751.det.lc.W149
# 4 2
# mag.dcnormffp_0_82_1752.det.lc.W149
# 124 122
# mag.dcnormffp_0_82_1753.det.lc.W149
# 252 248
# mag.dcnormffp_0_82_1755.det.lc.W149
# 592 593
# mag.dcnormffp_0_82_1756.det.lc.W149
# 49 47
# mag.dcnormffp_0_82_1757.det.lc.W149
# 27 25
# mag.dcnormffp_0_82_1758.det.lc.W149
# 267 777
# mag.dcnormffp_0_82_1759.det.lc.W149
# 548 551
# mag.dcnormffp_0_82_1761.det.lc.W149
# 9 7
# mag.dcnormffp_0_82_1762.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1764.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_1767.det.lc.W149
# 11 10
# mag.dcnormffp_0_82_1768.det.lc.W149
# 7 7
# mag.dcnormffp_0_82_1769.det.lc.W149
# 98 98
# mag.dcnormffp_0_82_1770.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_1771.det.lc.W149
# 188 187
# mag.dcnormffp_0_82_1772.det.lc.W149
# 50 52
# mag.dcnormffp_0_82_1773.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_1774.det.lc.W149
# 6 6
# mag.dcnormffp_0_82_1775.det.lc.W149
# 574 576
# mag.dcnormffp_0_82_1776.det.lc.W149
# 2602 2888
# mag.dcnormffp_0_82_1779.det.lc.W149
# 753 754
# mag.dcnormffp_0_82_1782.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_1783.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1784.det.lc.W149
# 13 15
# mag.dcnormffp_0_82_1785.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_1786.det.lc.W149
# 6 6
# mag.dcnormffp_0_82_1787.det.lc.W149
# 16 13
# mag.dcnormffp_0_82_1789.det.lc.W149
# 15 14
# mag.dcnormffp_0_82_1791.det.lc.W149
# 123 123
# mag.dcnormffp_0_82_1792.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_1793.det.lc.W149
# 82 84
# mag.dcnormffp_0_82_1794.det.lc.W149
# 165 166
# mag.dcnormffp_0_82_1795.det.lc.W149
# 125 125
# mag.dcnormffp_0_82_1796.det.lc.W149
# 340 343
# mag.dcnormffp_0_82_1797.det.lc.W149
# 549 547
# mag.dcnormffp_0_82_1799.det.lc.W149
# 1431 1427
# mag.dcnormffp_0_82_1800.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_1801.det.lc.W149
# 4 5
# mag.dcnormffp_0_82_1802.det.lc.W149
# 17 21
# mag.dcnormffp_0_82_1803.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_1805.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_1806.det.lc.W149
# 5 9
# mag.dcnormffp_0_82_1807.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_1808.det.lc.W149
# 337 337
# mag.dcnormffp_0_82_1810.det.lc.W149
# 58 59
# mag.dcnormffp_0_82_1811.det.lc.W149
# 72 70
# mag.dcnormffp_0_82_1812.det.lc.W149
# 7 9
# mag.dcnormffp_0_82_1813.det.lc.W149
# 128 128
# mag.dcnormffp_0_82_1814.det.lc.W149
# 176 177
# mag.dcnormffp_0_82_1815.det.lc.W149
# 222 222
# mag.dcnormffp_0_82_1816.det.lc.W149
# 68 65
# mag.dcnormffp_0_82_1817.det.lc.W149
# 162 160
# mag.dcnormffp_0_82_1818.det.lc.W149
# 36 37
# mag.dcnormffp_0_82_1819.det.lc.W149
# 1031 1033
# mag.dcnormffp_0_82_1821.det.lc.W149
# 9 6
# mag.dcnormffp_0_82_1822.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1824.det.lc.W149
# 4 2
# mag.dcnormffp_0_82_1825.det.lc.W149
# 7 8
# mag.dcnormffp_0_82_1826.det.lc.W149
# 10 7
# mag.dcnormffp_0_82_1827.det.lc.W149
# 4 3
# mag.dcnormffp_0_82_1828.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1829.det.lc.W149
# 10 11
# mag.dcnormffp_0_82_1830.det.lc.W149
# 30 34
# mag.dcnormffp_0_82_1832.det.lc.W149
# 17 18
# mag.dcnormffp_0_82_1833.det.lc.W149
# 92 92
# mag.dcnormffp_0_82_1834.det.lc.W149
# 24 22
# mag.dcnormffp_0_82_1835.det.lc.W149
# 112 116
# mag.dcnormffp_0_82_1836.det.lc.W149
# 66 67
# mag.dcnormffp_0_82_1837.det.lc.W149
# 321 319
# mag.dcnormffp_0_82_1838.det.lc.W149
# 6314 0
# mag.dcnormffp_0_82_1839.det.lc.W149
# 323 323
# mag.dcnormffp_0_82_1840.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1841.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_1842.det.lc.W149
# 13 11
# mag.dcnormffp_0_82_1845.det.lc.W149
# 9 12
# mag.dcnormffp_0_82_1848.det.lc.W149
# 13 16
# mag.dcnormffp_0_82_1849.det.lc.W149
# 27 24
# mag.dcnormffp_0_82_1850.det.lc.W149
# 28 26
# mag.dcnormffp_0_82_1851.det.lc.W149
# 22 25
# mag.dcnormffp_0_82_1852.det.lc.W149
# 37 37
# mag.dcnormffp_0_82_1853.det.lc.W149
# 28 26
# mag.dcnormffp_0_82_1854.det.lc.W149
# 138 137
# mag.dcnormffp_0_82_1855.det.lc.W149
# 146 150
# mag.dcnormffp_0_82_1856.det.lc.W149
# 62 60
# mag.dcnormffp_0_82_1857.det.lc.W149
# 909 219
# mag.dcnormffp_0_82_1858.det.lc.W149
# 326 329
# mag.dcnormffp_0_82_1859.det.lc.W149
# 500 500
# mag.dcnormffp_0_82_1860.det.lc.W149
# 0 0
# mag.dcnormffp_0_82_1862.det.lc.W149
# 5 5
# mag.dcnormffp_0_82_1863.det.lc.W149
# 2 3
# mag.dcnormffp_0_82_1864.det.lc.W149
# 4 3
# mag.dcnormffp_0_82_1865.det.lc.W149
# 11 7
# mag.dcnormffp_0_82_1866.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_1868.det.lc.W149
# 4 5
# mag.dcnormffp_0_82_1869.det.lc.W149
# 8 10
# mag.dcnormffp_0_82_1870.det.lc.W149
# 30 31
# mag.dcnormffp_0_82_1871.det.lc.W149
# 1 0
# mag.dcnormffp_0_82_1872.det.lc.W149
# 7 3
# mag.dcnormffp_0_82_1873.det.lc.W149
# 183 182
# mag.dcnormffp_0_82_1874.det.lc.W149
# 139 142
# mag.dcnormffp_0_82_1875.det.lc.W149
# 76 78
# mag.dcnormffp_0_82_1876.det.lc.W149
# 121 122
# mag.dcnormffp_0_82_1877.det.lc.W149
# 147 147
# mag.dcnormffp_0_82_1878.det.lc.W149
# 136 134
# mag.dcnormffp_0_82_1879.det.lc.W149
# 803 803
# mag.dcnormffp_0_82_1880.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_1881.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_1882.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_1883.det.lc.W149
# 7 4
# mag.dcnormffp_0_82_1884.det.lc.W149
# 6 5
# mag.dcnormffp_0_82_1885.det.lc.W149
# 5 7
# mag.dcnormffp_0_82_1886.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1888.det.lc.W149
# 16 15
# mag.dcnormffp_0_82_1889.det.lc.W149
# 206 205
# mag.dcnormffp_0_82_1890.det.lc.W149
# 7 7
# mag.dcnormffp_0_82_1891.det.lc.W149
# 48 52
# mag.dcnormffp_0_82_1892.det.lc.W149
# 72 74
# mag.dcnormffp_0_82_1896.det.lc.W149
# 333 337
# mag.dcnormffp_0_82_1897.det.lc.W149
# 84 83
# mag.dcnormffp_0_82_1898.det.lc.W149
# 185 188
# mag.dcnormffp_0_82_1899.det.lc.W149
# 356 357
# mag.dcnormffp_0_82_1901.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1902.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1903.det.lc.W149
# 6 3
# mag.dcnormffp_0_82_1904.det.lc.W149
# 19 22
# mag.dcnormffp_0_82_1906.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_1908.det.lc.W149
# 24 25
# mag.dcnormffp_0_82_1909.det.lc.W149
# 25 23
# mag.dcnormffp_0_82_1911.det.lc.W149
# 16 17
# mag.dcnormffp_0_82_1912.det.lc.W149
# 9 10
# mag.dcnormffp_0_82_1913.det.lc.W149
# 125 124
# mag.dcnormffp_0_82_1914.det.lc.W149
# 64 66
# mag.dcnormffp_0_82_1915.det.lc.W149
# 383 383
# mag.dcnormffp_0_82_1916.det.lc.W149
# 223 224
# mag.dcnormffp_0_82_1917.det.lc.W149
# 125 5181
# mag.dcnormffp_0_82_1918.det.lc.W149
# 40 39
# mag.dcnormffp_0_82_1919.det.lc.W149
# 419 486
# mag.dcnormffp_0_82_1921.det.lc.W149
# 3 4
# mag.dcnormffp_0_82_1924.det.lc.W149
# 6 7
# mag.dcnormffp_0_82_1926.det.lc.W149
# 6 9
# mag.dcnormffp_0_82_1928.det.lc.W149
# 146 145
# mag.dcnormffp_0_82_1929.det.lc.W149
# 99 102
# mag.dcnormffp_0_82_1930.det.lc.W149
# 170 167
# mag.dcnormffp_0_82_1931.det.lc.W149
# 39 40
# mag.dcnormffp_0_82_1932.det.lc.W149
# 36 36
# mag.dcnormffp_0_82_1935.det.lc.W149
# 61 64
# mag.dcnormffp_0_82_1936.det.lc.W149
# 327 325
# mag.dcnormffp_0_82_1937.det.lc.W149
# 946 949
# mag.dcnormffp_0_82_1939.det.lc.W149
# 236 237
# mag.dcnormffp_0_82_1940.det.lc.W149
# 7 9
# mag.dcnormffp_0_82_1941.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_1942.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1945.det.lc.W149
# 1 2
# mag.dcnormffp_0_82_1946.det.lc.W149
# 2 1
# mag.dcnormffp_0_82_1947.det.lc.W149
# 9 7
# mag.dcnormffp_0_82_1950.det.lc.W149
# 30 30
# mag.dcnormffp_0_82_1951.det.lc.W149
# 11 8
# mag.dcnormffp_0_82_1952.det.lc.W149
# 106 106
# mag.dcnormffp_0_82_1953.det.lc.W149
# 163 163
# mag.dcnormffp_0_82_1954.det.lc.W149
# 119 116
# mag.dcnormffp_0_82_1955.det.lc.W149
# 210 208
# mag.dcnormffp_0_82_1956.det.lc.W149
# 222 222
# mag.dcnormffp_0_82_1957.det.lc.W149
# 44 44
# mag.dcnormffp_0_82_1958.det.lc.W149
# 721 721
# mag.dcnormffp_0_82_1959.det.lc.W149
# 733 509
# mag.dcnormffp_0_82_1960.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1961.det.lc.W149
# 9 9
# mag.dcnormffp_0_82_1962.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1963.det.lc.W149
# 7 7
# mag.dcnormffp_0_82_1964.det.lc.W149
# 159 158
# mag.dcnormffp_0_82_1965.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_1966.det.lc.W149
# 10 10
# mag.dcnormffp_0_82_1967.det.lc.W149
# 52 52
# mag.dcnormffp_0_82_1968.det.lc.W149
# 2 2
# mag.dcnormffp_0_82_1970.det.lc.W149
# 42 42
# mag.dcnormffp_0_82_1971.det.lc.W149
# 34 32
# mag.dcnormffp_0_82_1972.det.lc.W149
# 26 25
# mag.dcnormffp_0_82_1973.det.lc.W149
# 19 19
# mag.dcnormffp_0_82_1974.det.lc.W149
# 230 231
# mag.dcnormffp_0_82_1976.det.lc.W149
# 138 137
# mag.dcnormffp_0_82_1977.det.lc.W149
# 159 157
# mag.dcnormffp_0_82_1978.det.lc.W149
# 548 545
# mag.dcnormffp_0_82_1980.det.lc.W149
# 0 1
# mag.dcnormffp_0_82_1983.det.lc.W149
# 1 1
# mag.dcnormffp_0_82_1985.det.lc.W149
# 13 9
# mag.dcnormffp_0_82_1986.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_1987.det.lc.W149
# 8 7
# mag.dcnormffp_0_82_1988.det.lc.W149
# 3 3
# mag.dcnormffp_0_82_1989.det.lc.W149
# 21 18
# mag.dcnormffp_0_82_1991.det.lc.W149
# 4 4
# mag.dcnormffp_0_82_1992.det.lc.W149
# 49 65
# mag.dcnormffp_0_82_1994.det.lc.W149
# 205 208
# mag.dcnormffp_0_82_1996.det.lc.W149
# 316 316
# mag.dcnormffp_0_82_1997.det.lc.W149
# 1411 1412
# mag.dcnormffp_0_82_1998.det.lc.W149
# 112 114
# mag.dcnormffp_0_82_1999.det.lc.W149
# 978 978
# done
