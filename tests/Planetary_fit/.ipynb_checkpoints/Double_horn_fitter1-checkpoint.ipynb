# %%
from Common_functions import smooth, localize_event, prepare
import glob,os,sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from numpy import *
import re
import scipy.stats as st
from os.path import expanduser
import cmath
import scipy.optimize as op
import time
import gzip
import pandas as pd
import scipy.special as sp
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import (mark_inset,inset_axes,InsetPosition)
from sympy.solvers import solve
from sympy import Symbol
import sympy
from lmfit import minimize, Parameters, Parameter, report_fit


# %matplotlib inline

# %%
def Double_horn_data (params, t, A_data):
    
    xe = params['xe'].value
    xp = params['xp'].value
    b1 = params['b1'].value
    b2 = params['b2'].value
    c = params['c'].value
    a = params['a'].value
    n = params['n'].value
    w = params['w'].value
    s = params['s'].value
    
    
    A = (a/4.)* (sp.erf(b1*(w+(s*t)-xe))+1) * (sp.erf(b2*(w-(s*t)+xe))+1) * (c*(np.abs((s*t)-xp)**n)+1)
                 
    return (A - A_data)

def Double_horn (xe, xp, b1, b2, c, a, n, w,s, t):
    
    A = (a/4.)* (sp.erf(b1*(w+(s*t)-xe))+1) * (sp.erf(b2*(w-(s*t)+xe))+1) * (c*(np.abs((s*t)-xp)**n)+1)

    return A


def Double_horn_PSPL_data (params, t, A_data):
    
    t0 = params['t0'].value
    tE = params['tE'].value
    u0 = params['u0'].value
    fs = params['fs'].value
    xe = params['xe'].value
    xp = params['xp'].value
    b1 = params['b1'].value
    b2 = params['b2'].value
    c = params['c'].value
    a = params['a'].value
    n = params['n'].value
    w = params['w'].value
    s = params['s'].value
    
    
    F = Double_horn (xe, xp, b1, b2, c, a, n, w,s, t)+PSPL (t0, tE, u0,fs, t)
                 
    return (F - A_data)

def Double_horn_PSPL (t0, tE, u0,fs, xe, xp, b1, b2, c, a, n, w,s, t):
    
    F = Double_horn (xe, xp, b1, b2, c, a, n, w,s, t)+PSPL (t0, tE, u0,fs, t)

    return F



def lnlike(theta, t, f, f_err):
    t0, tE, u0,fs, xe, xp, b1, b2, c, a, n, w,s = theta
    model = Double_horn_PSPL (t0, tE, u0,fs, xe, xp, b1, b2, c, a, n, w,s, t)
    inv_sigma2 = 1.0/(f_err**2)
    return -0.5*(np.sum((f-model)**2*inv_sigma2))

# %%
x = np.linspace(-10,10,1000)
a = 10
b1= 20
b2= 20
w = 2
xe = 5
xp = 5.1
c = 0.01 #0.01-1
n = 8
s = 4
busy = Double_horn(xe, xp, b1, b2, c, a, n, w,s,x)

ax = plt.gca()
plt.plot(x, busy, linewidth = 2)
# plt.xlim(-1,1)
plt.ylim(min(busy)-1,max(busy)+1)
#ax.tick_params(axis='both',which='both', bottom='off', top='off',left = 'off', right='off', labelbottom='off', labelleft='off')
plt.ylabel('Magnification', size=30)
# plt.xlabel('Time', size=30)
fig = plt.gcf()
fig.set_size_inches(15.0,12.0)
# fig.savefig('Double_horn.png')

# %%
def cal_chisqr(model, f, ferr):
    
    
    return np.sum(((f-model)**2)/((ferr)**2))

# %%
def PSPL_data (params, t, A_data):
    
    t0 = params['t0'].value
    tE = params['tE'].value
    u0 = params['u0'].value
    fs = params['fs'].value
#     fb = params['fb'].value

    u = np.sqrt(u0**2+((t-t0)/tE)**2)
    A = ((u**2)+2)/(u*np.sqrt(u**2+4))
    F = (fs * (A-1)) +1
    return F - A_data

def PSPL (t0, tE, u0,fs, t):
    
    u = np.sqrt(u0**2+((t-t0)/tE)**2)
    A = ((u**2)+2)/(u*np.sqrt(u**2+4))
    F = (fs * (A-1)) +1
    return F

# %%
name = 'cassan_32_46_225.det.lc.gz'  
tempdata = 'data/WFIRST_simulated/Multi_caustic_crossing/'+str(name)

t,f,f_err,f_true,code = np.loadtxt(tempdata,usecols=(0,1,2,3,5),unpack=True)
df = pd.DataFrame({'t':t , 'A':f , 'A_err' : f_err , 'A_true': f_true, 'code':code})
df = df[df['code']==4]

# %%
fname = gzip.open(tempdata, 'rb')
x_0 = fname.readlines()[0:7]
mag = x_0[1].split(' ')[3]
q = x_0[5].split(' ')[5]
s = x_0[5].split(' ')[6]

# %%
max(df['A'][df['A']<np.percentile(df['A'], [0.0,99.66])[1]])
# Out:
# 3.0548625

# %%
A_max = df['A'][np.argmax(df['A'][df['A']<np.percentile(df['A'], [0.0,99.66])[1]])] #np.max(df['A']) #1.0/(float(f_s_true)/(max(df['f'])-1+float(f_s_true)))
u0_true = np.sqrt( ( (1+np.sqrt(1+16*(A_max**2)))/(2* A_max) ) - 2 )
t0_true =  df['t'][np.argmax(df['A'][df['A']<np.percentile(df['A'], [0.0,99.66])[1]])] #it0 #t[A.argmax()] #float(t0_theo)
tE_true = [0.01,0.1,1,10,100]

print t0_true
print tE_true
# Out:
# 161.2519213
# [0.01, 0.1, 1, 10, 100]

# %%
dtt = 10
plt.plot(df['t'],df['A'],'k.')
plt.xlim(t0_true-2*dtt,t0_true+2*dtt)
# plt.ylim(21.2,20.3)
# Out:
# (141.2519213, 181.2519213)

# %%
params = Parameters()
params.add('t0', value= 135, min=min(df['t']), max=max(df['t']))
params.add('tE', value= 5, min=0.001, max=1000)
params.add('u0', value= u0_true,  min=0, max=5)
params.add('fs', value= 0.5, min=0, max=1)
# params.add('fb', value= 0, min=0, max=1)

result = minimize(PSPL_data, params, args=(df['t'].values, df['A'].values))

# %%
temp1 = [[],[]]
for tE in tE_true:
    print tE
    params1 = Parameters()
    params1.add('t0', value= 135, min=min(df['t']), max=max(df['t']))
    params1.add('tE', value= 5, min=0.001, max=1000)
    params1.add('u0', value= u0_true, min=0, max=5)
    params1.add('fs', value= 0.5, min=0, max=1)
#     params.add('fb', value= 0.5, min=0, max=1)

    res1 = minimize(PSPL_data, params1, args=(df['t'][df['A']<np.percentile(df['A'], [0.0,99.66])[1]].values, df['A'][df['A']<np.percentile(df['A'], [0.0,99.66])[1]].values))
    temp1[0].append(res1.params)
    temp1[1].append(cal_chisqr(PSPL(res1.params['t0'],res1.params['tE'],res1.params['u0'],
                      res1.params['fs'], df['t']), df['A'], df['A_err']))#(res1.chisqr)
    print cal_chisqr(PSPL(res1.params['t0'],res1.params['tE'],res1.params['u0'],
                      res1.params['fs'], df['t']), df['A'], df['A_err'])
    

result1 = [temp1[0][np.argmin(temp1[1])]['t0'], temp1[0][np.argmin(temp1[1])]['tE'], 
           temp1[0][np.argmin(temp1[1])]['u0'], temp1[0][np.argmin(temp1[1])]['fs']]
# Out:
# 0.01
# 122376.90375853877
# 0.1
# 122376.90375853877
# 1
# 122376.90375853877
# 10
# 122376.90375853877
# 100
# 122376.90375853877

# %%
dtt = 20
plt.plot(df['t'],df['A'],'b.', markersize=25, label='Lightcurve Data')
plt.plot(df['t'],PSPL(result1[0].value,result1[1].value,result1[2].value,
                      result1[3].value, df['t']),'r.', Label='Chebyshev Approximation')
plt.ylabel('Magnification', size=25)
plt.xlabel('Time - 2458234', size=25)
#plt.title('Chebyshev approximation of a Binary-lens Microlensing Lightcurve',size=25)
plt.xlim(result1[0].value-dtt, result1[0].value+dtt)
plt.legend(loc=2,fontsize=20)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

print result.params

fig = plt.gcf()
fig.set_size_inches(15.0,12.0)
# plt.savefig('Chebyshevfit_success.png')
# Out:
# Parameters([('t0', <Parameter 't0', value=160.35500807686026 +/- 0.00283, bounds=[112.50701389:1825.2415046]>), ('tE', <Parameter 'tE', value=66.89638310965167 +/- 0.227, bounds=[0.001:1000]>), ('u0', <Parameter 'u0', value=0.10566113568248353 +/- 0.000442, bounds=[0:5]>), ('fs', <Parameter 'fs', value=0.24320225928892397 +/- 0.0011, bounds=[0:1]>)])

# %%
#t0_ml, u0_ml, tE_ml = tE__[0][0],tE__[0][1],tE__[0][2]

f_ris = df['A'] - PSPL(result1[0].value,result1[1].value,result1[2].value,
                       result1[3].value, df['t'])#fun(df['t'], t0_ml, u0_ml, tE_ml)
    
duration = [0.01,0.1,1]  

f_res = f_ris
f_res = smooth(f_ris,10)
t_ = np.asarray(df['t'].values)



f_ris__ = [f_res.max(),f_res.min()]
t_ris__ = [t_[f_res.argmax()],t_[f_res.argmin()]]

# %%
# duration = [0.01, 0.1, 1]
# temp = [[], []]

# for tEp in duration:
#     for a in range(0,2):
        
#         print tEp, f_ris__[a]
#         params2 = Parameters()
#         params2.add('tp', value= t_ris__[a], min=min(df['t']), max=max(df['t']))
#         params2.add('tEp', value= tEp, min=0.001, max=10)
#         params2.add('amp', value= f_ris__[a],  min=0, max=20)
#         # params.add('fs', value= 1, min=0, max=1)
#         # params.add('fb', value= 0, min=0, max=1)
#         result2 = minimize(Gaussian_data, params2, args=(df['t'].values, f_res))
#         temp[0].append(result2.params)
#         temp[1].append(result2.chisqr)
#         print result2.chisqr

# %%
t_[np.argmax(f_res)]
# Out:
# 171.16743056

# %%
dtt =20
t_ = np.asarray(df['t'].values)
plt.plot(df['t'][event], f_res[event], 'b.')
#plt.plot(df['t']-2458234, Gaussian(temp[0][np.argmin(temp[1])]['tp'], temp[0][np.argmin(temp[1])]['tEp'],temp[0][np.argmin(temp[1])]['amp'], df['t']), 'r-')
# plt.plot(df['t']-2458234, Gaussian(t_[f_res.argmin()], 1.5,-0.2, df['t']), 'g-')
#plt.axvline(temp[0][np.argmin(temp[1])]['tp']-2458234)
#plt.xlim(temp[0][np.argmin(temp[1])]['tp']-2458234-dtt, temp[0][np.argmin(temp[1])]['tp']-2458234+dtt)
#plt.xlim(result1[0].value-dtt, result1[0].value+dtt)
plt.xlim(result1[0].value-dtt, result1[0].value+dtt)
print t_[np.argmax(f_res)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-269-b89747183fcb> in <module>()
#       1 dtt =20
#       2 t_ = np.asarray(df['t'].values)
# ----> 3 plt.plot(df['t'][event], f_res[event], 'b.')
#       4 #plt.plot(df['t']-2458234, Gaussian(temp[0][np.argmin(temp[1])]['tp'], temp[0][np.argmin(temp[1])]['tEp'],temp[0][np.argmin(temp[1])]['amp'], df['t']), 'r-')
#       5 # plt.plot(df['t']-2458234, Gaussian(t_[f_res.argmin()], 1.5,-0.2, df['t']), 'g-')
#
# NameError: name 'event' is not defined

# %%
params = Parameters()
params.add('xe', value= 0.5, min=-5, max=5)
params.add('xp', value= 0.5, min=-5, max=5)
params.add('b1', value= 15,  min=2, max=20)
params.add('b2', value= 15, min=2, max=20)
params.add('c', value= 0.01, min=0, max=2)
params.add('a', value= 0.02, min=0.01, max=0.5)
params.add('n', value= 9,  min=6, max=12)
params.add('w', value= 2, min=0.01, max=5)
params.add('s', value= 4, min=1, max=10)


result_res = minimize(Double_horn_data, params, args=(df['t'].values-t_[np.argmax(f_res)], f_res))

# %%
result_res.params
# Out:
# Parameters([('xe',
#              <Parameter 'xe', value=1.8495339607866432 +/- 2.64e+03, bounds=[-5:5]>),
#             ('xp',
#              <Parameter 'xp', value=1.9292203884126549 +/- 2.75e+03, bounds=[-5:5]>),
#             ('b1',
#              <Parameter 'b1', value=2.5022069365510804 +/- 3.57e+03, bounds=[2:20]>),
#             ('b2',
#              <Parameter 'b2', value=2.7198062198084068 +/- 3.88e+03, bounds=[2:20]>),
#             ('c',
#              <Parameter 'c', value=0.055178050425365166 +/- 472, bounds=[0:2]>),
#             ('a',
#              <Parameter 'a', value=0.17723875459277086 +/- 0.000971, bounds=[0.01:0.5]>),
#             ('n',
#              <Parameter 'n', value=6.000000312679923 +/- 0.308, bounds=[6:12]>),
#             ('w',
#              <Parameter 'w', value=1.9432831493527973 +/- 2.77e+03, bounds=[0.01:5]>),
#             ('s',
#              <Parameter 's', value=5.25791055713707 +/- 7.5e+03, bounds=[1:10]>)])

# %%
xe, xp, b1, b2, c, a, n, w, s = result_res.params['xe'], result_res.params['xp'], result_res.params['b1'],\
                                result_res.params['b2'], result_res.params['c'], result_res.params['a'],\
                                result_res.params['n'],result_res.params['w'],result_res.params['s']

# %%
dtt =5
t_ = np.asarray(df['t'].values)
plt.plot(df['t']-t_[np.argmax(f_res)], f_res, 'b.')
#plt.plot(df['t']-t_[np.argmax(f_res)], Double_horn(1.8,1.9,2,2, 0.01, 1, 9,2,3.5, df['t']-t_[np.argmax(f_res)]),  'r-')
plt.plot(df['t']-t_[np.argmax(f_res)], Double_horn(xe, xp, b1, b2, c, a, n, w, s, df['t']-t_[np.argmax(f_res)]),  'g-')


plt.xlim(-3,3)


#plt.xlim(result_res.params['xe'].value-2458234-dtt, result_res.params['xe'].value-2458234+dtt)
# Out:
# (-3, 3)

# %%
params2 = Parameters()
params2.add('t0', value= 0, min=-100, max=100)
params2.add('tE', value= result1[1].value, min=0.001, max=1000)
params2.add('u0', value= result1[2].value, min=0, max=5)
params2.add('fs', value= result1[3].value, min=0, max=1)
params2.add('xe', value= 60, min=0, max=200)
params2.add('xp', value= 60, min=0, max=200)
params2.add('b1', value= b1,  min=2, max=50)
params2.add('b2', value= b2 , min=2, max=50)
params2.add('c', value= c  , min=0.01, max=2)
params2.add('a', value= a, min=0.01, max=10)
params2.add('n', value= n,  min=6, max=12)
params2.add('w', value= w, min=0.01, max=5)
params2.add('s', value= s, min=1, max=10)


result2 = minimize(Double_horn_PSPL_data, params2, args=(df['t'].values-result1[0].value, df['A']))

# %%
t0, tE, u0, fs, xe, xp, b1, b2, c, a, n, w, s = result2.params['t0'], result2.params['tE'], result2.params['u0'],result2.params['fs'],\
                                                result2.params['xe'], result2.params['xp'], result2.params['b1'],\
                                                result2.params['b2'], result2.params['c'], result2.params['a'],\
                                                result2.params['n'],result2.params['w'],result2.params['s']

# %%
dtt = 20
plt.plot(df['t']-result1[0].value,df['A'],'b.', markersize=25, label='Lightcurve Data')
plt.plot(df['t']-result1[0].value,Double_horn_PSPL(t0, tE, u0, fs,xe, xp, b1, b2, c, a, n, w, s, df['t']-result1[0].value),'r.', Label='Chebyshev Approximation')
# plt.plot(df['t']-result1[0].value,
#          PSPL(0, tE, u0, fs, df['t']-result1[0].value)+\
#          Double_horn(60, 60, b1, b2, c, a, n, w, s, df['t']-result1[0].value),'r.', Label='PSPL+Double horn')


plt.ylabel('Magnification', size=25)
plt.xlabel('Time - 2458234', size=25)
#plt.title('Chebyshev approximation of a Binary-lens Microlensing Lightcurve',size=25)
plt.xlim(-dtt, +dtt)
plt.legend(loc=2,fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

print result2.params

fig = plt.gcf()
fig.set_size_inches(15.0,12.0)
# plt.savefig('Chebyshevfit_success.png')
# Out:
# Parameters([('t0', <Parameter 't0', 7.447452578901448e-05, bounds=[-100:100]>), ('tE', <Parameter 'tE', 66.89645128295206, bounds=[0.001:1000]>), ('u0', <Parameter 'u0', 0.10566101306536846, bounds=[0:5]>), ('fs', <Parameter 'fs', 0.2432019489170833, bounds=[0:1]>), ('xe', <Parameter 'xe', 199.4997932748873, bounds=[0:200]>), ('xp', <Parameter 'xp', 199.5145514920928, bounds=[0:200]>), ('b1', <Parameter 'b1', 5.739965580853719, bounds=[2:50]>), ('b2', <Parameter 'b2', 12.99612470001788, bounds=[2:50]>), ('c', <Parameter 'c', 1.9859043398521727, bounds=[0.01:2]>), ('a', <Parameter 'a', 0.25654800497549424, bounds=[0.01:10]>), ('n', <Parameter 'n', 6.588331480828854, bounds=[6:12]>), ('w', <Parameter 'w', 0.868620173866991, bounds=[0.01:5]>), ('s', <Parameter 's', 3.505199434370251, bounds=[1:10]>)])

# %%
# min_model_ = [[],[]]

# for sigma in duration:

#     for a in range(0,2):   
t0 = 0
tE = result1[1].value
u0 = result1[2].value 
fs = result1[3].value
xe = 11#t_[np.argmax(f_res)]+xe-result1[0].value
xp = 11#t_[np.argmax(f_res)]+xe-result1[0].value
b1_ = b1
b2_ = b2
c_ = c
a_ = a
n_ = n
w_ = w
s_ = s
initials = [t0, tE, u0, fs, xe, xp, b1_, b2_, c_, a_, n_, w_, s_]
nll = lambda *args: -lnlike(*args)
result = op.minimize(nll, initials, args=(df['t']-result1[0].value,df['A'], df['A_err']),method = 'Nelder-Mead')
t0_, tE_, u0_, fs_, xe_, xp_, b1__, b2__, c__, a__, n__, w__, s__ = result['x']
# min_model_[0].append(lnlike2([mean_mll, sigma_mll,amp_mll,t0_mll, u0_mll, tE_mll],df['t'],df['A'], df['m_err']))
# min_model_[1].append([mean_mll, sigma_mll,amp_mll,t0_mll, u0_mll, tE_mll])


min_chisqr = lnlike([t0_, tE_, u0_, fs_, xe_, xp_, b1__, b2__, c__, a__, n__, w__, s__],df['t']-result1[0].value,df['A'], df['A_err'])#np.asarray( min_model_[0])
fp = [t0_, tE_, u0_, fs_, xe_, xp_, b1__, b2__, c__, a__, n__, w__, s__]

# %%
fitted_model = Double_horn_PSPL(t0_, tE_, u0_, fs_, xe_, xp_, b1__, b2__, c__, a__, n__, w__, s__, df['t']-result1[0])

# %%
dtt = 20
plt.plot(df['t']-result1[0].value,df['A'],'b.', markersize=25, label='Lightcurve Data')
plt.plot(df['t']-result1[0].value,fitted_model,'r.', Label='Chebyshev Approximation')
plt.ylabel('Magnification', size=25)
plt.xlabel('Time - 2458234', size=25)
#plt.title('Chebyshev approximation of a Binary-lens Microlensing Lightcurve',size=25)
plt.xlim(t0-dtt, t0+dtt)
plt.legend(loc=2,fontsize=20)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

print result2.params

fig = plt.gcf()
fig.set_size_inches(15.0,12.0)
# plt.savefig('Chebyshevfit_success.png')
# Out:
# Parameters([('t0', <Parameter 't0', value=-0.00042251894193157113 +/- 0.00284, bounds=[-100:100]>), ('tE', <Parameter 'tE', value=66.61969690860204 +/- 0.226, bounds=[0.001:1000]>), ('u0', <Parameter 'u0', value=0.10621277323435652 +/- 0.000445, bounds=[0:5]>), ('fs', <Parameter 'fs', value=0.24456058671523617 +/- 0.00111, bounds=[0:1]>), ('xe', <Parameter 'xe', value=19.192017150327885 +/- 331, bounds=[-20:20]>), ('xp', <Parameter 'xp', value=20.0 +/- 0.0127, bounds=[-20:20]>), ('b1', <Parameter 'b1', value=2.189878570139458 +/- 30.9, bounds=[2:20]>), ('b2', <Parameter 'b2', value=19.999643452617597 +/- 2.04e+03, bounds=[2:20]>), ('c', <Parameter 'c', value=0.08966664739605679 +/- 154, bounds=[0:2]>), ('a', <Parameter 'a', value=0.023856402380353636 +/- 0.0453, bounds=[0.01:0.5]>), ('n', <Parameter 'n', value=6.13855524474427 +/- 1.45e+03, bounds=[6:12]>), ('w', <Parameter 'w', value=0.5535627402950202 +/- 40.1, bounds=[0.01:5]>), ('s', <Parameter 's', value=9.658122435285138 +/- 18
# ...
